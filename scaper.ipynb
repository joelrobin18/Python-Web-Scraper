# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

url = "https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?id=14450;type=tournament"
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find('table', {'class': 'engineTable'})

# print(table)

match_summary=[]
# Extract the data from the table
rows = table.find_all('tr', {'class': ['data1', 'data2']})
for row in rows:
    cols = row.find_all('td')
    temp=[]
    
    # print(cols)
    
    team1 = cols[0].text.strip()
    temp.append(team1)
    team2 = cols[1].text.strip()
    temp.append(team2)
    result = cols[2].text.strip()
    temp.append(result)
    margin = cols[3].text.strip()
    temp.append(margin)
    Venue = cols[4].text.strip()
    temp.append(Venue)
    Date = cols[5].text.strip()
    temp.append(Date)
    Match_id = cols[6].text.strip()
    temp.append(Match_id)

    match_summary.append(temp)
    
    # print(f'{team1} vs {team2} | Result: {result} | margin: {margin} | Venue: {Venue} | Date: {Date} | Match ID: {Match_id}')
    

print(match_summary)
# Out:
# [['Namibia', 'Sri Lanka', 'Namibia', '55 runs', 'Geelong', 'Oct 16, 2022', 'T20I # 1823'], ['Netherlands', 'U.A.E.', 'Netherlands', '3 wickets', 'Geelong', 'Oct 16, 2022', 'T20I # 1825'], ['Scotland', 'West Indies', 'Scotland', '42 runs', 'Hobart', 'Oct 17, 2022', 'T20I # 1826'], ['Ireland', 'Zimbabwe', 'Zimbabwe', '31 runs', 'Hobart', 'Oct 17, 2022', 'T20I # 1828'], ['Namibia', 'Netherlands', 'Netherlands', '5 wickets', 'Geelong', 'Oct 18, 2022', 'T20I # 1830'], ['Sri Lanka', 'U.A.E.', 'Sri Lanka', '79 runs', 'Geelong', 'Oct 18, 2022', 'T20I # 1832'], ['Ireland', 'Scotland', 'Ireland', '6 wickets', 'Hobart', 'Oct 19, 2022', 'T20I # 1833'], ['West Indies', 'Zimbabwe', 'West Indies', '31 runs', 'Hobart', 'Oct 19, 2022', 'T20I # 1834'], ['Netherlands', 'Sri Lanka', 'Sri Lanka', '16 runs', 'Geelong', 'Oct 20, 2022', 'T20I # 1835'], ['Namibia', 'U.A.E.', 'U.A.E.', '7 runs', 'Geelong', 'Oct 20, 2022', 'T20I # 1836'], ['Ireland', 'West Indies', 'Ireland', '9 wickets', 'Hobart', 'Oct 21, 2022', 'T20I # 1837'], ['Scotland', 'Zimbabwe', 'Zimbabwe', '5 wickets', 'Hobart', 'Oct 21, 2022', 'T20I # 1838'], ['Australia', 'New Zealand', 'New Zealand', '89 runs', 'Sydney', 'Oct 22, 2022', 'T20I # 1839'], ['Afghanistan', 'England', 'England', '5 wickets', 'Perth', 'Oct 22, 2022', 'T20I # 1840'], ['Ireland', 'Sri Lanka', 'Sri Lanka', '9 wickets', 'Hobart', 'Oct 23, 2022', 'T20I # 1841'], ['India', 'Pakistan', 'India', '4 wickets', 'Melbourne', 'Oct 23, 2022', 'T20I # 1842'], ['Bangladesh', 'Netherlands', 'Bangladesh', '9 runs', 'Hobart', 'Oct 24, 2022', 'T20I # 1843'], ['South Africa', 'Zimbabwe', 'no result', '', 'Hobart', 'Oct 24, 2022', 'T20I # 1844'], ['Australia', 'Sri Lanka', 'Australia', '7 wickets', 'Perth', 'Oct 25, 2022', 'T20I # 1845'], ['England', 'Ireland', 'Ireland', '5 runs', 'Melbourne', 'Oct 26, 2022', 'T20I # 1846'], ['Afghanistan', 'New Zealand', 'abandoned', '', 'Melbourne', 'Oct 26, 2022', 'T20I # 1846a'], ['Bangladesh', 'South Africa', 'South Africa', '104 runs', 'Sydney', 'Oct 27, 2022', 'T20I # 1847'], ['India', 'Netherlands', 'India', '56 runs', 'Sydney', 'Oct 27, 2022', 'T20I # 1848'], ['Pakistan', 'Zimbabwe', 'Zimbabwe', '1 run', 'Perth', 'Oct 27, 2022', 'T20I # 1849'], ['Afghanistan', 'Ireland', 'abandoned', '', 'Melbourne', 'Oct 28, 2022', 'T20I # 1849a'], ['Australia', 'England', 'abandoned', '', 'Melbourne', 'Oct 28, 2022', 'T20I # 1849b'], ['New Zealand', 'Sri Lanka', 'New Zealand', '65 runs', 'Sydney', 'Oct 29, 2022', 'T20I # 1850'], ['Bangladesh', 'Zimbabwe', 'Bangladesh', '3 runs', 'Brisbane', 'Oct 30, 2022', 'T20I # 1851'], ['Netherlands', 'Pakistan', 'Pakistan', '6 wickets', 'Perth', 'Oct 30, 2022', 'T20I # 1852'], ['India', 'South Africa', 'South Africa', '5 wickets', 'Perth', 'Oct 30, 2022', 'T20I # 1853'], ['Australia', 'Ireland', 'Australia', '42 runs', 'Brisbane', 'Oct 31, 2022', 'T20I # 1855'], ['Afghanistan', 'Sri Lanka', 'Sri Lanka', '6 wickets', 'Brisbane', 'Nov 1, 2022', 'T20I # 1856'], ['England', 'New Zealand', 'England', '20 runs', 'Brisbane', 'Nov 1, 2022', 'T20I # 1858'], ['Netherlands', 'Zimbabwe', 'Netherlands', '5 wickets', 'Adelaide', 'Nov 2, 2022', 'T20I # 1859'], ['Bangladesh', 'India', 'India', '5 runs', 'Adelaide', 'Nov 2, 2022', 'T20I # 1860'], ['Pakistan', 'South Africa', 'Pakistan', '33 runs', 'Sydney', 'Nov 3, 2022', 'T20I # 1861'], ['Ireland', 'New Zealand', 'New Zealand', '35 runs', 'Adelaide', 'Nov 4, 2022', 'T20I # 1862'], ['Australia', 'Afghanistan', 'Australia', '4 runs', 'Adelaide', 'Nov 4, 2022', 'T20I # 1864'], ['England', 'Sri Lanka', 'England', '4 wickets', 'Sydney', 'Nov 5, 2022', 'T20I # 1867'], ['Netherlands', 'South Africa', 'Netherlands', '13 runs', 'Adelaide', 'Nov 6, 2022', 'T20I # 1871'], ['Bangladesh', 'Pakistan', 'Pakistan', '5 wickets', 'Adelaide', 'Nov 6, 2022', 'T20I # 1872'], ['India', 'Zimbabwe', 'India', '71 runs', 'Melbourne', 'Nov 6, 2022', 'T20I # 1873'], ['New Zealand', 'Pakistan', 'Pakistan', '7 wickets', 'Sydney', 'Nov 9, 2022', 'T20I # 1877'], ['En ...

# %%
match = pd.DataFrame(match_summary)

# %%
match.head()
# Out:
#              0            1            2          3        4             5  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#              6
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %%
links = []
for i,link in enumerate(table.find_all("a")):
    if "team" not in link.get("href") and "ground" not in link.get("href"):
        links.append(link.get("href"))

print(links)
print(i)
# Out:
# ['/ci/engine/match/1298135.html', '/ci/engine/match/1298136.html', '/ci/engine/match/1298137.html', '/ci/engine/match/1298138.html', '/ci/engine/match/1298139.html', '/ci/engine/match/1298140.html', '/ci/engine/match/1298141.html', '/ci/engine/match/1298142.html', '/ci/engine/match/1298143.html', '/ci/engine/match/1298144.html', '/ci/engine/match/1298145.html', '/ci/engine/match/1298146.html', '/ci/engine/match/1298147.html', '/ci/engine/match/1298148.html', '/ci/engine/match/1298149.html', '/ci/engine/match/1298150.html', '/ci/engine/match/1298151.html', '/ci/engine/match/1298152.html', '/ci/engine/match/1298153.html', '/ci/engine/match/1298154.html', '/ci/engine/match/1298155.html', '/ci/engine/match/1298156.html', '/ci/engine/match/1298157.html', '/ci/engine/match/1298158.html', '/ci/engine/match/1298159.html', '/ci/engine/match/1298160.html', '/ci/engine/match/1298161.html', '/ci/engine/match/1298162.html', '/ci/engine/match/1298163.html', '/ci/engine/match/1298164.html', '/ci/engine/match/1298165.html', '/ci/engine/match/1298166.html', '/ci/engine/match/1298167.html', '/ci/engine/match/1298168.html', '/ci/engine/match/1298169.html', '/ci/engine/match/1298170.html', '/ci/engine/match/1298171.html', '/ci/engine/match/1298172.html', '/ci/engine/match/1298173.html', '/ci/engine/match/1298174.html', '/ci/engine/match/1298175.html', '/ci/engine/match/1298176.html', '/ci/engine/match/1298177.html', '/ci/engine/match/1298178.html', '/ci/engine/match/1298179.html']
# 220

# %%
scorecard_link = pd.DataFrame(links)

# %%
scorecard_link.head()
# Out:
#                                0
# 0  /ci/engine/match/1298135.html
# 1  /ci/engine/match/1298136.html
# 2  /ci/engine/match/1298137.html
# 3  /ci/engine/match/1298138.html
# 4  /ci/engine/match/1298139.html

# %%
i=0

score_card=[]

for link in links:
    url_check = "https://stats.espncricinfo.com" + link
    
    response_link = requests.get(url_check)
    
    soup_check = BeautifulSoup(response_link.content,'html.parser')
    
    tables_link = soup_check.find_all('table',{'class':'ci-scorecard-table'})
    
    # match_scorecard=[]
    
    # # print(table_link)
    for table_link in tables_link:
        if table_link is not None:
            rows_check = table_link.find_all('tr')
            # print(rows_check)
            
            innings_scorecard = []
            
            for row in rows_check:
                
                col = row.find_all('td')
                # print(col)
                if len(col) > 4:
                    name = col[0].text.strip()
                    dismisal = col[1].text.strip()
                    runs = col[2].text.strip()
                    balls = col[3].text.strip()
                    
                    minutes = col[4].text.strip()
                    fours = col[5].text.strip()
                    sixes = col[6].text.strip()
                    strike_rate = col[7].text.strip()
                    
                    # print(f"Name: {name } | Dismissal: {dismisal} | Runs: {runs}: {runs} | Ball : {balls} | Minuts: {minutes} | Fours: {fours} | Sixes: {sixes} | Strike rate: {strike_rate}")
                    innings_scorecard.append([name,dismisal,runs,balls,minutes,fours,sixes,strike_rate])
            # match_scorecard.append(innings_scorecard)
            score_card.extend(innings_scorecard)
            print("match: ",i)
            i=i+1
    
    print(len(score_card))
# Out:
# match:  0
# match:  1
# 19
# match:  2
# match:  3
# 38
# match:  4
# match:  5
# 56
# match:  6
# match:  7
# 75
# match:  8
# match:  9
# 90
# match:  10
# match:  11
# 111
# match:  12
# match:  13
# 123
# match:  14
# match:  15
# 143
# match:  16
# match:  17
# 162
# match:  18
# match:  19
# 177
# match:  20
# match:  21
# 187
# match:  22
# match:  23
# 202
# match:  24
# match:  25
# 218
# match:  26
# match:  27
# 236
# match:  28
# match:  29
# 249
# match:  30
# match:  31
# 267
# match:  32
# match:  33
# 288
# match:  34
# match:  35
# 296
# match:  36
# match:  37
# 309
# match:  38
# match:  39
# 327
# 327
# match:  40
# match:  41
# 345
# match:  42
# match:  43
# 360
# match:  44
# match:  45
# 379
# 379
# 379
# match:  46
# match:  47
# 399
# match:  48
# match:  49
# 417
# match:  50
# match:  51
# 434
# match:  52
# match:  53
# 452
# match:  54
# match:  55
# 470
# match:  56
# match:  57
# 485
# match:  58
# match:  59
# 501
# match:  60
# match:  61
# 519
# match:  62
# match:  63
# 535
# match:  64
# match:  65
# 556
# match:  66
# match:  67
# 575
# match:  68
# match:  69
# 594
# match:  70
# match:  71
# 611
# match:  72
# match:  73
# 627
# match:  74
# match:  75
# 644
# match:  76
# match:  77
# 662
# match:  78
# match:  79
# 673
# match:  80
# match:  81
# 682
# match:  82
# match:  83
# 699

# %%
score_card
# Out:
# [['Michael van Lingen',
#   'c Pramod Madushan b Chameera',
#   '3',
#   '6',
#   '7',
#   '0',
#   '0',
#   '50.00'],
#  ['Divan la Cock',
#   'c Shanaka b Pramod Madushan',
#   '9',
#   '9',
#   '15',
#   '1',
#   '0',
#   '100.00'],
#  ['Jan Nicol Loftie-Eaton',
#   'c †Mendis b Karunaratne',
#   '20',
#   '12',
#   '18',
#   '1',
#   '2',
#   '166.66'],
#  ['Stephan Baard',
#   'c DM de Silva b Pramod Madushan',
#   '26',
#   '24',
#   '49',
#   '2',
#   '0',
#   '108.33'],
#  ['Gerhard Erasmus\xa0(c)',
#   'c Gunathilaka b PWH de Silva',
#   '20',
#   '24',
#   '30',
#   '0',
#   '0',
#   '83.33'],
#  ['Jan Frylinck',
#   'run out (Gunathilaka/†Mendis)',
#   '44',
#   '28',
#   '44',
#   '4',
#   '0',
#   '157.14'],
#  ['David Wiese', 'c †Mendis b Theekshana', '0', '1', '4', '0', '0', '0.00'],
#  ['JJ Smit', 'not out', '31', '16', '29', '2', '2', '193.75'],
#  ['Pathum Nissanka', 'c Smit b Shikongo', '9', '10', '16', '1', '0', '90.00'],
#  ['Kusal Mendis\xa0†', 'c †Green b Wiese', '6', '6', '8', '0', '0', '100.00'],
#  ['Dhananjaya de Silva',
#   'c Shikongo b Frylinck',
#   '12',
#   '11',
#   '25',
#   '1',
#   '0',
#   '109.09'],
#  ['Danushka Gunathilaka',
#   'c †Green b Shikongo',
#   '0',
#   '1',
#   '2',
#   '0',
#   '0',
#   '0.00'],
#  ['Bhanuka Rajapaksa',
#   'c la Cock b Scholtz',
#   '20',
#   '21',
#   '39',
#   '2',
#   '0',
#   '95.23'],
#  ['Dasun Shanaka\xa0(c)',
#   'c †Green b Frylinck',
#   '29',
#   '23',
#   '37',
#   '2',
#   '1',
#   '126.08'],
#  ['Wanindu Hasaranga de Silva',
#   'c Loftie-Eaton b Scholtz',
#   '4',
#   '8',
#   '9',
#   '0',
#   '0',
#   '50.00'],
#  ['Chamika Karunaratne', 'c Baard b Smit', '5', '8', '15', '0', '0', '62.50'],
#  ['Pramod Madushan',
#   'run out (van Lingen/†Green)',
#   '0',
#   '0',
#   '4',
#   '0',
#   '0',
#   '-'],
#  ['Dushmantha Chameera',
#   'c Erasmus b Wiese',
#   '8',
#   '15',
#   '20',
#   '0',
#   '0',
#   '53.33'],
#  ['Maheesh Theekshana', 'not out', '11', '11', '14', '0', '1', '100.00'],
#  ['Chirag Suri',
#   'c †Edwards b van der Merwe',
#   '12',
#   '20',
#   '28',
#   '1',
#   '0',
#   '60.00'],
#  ['Muhammad Waseem',
#   'c Pringle b Klaassen',
#   '41',
#   '47',
#   '71',
#   '1',
#   '2',
#   '87.23'],
#  ['Kashif Daud', 'b Pringle', '15', '14', '19', '0', '1', '107.14'],
#  ['Vriitya Aravind\xa0†',
#   'c Klaassen b de Leede',
#   '18',
#   '21',
#   '37',
#   '0',
#   '0',
#   '85.71'],
#  ['Zawar Farid',
#   'run out (Ackermann/†Edwards)',
#   '2',
#   '4',
#   '8',
#   '0',
#   '0',
#   '50.00'],
#  ['Basil Hameed',
#   'c van der Merwe b de Leede',
#   '4',
#   '4',
#   '7',
#   '1',
#   '0',
#   '100.00'],
#  ['Chundangapoyil Rizwan\xa0(c)',
#   'b de Leede',
#   '1',
#   '2',
#   '7',
#   '0',
#   '0',
#   '50.00'],
#  ['Aayan Afzal Khan', 'c Cooper b Klaassen', '5', '7', '8', '0', '0', '71.42'],
#  ['Karthik Meiyappan', 'not out', '0', '0', '4', '0', '0', '-'],
#  ['Junaid Siddique', 'not out', '0', '1', '1', '0', '0', '0.00'],
#  ['Vikramjit Singh', 'b Basil Hameed', '10', '7', '8', '2', '0', '142.85'],
#  ["Max O'Dowd", 'b Junaid Siddique', '23', '18', '25', '3', '1', '127.77'],
#  ['Bas de Leede', 'c Rizwan b Meiyappan', '14', '18', '37', '1', '0', '77.77'],
#  ['Colin Ackermann',
#   'c Junaid Siddique b Aayan Afzal Khan',
#   '17',
#   '19',
#   '33',
#   '1',
#   '0',
#   '89.47'],
#  ['Tom Cooper', 'lbw b Junaid Siddique', '8', '16', '22', '0', '0', '50.00'],
#  ['Scott Edwards\xa0(c)†', 'not out', '16', '19', '42', '0', '0', '84.21'],
#  ['Roelof van der Merwe',
#   'b Junaid Siddique',
#   '0',
#   '2',
#   '4',
#   '0',
#   '0',
#   '0.00'],
#  ['Tim Pringle', 'b Zahoor Khan', '15', '16', '26', '0', '0', '93.75'],
#  ['Logan van Beek', 'not out', '4', '4', '7', '0', '0', '100.00'],
#  ['George Munsey', 'not out', '66', '53', '106', '9', '0', '124.52'],
#  ['Michael Jones', 'b Holder', '20', '17', '36', '3', '0', '117.64'],
#  ['Matthew Cross\xa0†',
#   'c Brooks b Holder',
#   '3',
#   '5',
#   '10',
#   '0',
#   '0',
#   '60.00'],
#  ['Richie Berrington\xa0(c)',
#   'c Mayers b Joseph',
#   '16',
#   '14',
#   '21',
#   '0',
#   '1',
#   '114.28'],
#  ['Calum MacLeod', 'c King b Smith', '23', '14', '15', '4', '0', '164.28'],
#  ['Michael Leask', 'b Joseph', '4', '6', '8', '0', '0', '66.66'],
#  ['Chris Greaves', 'not out', '16', '11', '19', '2', '0', '145.45'],
#  ['Kyle Mayers', 'c Munsey b Davey', '20', '13', '12', '3', '1', '153.84'],
#  ['Evin Lewis', 'c Jones b Wheal', '14', '13', '30', '1', '1', '107.69'],
#  ['Brandon King', 'b Watt', '17', '15', '24', '3', '0', '113.33'],
#  ['Nicholas Pooran\xa0(c)†', 'b Leask', '5', '9', '14', '0', '0', '55.55'],
#  ['Shamarh Brooks', 'c Leask b Wheal', '4', '9', '24', '0', '0', '44.44'],
#  ['Rovman Powell', 'c MacLeod b Leask', '5', '6', '12', '0', '0', '83.33'],
#  ['Jason Holder', 'c Greaves b Sharif', '38', '33', '37', '4', '1', '115.15'],
#  ['Akeal Hosein', 'run out (†Cross/Leask)', '1', '1', '4', '0', '0', '100.00'],
#  ['Alzarri Joseph', 'c †Cross b Watt', '0', '1', '4', '0', '0', '0.00'],
#  ['Odean Smith', 'c Greaves b Watt', '5', '8', '14', '0', '0', '62.50'],
#  ['Obed McCoy', 'not out', '2', '3', '10', '0', '0', '66.66'],
#  ['Regis Chakabva\xa0†',
#   'c †Tucker b Little',
#   '0',
#   '2',
#   '3',
#   '0',
#   '0',
#   '0.00'],
#  ['Craig Ervine\xa0(c)',
#   'st †Tucker b Simi Singh',
#   '9',
#   '12',
#   '28',
#   '1',
#   '0',
#   '75.00'],
#  ['Wessly Madhevere',
#   'c Delany b Little',
#   '22',
#   '19',
#   '22',
#   '4',
#   '0',
#   '115.78'],
#  ['Sean Williams',
#   'c Tector b Simi Singh',
#   '12',
#   '11',
#   '24',
#   '0',
#   '1',
#   '109.09'],
#  ['Sikandar Raza', 'b Adair', '82', '48', '72', '5', '5', '170.83'],
#  ['Milton Shumba', 'c Little b Adair', '16', '14', '26', '1', '0', '114.28'],
#  ['Ryan Burl', 'c Adair b Little', '1', '4', '9', '0', '0', '25.00'],
#  ['Luke Jongwe', 'not out', '20', '10', '14', '3', '0', '200.00'],
#  ['Paul Stirling', 'b Ngarava', '0', '2', '3', '0', '0', '0.00'],
#  ['Andy Balbirnie\xa0(c)',
#   'c Ervine b Muzarabani',
#   '3',
#   '4',
#   '20',
#   '0',
#   '0',
#   '75.00'],
#  ['Lorcan Tucker\xa0†', 'b Ngarava', '11', '11', '10', '2', '0', '100.00'],
#  ['Harry Tector', 'c Ervine b Muzarabani', '1', '4', '5', '0', '0', '25.00'],
#  ['Curtis Campher', 'b Williams', '27', '22', '41', '1', '0', '122.72'],
#  ['George Dockrell', 'b Sikandar Raza', '24', '20', '25', '3', '0', '120.00'],
#  ['Gareth Delany', 'c Shumba b Chatara', '24', '20', '23', '1', '1', '120.00'],
#  ['Mark Adair',
#   'c Sikandar Raza b Muzarabani',
#   '9',
#   '10',
#   '18',
#   '0',
#   '1',
#   '90.00'],
#  ['Simi Singh', 'b Chatara', '0', '1', '1', '0', '0', '0.00'],
#  ['Barry McCarthy', 'not out', '22', '16', '23', '1', '2', '137.50'],
#  ['Josh Little', 'not out', '7', '11', '17', '1', '0', '63.63'],
#  ['Michael van Lingen',
#   'c de Leede b Ackermann',
#   '20',
#   '19',
#   '20',
#   '3',
#   '0',
#   '105.26'],
#  ['Divan la Cock', 'c de Leede b Pringle', '0', '2', '5', '0', '0', '0.00'],
#  ['Stephan Baard',
#   'c Klaassen b van der Merwe',
#   '19',
#   '22',
#   '46',
#   '0',
#   '0',
#   '86.36'],
#  ['Jan Nicol Loftie-Eaton',
#   'c †Edwards b van Meekeren',
#   '0',
#   '2',
#   '3',
#   '0',
#   '0',
#   '0.00'],
#  ['Jan Frylinck',
#   'c van Meekeren b de Leede',
#   '43',
#   '48',
#   '63',
#   '1',
#   '1',
#   '89.58'],
#  ['Gerhard Erasmus\xa0(c)', 'b de Leede', '16', '18', '37', '0', '0', '88.88'],
#  ['David Wiese', 'not out', '11', '5', '8', '1', '0', '220.00'],
#  ['JJ Smit', 'not out', '5', '4', '6', '1', '0', '125.00'],
#  ["Max O'Dowd", 'run out (Erasmus)', '35', '35', '59', '1', '1', '100.00'],
#  ['Vikramjit Singh',
#   'c Loftie-Eaton b Scholtz',
#   '39',
#   '31',
#   '37',
#   '3',
#   '2',
#   '125.80'],
#  ['Bas de Leede', 'not out', '30', '30', '51', '2', '0', '100.00'],
#  ['Tom Cooper', 'c van Lingen b Smit', '6', '6', '7', '1', '0', '100.00'],
#  ['Colin Ackermann', 'c Erasmus b Smit', '0', '2', '2', '0', '0', '0.00'],
#  ['Scott Edwards\xa0(c)†',
#   'c Loftie-Eaton b Frylinck',
#   '1',
#   '5',
#   '5',
#   '0',
#   '0',
#   '20.00'],
#  ['Tim Pringle', 'not out', '8', '9', '14', '0', '0', '88.88'],
#  ['Pathum Nissanka',
#   'c Basil Hameed b Zahoor Khan',
#   '74',
#   '60',
#   '105',
#   '6',
#   '2',
#   '123.33'],
#  ['Kusal Mendis\xa0†',
#   'lbw b Aryan Lakra',
#   '18',
#   '13',
#   '24',
#   '2',
#   '0',
#   '138.46'],
#  ['Dhananjaya de Silva',
#   'run out (Muhammad Waseem/Aayan Afzal Khan)',
#   '33',
#   '21',
#   '30',
#   '3',
#   '1',
#   '157.14'],
#  ['Bhanuka Rajapaksa',
#   'c Kashif Daud b Meiyappan',
#   '5',
#   '8',
#   '19',
#   '0',
#   '0',
#   '62.50'],
#  ['Charith Asalanka',
#   'c †Aravind b Meiyappan',
#   '0',
#   '1',
#   '2',
#   '0',
#   '0',
#   '0.00'],
#  ['Dasun Shanaka\xa0(c)', 'b Meiyappan', '0', '1', '2', '0', '0', '0.00'],
#  ['Wanindu Hasaranga de Silva',
#   'c Basil Hameed b Aayan Afzal Khan',
#   '2',
#   '3',
#   '3',
#   '0',
#   '0',
#   '66.66'],
#  ['Chamika Karunaratne',
#   'c Kashif Daud b Zahoor Khan',
#   '8',
#   '11',
#   '22',
#   '1',
#   '0',
#   '72.72'],
#  ['Pramod Madushan', 'not out', '1', '1', '4', '0', '0', '100.00'],
#  ['Dushmantha Chameera', 'not out', '1', '1', '2', '0', '0', '100.00'],
#  ['Muhammad Waseem', 'b Chameera', '2', '4', '13', '0', '0', '50.00'],
#  ['Chirag Suri', 'b Pramod Madushan', '14', '19', '31', '3', '0', '73.68'],
#  ['Aryan Lakra', 'b Chameera', '1', '3', '4', '0', '0', '33.33'],
#  ['Chundangapoyil Rizwan\xa0(c)',
#   'c Rajapaksa b Chameera',
#   '1',
#   '3',
#   '8',
#   '0',
#   '0',
#   '33.33'],
#  ['Vriitya Aravind\xa0†',
#   'lbw b PWH de Silva',
#   '9',
#   '18',
#   '26',
#   '1',
#   '0',
#   '50.00'],
#  ['Basil Hameed',
#   'c DM de Silva b Shanaka',
#   '2',
#   '6',
#   '14',
#   '0',
#   '0',
#   '33.33'],
#  ['Aayan Afzal Khan', 'b PWH de Silva', '19', '21', '33', '1', '0', '90.47'],
#  ['Kashif Daud', 'lbw b PWH de Silva', '0', '4', '8', '0', '0', '0.00'],
#  ['Karthik Meiyappan',
#   'st †Mendis b Theekshana',
#   '4',
#   '8',
#   '11',
#   '0',
#   '0',
#   '50.00'],
#  ['Junaid Siddique',
#   'c Nissanka b Theekshana',
#   '18',
#   '16',
#   '22',
#   '1',
#   '1',
#   '112.50'],
#  ['Zahoor Khan', 'not out', '1', '1', '15', '0', '0', '100.00'],
#  ['George Munsey', 'lbw b Adair', '1', '2', '9', '0', '0', '50.00'],
#  ['Michael Jones', 'c Adair b Little', '86', '55', '95', '6', '4', '156.36'],
#  ['Matthew Cross\xa0†',
#   'c McCarthy b Campher',
#   '28',
#   '21',
#   '33',
#   '5',
#   '0',
#   '133.33'],
#  ['Richie Berrington\xa0(c)',
#   'c Dockrell b Campher',
#   '37',
#   '27',
#   '39',
#   '3',
#   '1',
#   '137.03'],
#  ['Michael Leask', 'not out', '17', '13', '19', '2', '0', '130.76'],
#  ['Calum MacLeod', 'run out (†Tucker)', '0', '3', '6', '0', '0', '0.00'],
#  ['Paul Stirling', 'c †Cross b Sharif', '8', '10', '22', '1', '0', '80.00'],
#  ['Andy Balbirnie\xa0(c)',
#   'c Jones b Wheal',
#   '14',
#   '12',
#   '15',
#   '2',
#   '0',
#   '116.66'],
#  ['Lorcan Tucker\xa0†',
#   'c Davey b Watt',
#   '20',
#   '17',
#   '28',
#   '2',
#   '0',
#   '117.64'],
#  ['Harry Tector', 'c Greaves b Leask', '14', '16', '23', '1', '0', '87.50'],
#  ['Curtis Campher', 'not out', '72', '32', '48', '7', '2', '225.00'],
#  ['George Dockrell', 'not out', '39', '27', '42', '4', '1', '144.44'],
#  ['Kyle Mayers',
#   'c †Chakabva b Muzarabani',
#   '13',
#   '12',
#   '17',
#   '2',
#   '0',
#   '108.33'],
#  ['Johnson Charles',
#   'run out (Munyonga/Williams)',
#   '45',
#   '36',
#   '60',
#   '3',
#   '2',
#   '125.00'],
#  ['Evin Lewis',
#   'c Shumba b Sikandar Raza',
#   '15',
#   '18',
#   '28',
#   '1',
#   '0',
#   '83.33'],
#  ['Nicholas Pooran\xa0(c)†',
#   'c & b Williams',
#   '7',
#   '9',
#   '10',
#   '0',
#   '0',
#   '77.77'],
#  ['Rovman Powell',
#   'c Ngarava b Muzarabani',
#   '28',
#   '21',
#   '40',
#   '1',
#   '2',
#   '133.33'],
#  ['Shamarh Brooks', 'lbw b Sikandar Raza', '0', '3', '5', '0', '0', '0.00'],
#  ['Jason Holder', 'c & b Sikandar Raza', '4', '3', '3', '0', '0', '133.33'],
#  ['Akeal Hosein', 'not out', '23', '18', '31', '2', '0', '127.77'],
#  ['Odean Smith', 'not out', '1', '2', '2', '0', '0', '50.00'],
#  ['Wessly Madhevere',
#   'c Lewis b Holder',
#   '27',
#   '19',
#   '37',
#   '3',
#   '1',
#   '142.10'],
#  ['Regis Chakabva\xa0(c)†', 'b Joseph', '13', '9', '14', '3', '0', '144.44'],
#  ['Tony Munyonga', 'b Joseph', '2', '6', '12', '0', '0', '33.33'],
#  ['Sean Williams', 'c †Pooran b McCoy', '1', '2', '4', '0', '0', '50.00'],
#  ['Sikandar Raza', 'c Powell b Smith', '14', '8', '12', '1', '1', '175.00'],
#  ['Milton Shumba', 'c Brooks b Hosein', '2', '9', '20', '0', '0', '22.22'],
#  ['Ryan Burl', 'lbw b Holder', '17', '19', '30', '3', '0', '89.47'],
#  ['Luke Jongwe', 'b Joseph', '29', '22', '31', '3', '1', '131.81'],
#  ['Richard Ngarava', 'b Joseph', '2', '6', '11', '0', '0', '33.33'],
#  ['Tendai Chatara', 'b Holder', '3', '8', '12', '0', '0', '37.50'],
#  ['Blessing Muzarabani', 'not out', '1', '4', '4', '0', '0', '25.00'],
#  ['Pathum Nissanka', 'b van Meekeren', '14', '21', '25', '0', '1', '66.66'],
#  ['Kusal Mendis\xa0†',
#   'c sub (LV van Beek) b van der Gugten',
#   '79',
#   '44',
#   '94',
#   '5',
#   '5',
#   '179.54'],
#  ['Dhananjaya de Silva',
#   'lbw b van Meekeren',
#   '0',
#   '1',
#   '2',
#   '0',
#   '0',
#   '0.00'],
#  ['Charith Asalanka',
#   'c †Edwards b de Leede',
#   '31',
#   '30',
#   '38',
#   '3',
#   '0',
#   '103.33'],
#  ['Bhanuka Rajapaksa',
#   'c Pringle b de Leede',
#   '19',
#   '13',
#   '18',
#   '2',
#   '0',
#   '146.15'],
#  ['Dasun Shanaka\xa0(c)',
#   'c Ackermann b Klaassen',
#   '8',
#   '5',
#   '9',
#   '0',
#   '1',
#   '160.00'],
#  ['Wanindu Hasaranga de Silva', 'not out', '5', '4', '8', '0', '0', '125.00'],
#  ['Chamika Karunaratne', 'not out', '2', '2', '4', '0', '0', '100.00'],
#  ["Max O'Dowd", 'not out', '71', '53', '99', '6', '3', '133.96'],
#  ['Vikramjit Singh',
#   'c Shanaka b Theekshana',
#   '7',
#   '14',
#   '18',
#   '0',
#   '0',
#   '50.00'],
#  ['Bas de Leede', 'c †Mendis b Kumara', '14', '10', '12', '1', '1', '140.00'],
#  ['Colin Ackermann', 'c & b PWH de Silva', '0', '1', '4', '0', '0', '0.00'],
#  ['Tom Cooper', 'b Theekshana', '16', '19', '23', '2', '0', '84.21'],
#  ['Scott Edwards\xa0(c)†', 'b Fernando', '21', '15', '16', '3', '0', '140.00'],
#  ['Tim Pringle', 'run out (DM de Silva)', '2', '4', '8', '0', '0', '50.00'],
#  ['Timm van der Gugten', 'b PWH de Silva', '0', '1', '2', '0', '0', '0.00'],
#  ['Fred Klaassen', 'b PWH de Silva', '3', '3', '5', '0', '0', '100.00'],
#  ['Paul van Meekeren', 'run out (Shanaka)', '0', '0', '4', '0', '0', '-'],
#  ['Roelof van der Merwe', 'not out', '0', '1', '14', '0', '0', '0.00'],
#  ['Muhammad Waseem',
#   'c Trumpelmann b Shikongo',
#   '50',
#   '41',
#   '66',
#   '1',
#   '3',
#   '121.95'],
#  ['Vriitya Aravind\xa0†',
#   'c van Lingen b Scholtz',
#   '21',
#   '32',
#   '34',
#   '2',
#   '0',
#   '65.62'],
#  ['Chundangapoyil Rizwan\xa0(c)',
#   'not out',
#   '43',
#   '29',
#   '55',
#   '3',
#   '1',
#   '148.27'],
#  ['Alishan Sharafu', 'c †Green b Wiese', '4', '4', '10', '0', '0', '100.00'],
#  ['Basil Hameed', 'not out', '25', '14', '13', '2', '2', '178.57'],
#  ['Michael van Lingen',
#   'c Sharafu b Basil Hameed',
#   '10',
#   '8',
#   '14',
#   '1',
#   '0',
#   '125.00'],
#  ['Stephan Baard',
#   'c Ahmed Raza b Junaid Siddique',
#   '4',
#   '6',
#   '9',
#   '1',
#   '0',
#   '66.66'],
#  ['Jan Nicol Loftie-Eaton',
#   'lbw b Basil Hameed',
#   '1',
#   '6',
#   '17',
#   '0',
#   '0',
#   '16.66'],
#  ['Gerhard Erasmus\xa0(c)',
#   'b Meiyappan',
#   '16',
#   '18',
#   '23',
#   '2',
#   '0',
#   '88.88'],
#  ['Jan Frylinck', 'b Zahoor Khan', '14', '17', '33', '1', '0', '82.35'],
#  ['JJ Smit',
#   'run out (Meiyappan/Ahmed Raza)',
#   '3',
#   '3',
#   '3',
#   '0',
#   '0',
#   '100.00'],
#  ['David Wiese',
#   'c Sharafu b Muhammad Waseem',
#   '55',
#   '36',
#   '65',
#   '3',
#   '3',
#   '152.77'],
#  ['Zane Green\xa0†', 'b Zahoor Khan', '2', '3', '3', '0', '0', '66.66'],
#  ['Ruben Trumpelmann', 'not out', '25', '24', '43', '1', '1', '104.16'],
#  ['Bernard Scholtz', 'not out', '1', '1', '-', '0', '0', '100.00'],
#  ['Kyle Mayers', 'c Tector b McCarthy', '1', '5', '12', '0', '0', '20.00'],
#  ['Johnson Charles',
#   'c Campher b Simi Singh',
#   '24',
#   '18',
#   '22',
#   '3',
#   '1',
#   '133.33'],
#  ['Evin Lewis', 'c Adair b Delany', '13', '18', '42', '0', '0', '72.22'],
#  ['Brandon King', 'not out', '62', '48', '80', '6', '1', '129.16'],
#  ['Nicholas Pooran\xa0(c)†',
#   'c Tector b Delany',
#   '13',
#   '11',
#   '16',
#   '0',
#   '1',
#   '118.18'],
#  ['Rovman Powell', 'c Tector b Delany', '6', '8', '12', '1', '0', '75.00'],
#  ['Odean Smith', 'not out', '19', '12', '18', '1', '2', '158.33'],
#  ['Paul Stirling', 'not out', '66', '48', '79', '6', '2', '137.50'],
#  ['Andy Balbirnie\xa0(c)',
#   'c Mayers b Hosein',
#   '37',
#   '23',
#   '34',
#   '3',
#   '3',
#   '160.86'],
#  ['Lorcan Tucker\xa0†', 'not out', '45', '35', '46', '2', '2', '128.57'],
#  ['George Munsey', 'c Shumba b Ngarava', '54', '51', '74', '7', '0', '105.88'],
#  ['Michael Jones',
#   'c Sikandar Raza b Chatara',
#   '4',
#   '5',
#   '6',
#   '1',
#   '0',
#   '80.00'],
#  ['Matthew Cross\xa0†',
#   'c Madhevere b Ngarava',
#   '1',
#   '7',
#   '15',
#   '0',
#   '0',
#   '14.28'],
#  ['Richie Berrington\xa0(c)',
#   'c Shumba b Sikandar Raza',
#   '13',
#   '15',
#   '24',
#   '0',
#   '0',
#   '86.66'],
#  ['Calum MacLeod', 'c Jongwe b Chatara', '25', '26', '46', '1', '0', '96.15'],
#  ['Michael Leask', 'b Muzarabani', '12', '9', '11', '2', '0', '133.33'],
#  ['Chris Greaves', 'not out', '3', '7', '10', '0', '0', '42.85'],
#  ['Josh Davey', 'not out', '4', '3', '3', '0', '0', '133.33'],
#  ['Regis Chakabva\xa0†', 'lbw b Wheal', '4', '3', '3', '1', '0', '133.33'],
#  ['Craig Ervine\xa0(c)',
#   'c MacLeod b Watt',
#   '58',
#   '54',
#   '79',
#   '6',
#   '0',
#   '107.40'],
#  ['Wessly Madhevere', 'b Davey', '0', '5', '8', '0', '0', '0.00'],
#  ['Sean Williams', 'c Wheal b Leask', '7', '12', '28', '0', '0', '58.33'],
#  ['Sikandar Raza', 'c †Cross b Davey', '40', '23', '34', '3', '2', '173.91'],
#  ['Milton Shumba', 'not out', '11', '11', '16', '0', '0', '100.00'],
#  ['Ryan Burl', 'not out', '9', '5', '7', '1', '0', '180.00'],
#  ['Finn Allen', 'b Hazlewood', '42', '16', '24', '5', '3', '262.50'],
#  ['Devon Conway\xa0†', 'not out', '92', '58', '106', '7', '2', '158.62'],
#  ['Kane Williamson\xa0(c)',
#   'lbw b Zampa',
#   '23',
#   '23',
#   '48',
#   '1',
#   '1',
#   '100.00'],
#  ['Glenn Phillips', 'c & b Hazlewood', '12', '10', '16', '2', '0', '120.00'],
#  ['James Neesham', 'not out', '26', '13', '19', '0', '2', '200.00'],
#  ['David Warner', 'b Southee', '5', '6', '7', '1', '0', '83.33'],
#  ['Aaron Finch\xa0(c)',
#   'c Williamson b Santner',
#   '13',
#   '11',
#   '20',
#   '1',
#   '1',
#   '118.18'],
#  ['Mitchell Marsh',
#   'c Neesham b Southee',
#   '16',
#   '12',
#   '17',
#   '2',
#   '1',
#   '133.33'],
#  ['Glenn Maxwell', 'b Sodhi', '28', '20', '47', '3', '1', '140.00'],
#  ['Marcus Stoinis',
#   'c Phillips b Santner',
#   '7',
#   '14',
#   '16',
#   '0',
#   '0',
#   '50.00'],
#  ['Tim David', 'c Neesham b Santner', '11', '8', '12', '0', '1', '137.50'],
#  ['Matthew Wade\xa0†',
#   'c †Conway b Ferguson',
#   '2',
#   '4',
#   '10',
#   '0',
#   '0',
#   '50.00'],
#  ['Pat Cummins', 'c †Conway b Southee', '21', '18', '27', '2', '1', '116.66'],
#  ['Mitchell Starc', 'b Boult', '4', '7', '13', '0', '0', '57.14'],
#  ['Adam Zampa', 'b Boult', '0', '2', '3', '0', '0', '0.00'],
#  ['Josh Hazlewood', 'not out', '1', '1', '6', '0', '0', '100.00'],
#  ['Hazratullah Zazai',
#   'c Livingstone b Stokes',
#   '7',
#   '17',
#   '31',
#   '1',
#   '0',
#   '41.17'],
#  ['Rahmanullah Gurbaz\xa0†',
#   'c †Buttler b Wood',
#   '10',
#   '9',
#   '13',
#   '0',
#   '1',
#   '111.11'],
#  ['Ibrahim Zadran', 'c Ali b Curran', '32', '32', '41', '3', '1', '100.00'],
#  ['Usman Ghani',
#   'c Livingstone b Curran',
#   '30',
#   '30',
#   '60',
#   '3',
#   '0',
#   '100.00'],
#  ['Najibullah Zadran',
#   'c Rashid b Stokes',
#   '13',
#   '11',
#   '15',
#   '0',
#   '1',
#   '118.18'],
#  ['Mohammad Nabi\xa0(c)',
#   'c †Buttler b Wood',
#   '3',
#   '5',
#   '7',
#   '0',
#   '0',
#   '60.00'],
#  ['Azmatullah Omarzai',
#   'c Stokes b Curran',
#   '8',
#   '6',
#   '11',
#   '1',
#   '0',
#   '133.33'],
#  ['Rashid Khan', 'c Hales b Curran', '0', '1', '2', '0', '0', '0.00'],
#  ['Mujeeb Ur Rahman', 'c & b Woakes', '0', '1', '3', '0', '0', '0.00'],
#  ['Fareed Ahmad', 'not out', '2', '4', '7', '0', '0', '50.00'],
#  ['Fazalhaq Farooqi', 'c Malan b Curran', '0', '2', '3', '0', '0', '0.00'],
#  ['Jos Buttler\xa0(c)†',
#   'c Mujeeb Ur Rahman b Fazalhaq Farooqi',
#   '18',
#   '18',
#   '25',
#   '3',
#   '0',
#   '100.00'],
#  ['Alex Hales',
#   'c Fazalhaq Farooqi b Fareed Ahmad',
#   '19',
#   '20',
#   '41',
#   '0',
#   '1',
#   '95.00'],
#  ['Dawid Malan',
#   'c Mohammad Nabi b Mujeeb Ur Rahman',
#   '18',
#   '30',
#   '40',
#   '0',
#   '0',
#   '60.00'],
#  ['Ben Stokes', 'b Mohammad Nabi', '2', '4', '11', '0', '0', '50.00'],
#  ['Liam Livingstone', 'not out', '29', '21', '34', '3', '0', '138.09'],
#  ['Harry Brook',
#   'c Ibrahim Zadran b Rashid Khan',
#   '7',
#   '6',
#   '9',
#   '0',
#   '0',
#   '116.66'],
#  ['Moeen Ali', 'not out', '8', '10', '13', '0', '0', '80.00'],
#  ['Paul Stirling',
#   'c Rajapaksa b DM de Silva',
#   '34',
#   '25',
#   '45',
#   '4',
#   '1',
#   '136.00'],
#  ['Andy Balbirnie\xa0(c)', 'b Kumara', '1', '5', '7', '0', '0', '20.00'],
#  ['Lorcan Tucker\xa0†', 'b Theekshana', '10', '11', '20', '1', '0', '90.90'],
#  ['Harry Tector',
#   'c Shanaka b Fernando',
#   '45',
#   '42',
#   '59',
#   '2',
#   '1',
#   '107.14'],
#  ['Curtis Campher',
#   'c Asalanka b Karunaratne',
#   '2',
#   '4',
#   '6',
#   '0',
#   '0',
#   '50.00'],
#  ['George Dockrell', 'b Theekshana', '14', '16', '25', '0', '0', '87.50'],
#  ['Gareth Delany',
#   'c Karunaratne b PWH de Silva',
#   '9',
#   '6',
#   '10',
#   '1',
#   '0',
#   '150.00'],
#  ['Mark Adair',
#   'c Karunaratne b PWH de Silva',
#   '0',
#   '1',
#   '5',
#   '0',
#   '0',
#   '0.00'],
#  ['Simi Singh', 'not out', '7', '8', '9', '1', '0', '87.50'],
#  ['Barry McCarthy', 'not out', '2', '2', '7', '0', '0', '100.00'],
#  ['Kusal Mendis\xa0†', 'not out', '68', '43', '68', '5', '3', '158.13'],
#  ['Dhananjaya de Silva',
#   'c †Tucker b Delany',
#   '31',
#   '25',
#   '35',
#   '2',
#   '1',
#   '124.00'],
#  ['Charith Asalanka', 'not out', '31', '22', '33', '2', '0', '140.90'],
#  ['Mohammad Rizwan\xa0†',
#   'c Kumar b Arshdeep Singh',
#   '4',
#   '12',
#   '25',
#   '1',
#   '0',
#   '33.33'],
#  ['Babar Azam\xa0(c)',
#   'lbw b Arshdeep Singh',
#   '0',
#   '1',
#   '10',
#   '0',
#   '0',
#   '0.00'],
#  ['Shan Masood', 'not out', '52', '42', '101', '5', '0', '123.80'],
#  ['Iftikhar Ahmed',
#   'lbw b Mohammed Shami',
#   '51',
#   '34',
#   '43',
#   '2',
#   '4',
#   '150.00'],
#  ['Shadab Khan', 'c Yadav b Pandya', '5', '6', '6', '1', '0', '83.33'],
#  ['Haider Ali', 'c Yadav b Pandya', '2', '4', '6', '0', '0', '50.00'],
#  ['Mohammad Nawaz', 'c †Karthik b Pandya', '9', '6', '12', '2', '0', '150.00'],
#  ['Asif Ali', 'c †Karthik b Arshdeep Singh', '2', '3', '6', '0', '0', '66.66'],
#  ['Shaheen Shah Afridi', 'c & b Kumar', '16', '8', '17', '1', '1', '200.00'],
#  ['Haris Rauf', 'not out', '6', '4', '3', '0', '1', '150.00'],
#  ['KL Rahul', 'b Naseem Shah', '4', '8', '13', '0', '0', '50.00'],
#  ['Rohit Sharma\xa0(c)',
#   'c Iftikhar Ahmed b Haris Rauf',
#   '4',
#   '7',
#   '20',
#   '0',
#   '0',
#   '57.14'],
#  ['Virat Kohli', 'not out', '82', '53', '98', '6', '4', '154.71'],
#  ['Suryakumar Yadav',
#   'c †Mohammad Rizwan b Haris Rauf',
#   '15',
#   '10',
#   '11',
#   '2',
#   '0',
#   '150.00'],
#  ['Axar Patel',
#   'run out (Babar Azam/†Mohammad Rizwan)',
#   '2',
#   '3',
#   '7',
#   '0',
#   '0',
#   '66.66'],
#  ['Hardik Pandya',
#   'c Babar Azam b Mohammad Nawaz',
#   '40',
#   '37',
#   '61',
#   '1',
#   '2',
#   '108.10'],
#  ['Dinesh Karthik\xa0†',
#   'st †Mohammad Rizwan b Mohammad Nawaz',
#   '1',
#   '2',
#   '10',
#   '0',
#   '0',
#   '50.00'],
#  ['Ravichandran Ashwin', 'not out', '1', '1', '2', '0', '0', '100.00'],
#  ['Najmul Hossain Shanto',
#   'c van Beek b Pringle',
#   '25',
#   '20',
#   '31',
#   '4',
#   '0',
#   '125.00'],
#  ['Soumya Sarkar',
#   'c de Leede b van Meekeren',
#   '14',
#   '14',
#   '24',
#   '2',
#   '0',
#   '100.00'],
#  ['Litton Das', 'c Cooper b van Beek', '9', '11', '17', '0', '0', '81.81'],
#  ['Shakib Al Hasan\xa0(c)',
#   'c de Leede b Shariz Ahmad',
#   '7',
#   '9',
#   '14',
#   '0',
#   '0',
#   '77.77'],
#  ['Afif Hossain',
#   'c †Edwards b de Leede',
#   '38',
#   '27',
#   '47',
#   '2',
#   '2',
#   '140.74'],
#  ['Yasir Ali', 'b van Meekeren', '3', '5', '9', '0', '0', '60.00'],
#  ['Nurul Hasan\xa0†',
#   'c van Meekeren b de Leede',
#   '13',
#   '18',
#   '28',
#   '0',
#   '0',
#   '72.22'],
#  ['Mosaddek Hossain', 'not out', '20', '12', '12', '2', '1', '166.66'],
#  ['Taskin Ahmed', 'c van Beek b Klaassen', '0', '1', '3', '0', '0', '0.00'],
#  ['Hasan Mahmud', 'not out', '0', '3', '6', '0', '0', '0.00'],
#  ['Vikramjit Singh',
#   'c Yasir Ali b Taskin Ahmed',
#   '0',
#   '1',
#   '4',
#   '0',
#   '0',
#   '0.00'],
#  ["Max O'Dowd",
#   'run out (Afif Hossain/Shakib Al Hasan)',
#   '8',
#   '8',
#   '21',
#   '0',
#   '1',
#   '100.00'],
#  ['Bas de Leede',
#   'c †Nurul Hasan b Taskin Ahmed',
#   '0',
#   '1',
#   '2',
#   '0',
#   '0',
#   '0.00'],
#  ['Colin Ackermann',
#   'c Mosaddek Hossain b Taskin Ahmed',
#   '62',
#   '48',
#   '77',
#   '6',
#   '2',
#   '129.16'],
#  ['Tom Cooper',
#   'run out (Najmul Hossain Shanto/†Nurul Hasan)',
#   '0',
#   '0',
#   '2',
#   '0',
#   '0',
#   '-'],
#  ['Scott Edwards\xa0(c)†',
#   'c Hasan Mahmud b Shakib Al Hasan',
#   '16',
#   '24',
#   '33',
#   '1',
#   '0',
#   '66.66'],
#  ['Tim Pringle', 'b Hasan Mahmud', '1', '6', '5', '0', '0', '16.66'],
#  ['Logan van Beek',
#   'c Taskin Ahmed b Hasan Mahmud',
#   '2',
#   '5',
#   '9',
#   '0',
#   '0',
#   '40.00'],
#  ['Shariz Ahmad',
#   'c Hasan Mahmud b Taskin Ahmed',
#   '9',
#   '8',
#   '9',
#   '1',
#   '0',
#   '112.50'],
#  ['Fred Klaassen', 'not out', '7', '6', '20', '0', '0', '116.66'],
#  ['Paul van Meekeren',
#   'c Litton Das b Soumya Sarkar',
#   '24',
#   '14',
#   '16',
#   '3',
#   '1',
#   '171.42'],
#  ['Regis Chakabva\xa0†',
#   'c †de Kock b Ngidi',
#   '8',
#   '8',
#   '13',
#   '0',
#   '1',
#   '100.00'],
#  ['Craig Ervine\xa0(c)',
#   'c Ngidi b Parnell',
#   '2',
#   '6',
#   '11',
#   '0',
#   '0',
#   '33.33'],
#  ['Sean Williams', 'run out (Miller)', '1', '1', '10', '0', '0', '100.00'],
#  ['Sikandar Raza', 'c †de Kock b Ngidi', '0', '2', '3', '0', '0', '0.00'],
#  ['Wessly Madhevere', 'not out', '35', '18', '37', '4', '1', '194.44'],
#  ['Milton Shumba', 'c †de Kock b Nortje', '18', '20', '32', '2', '0', '90.00'],
#  ['Quinton de Kock\xa0†', 'not out', '47', '18', '26', '8', '1', '261.11'],
#  ['Temba Bavuma\xa0(c)', 'not out', '2', '2', '26', '0', '0', '100.00'],
#  ['Pathum Nissanka',
#   'run out (Marsh/†Wade)',
#   '40',
#   '45',
#   '65',
#   '2',
#   '0',
#   '88.88'],
#  ['Kusal Mendis\xa0†', 'c Marsh b Cummins', '5', '6', '9', '1', '0', '83.33'],
#  ['Dhananjaya de Silva',
#   'c Warner b Agar',
#   '26',
#   '23',
#   '47',
#   '3',
#   '0',
#   '113.04'],
#  ['Charith Asalanka', 'not out', '38', '25', '45', '3', '2', '152.00'],
#  ['Bhanuka Rajapaksa', 'c Cummins b Starc', '7', '5', '9', '1', '0', '140.00'],
#  ['Dasun Shanaka\xa0(c)',
#   'c †Wade b Maxwell',
#   '3',
#   '5',
#   '6',
#   '0',
#   '0',
#   '60.00'],
#  ['Wanindu Hasaranga de Silva',
#   'c †Wade b Hazlewood',
#   '1',
#   '4',
#   '8',
#   '0',
#   '0',
#   '25.00'],
#  ['Chamika Karunaratne', 'not out', '14', '7', '16', '2', '0', '200.00'],
#  ['David Warner',
#   'c Shanaka b Theekshana',
#   '11',
#   '10',
#   '26',
#   '0',
#   '0',
#   '110.00'],
#  ['Aaron Finch\xa0(c)', 'not out', '31', '42', '89', '0', '1', '73.80'],
#  ['Mitchell Marsh',
#   'c Rajapaksa b DM de Silva',
#   '17',
#   '17',
#   '20',
#   '1',
#   '1',
#   '100.00'],
#  ['Glenn Maxwell',
#   'c sub (KNA Bandara) b Karunaratne',
#   '23',
#   '12',
#   '21',
#   '2',
#   '2',
#   '191.66'],
#  ['Marcus Stoinis', 'not out', '59', '18', '22', '4', '6', '327.77'],
#  ['Paul Stirling', 'c Curran b Wood', '14', '8', '16', '1', '1', '175.00'],
#  ['Andy Balbirnie\xa0(c)',
#   'c Hales b Livingstone',
#   '62',
#   '47',
#   '74',
#   '5',
#   '2',
#   '131.91'],
#  ['Lorcan Tucker\xa0†',
#   'run out (Rashid)',
#   '34',
#   '27',
#   '42',
#   '3',
#   '1',
#   '125.92'],
#  ['Harry Tector', 'c †Buttler b Wood', '0', '2', '3', '0', '0', '0.00'],
#  ['Curtis Campher', 'c †Buttler b Wood', '18', '11', '22', '3', '0', '163.63'],
#  ['George Dockrell', 'b Livingstone', '0', '1', '2', '0', '0', '0.00'],
#  ['Gareth Delany', 'not out', '12', '10', '22', '1', '0', '120.00'],
#  ['Mark Adair', 'c Curran b Livingstone', '4', '4', '8', '0', '0', '100.00'],
#  ['Barry McCarthy', 'b Curran', '3', '3', '4', '0', '0', '100.00'],
#  ['Fionn Hand', 'b Curran', '1', '2', '4', '0', '0', '50.00'],
#  ['Josh Little', 'c †Buttler b Stokes', '0', '1', '3', '0', '0', '0.00'],
#  ['Jos Buttler\xa0(c)†',
#   'c †Tucker b Little',
#   '0',
#   '2',
#   '3',
#   '0',
#   '0',
#   '0.00'],
#  ['Alex Hales', 'c Adair b Little', '7', '5', '14', '1', '0', '140.00'],
#  ['Dawid Malan', 'c Hand b McCarthy', '35', '37', '66', '2', '0', '94.59'],
#  ['Ben Stokes', 'b Hand', '6', '8', '14', '0', '0', '75.00'],
#  ['Harry Brook', 'c Delany b Dockrell', '18', '21', '30', '1', '0', '85.71'],
#  ['Moeen Ali', 'not out', '24', '12', '18', '3', '1', '200.00'],
#  ['Liam Livingstone', 'not out', '1', '2', '7', '0', '0', '50.00'],
#  ['Temba Bavuma\xa0(c)',
#   'c †Nurul Hasan b Taskin Ahmed',
#   '2',
#   '6',
#   '6',
#   '0',
#   '0',
#   '33.33'],
#  ['Quinton de Kock\xa0†',
#   'c Soumya Sarkar b Afif Hossain',
#   '63',
#   '38',
#   '77',
#   '7',
#   '3',
#   '165.78'],
#  ['Rilee Rossouw',
#   'c Litton Das b Shakib Al Hasan',
#   '109',
#   '56',
#   '90',
#   '7',
#   '8',
#   '194.64'],
#  ['Tristan Stubbs',
#   'c Litton Das b Shakib Al Hasan',
#   '7',
#   '7',
#   '9',
#   '1',
#   '0',
#   '100.00'],
#  ['Aiden Markram',
#   'c Soumya Sarkar b Hasan Mahmud',
#   '10',
#   '11',
#   '16',
#   '1',
#   '0',
#   '90.90'],
#  ['David Miller', 'not out', '2', '4', '8', '0', '0', '50.00'],
#  ['Wayne Parnell', 'not out', '0', '2', '2', '0', '0', '0.00'],
#  ['Najmul Hossain Shanto', 'b Nortje', '9', '9', '15', '1', '0', '100.00'],
#  ['Soumya Sarkar', 'c †de Kock b Nortje', '15', '6', '11', '0', '2', '250.00'],
#  ['Litton Das', 'c Stubbs b Shamsi', '34', '31', '57', '1', '1', '109.67'],
#  ['Shakib Al Hasan\xa0(c)', 'lbw b Nortje', '1', '4', '11', '0', '0', '25.00'],
#  ['Afif Hossain', 'c Parnell b Rabada', '1', '5', '8', '0', '0', '20.00'],
#  ['Mehidy Hasan Miraz',
#   'c Markram b Shamsi',
#   '11',
#   '13',
#   '17',
#   '0',
#   '0',
#   '84.61'],
#  ['Mosaddek Hossain',
#   'st †de Kock b Maharaj',
#   '0',
#   '3',
#   '4',
#   '0',
#   '0',
#   '0.00'],
#  ['Nurul Hasan\xa0†', 'c Nortje b Shamsi', '2', '6', '7', '0', '0', '33.33'],
#  ['Taskin Ahmed', 'b Nortje', '10', '17', '22', '1', '0', '58.82'],
#  ['Hasan Mahmud', 'run out (Rabada)', '0', '2', '7', '0', '0', '0.00'],
#  ['Mustafizur Rahman', 'not out', '9', '3', '8', '0', '1', '300.00'],
#  ['KL Rahul', 'lbw b van Meekeren', '9', '12', '12', '1', '0', '75.00'],
#  ['Rohit Sharma\xa0(c)',
#   'c Ackermann b Klaassen',
#   '53',
#   '39',
#   '53',
#   '4',
#   '3',
#   '135.89'],
#  ['Virat Kohli', 'not out', '62', '44', '79', '3', '2', '140.90'],
#  ['Suryakumar Yadav', 'not out', '51', '25', '38', '7', '1', '204.00'],
#  ['Vikramjit Singh', 'b Kumar', '1', '9', '13', '0', '0', '11.11'],
#  ["Max O'Dowd", 'b Patel', '16', '10', '22', '3', '0', '160.00'],
#  ['Bas de Leede', 'c Pandya b Patel', '16', '23', '27', '0', '0', '69.56'],
#  ['Colin Ackermann', 'c Patel b Ashwin', '17', '21', '31', '1', '0', '80.95'],
#  ['Tom Cooper',
#   'c sub (DJ Hooda) b Ashwin',
#   '9',
#   '12',
#   '12',
#   '0',
#   '0',
#   '75.00'],
#  ['Scott Edwards\xa0(c)†',
#   'c sub (DJ Hooda) b Kumar',
#   '5',
#   '8',
#   '21',
#   '0',
#   '0',
#   '62.50'],
#  ['Tim Pringle',
#   'c Kohli b Mohammed Shami',
#   '20',
#   '15',
#   '14',
#   '1',
#   '1',
#   '133.33'],
#  ['Logan van Beek',
#   'c †Karthik b Arshdeep Singh',
#   '3',
#   '5',
#   '11',
#   '0',
#   '0',
#   '60.00'],
#  ['Shariz Ahmad', 'not out', '16', '11', '18', '2', '0', '145.45'],
#  ['Fred Klaassen', 'lbw b Arshdeep Singh', '0', '1', '3', '0', '0', '0.00'],
#  ['Paul van Meekeren', 'not out', '14', '6', '9', '3', '0', '233.33'],
#  ['Wessly Madhevere',
#   'lbw b Mohammad Wasim',
#   '17',
#   '13',
#   '30',
#   '3',
#   '0',
#   '130.76'],
#  ['Craig Ervine\xa0(c)',
#   'c Mohammad Wasim b Haris Rauf',
#   '19',
#   '19',
#   '26',
#   '2',
#   '0',
#   '100.00'],
#  ['Milton Shumba', 'c & b Shadab Khan', '8', '10', '22', '1', '0', '80.00'],
#  ['Sean Williams', 'b Shadab Khan', '31', '28', '37', '3', '0', '110.71'],
#  ['Sikandar Raza',
#   'c Haris Rauf b Mohammad Wasim',
#   '9',
#   '16',
#   '22',
#   '1',
#   '0',
#   '56.25'],
#  ['Regis Chakabva\xa0†',
#   'c Babar Azam b Shadab Khan',
#   '0',
#   '1',
#   '2',
#   '0',
#   '0',
#   '0.00'],
#  ['Ryan Burl', 'not out', '10', '15', '30', '0', '0', '66.66'],
#  ['Luke Jongwe', 'b Mohammad Wasim', '0', '1', '2', '0', '0', '0.00'],
#  ['Brad Evans', 'b Mohammad Wasim', '19', '15', '24', '0', '1', '126.66'],
#  ['Richard Ngarava', 'not out', '3', '2', '3', '0', '0', '150.00'],
#  ['Mohammad Rizwan\xa0†', 'b Muzarabani', '14', '16', '23', '1', '1', '87.50'],
#  ['Babar Azam\xa0(c)', 'c Burl b Evans', '4', '9', '17', '1', '0', '44.44'],
#  ['Shan Masood',
#   'st †Chakabva b Sikandar Raza',
#   '44',
#   '38',
#   '61',
#   '3',
#   '0',
#   '115.78'],
#  ['Iftikhar Ahmed',
#   'c †Chakabva b Jongwe',
#   '5',
#   '10',
#   '16',
#   '1',
#   '0',
#   '50.00'],
#  ['Shadab Khan',
#   'c Williams b Sikandar Raza',
#   '17',
#   '14',
#   '27',
#   '0',
#   '1',
#   '121.42'],
#  ['Haider Ali', 'lbw b Sikandar Raza', '0', '1', '3', '0', '0', '0.00'],
#  ['Mohammad Nawaz', 'c Ervine b Evans', '22', '18', '36', '1', '1', '122.22'],
#  ['Mohammad Wasim', 'not out', '12', '13', '29', '2', '0', '92.30'],
#  ['Shaheen Shah Afridi',
#   'run out (Sikandar Raza/†Chakabva)',
#   '1',
#   '1',
#   '3',
#   '0',
#   '0',
#   '100.00'],
#  ['Finn Allen', 'b Theekshana', '1', '3', '3', '0', '0', '33.33'],
#  ['Devon Conway\xa0†', 'b DM de Silva', '1', '4', '14', '0', '0', '25.00'],
#  ['Kane Williamson\xa0(c)',
#   'c †Mendis b Rajitha',
#   '8',
#   '13',
#   '18',
#   '1',
#   '0',
#   '61.53'],
#  ['Glenn Phillips',
#   'c Shanaka b Kumara',
#   '104',
#   '64',
#   '87',
#   '10',
#   '4',
#   '162.50'],
#  ['Daryl Mitchell', 'b PWH de Silva', '22', '24', '52', '0', '0', '91.66'],
#  ['James Neesham', 'c Shanaka b Rajitha', '5', '8', '15', '0', '0', '62.50'],
#  ['Mitchell Santner', 'not out', '11', '5', '17', '0', '1', '220.00'],
#  ['Ish Sodhi',
#   'run out (sub [KNA Bandara]/†Mendis)',
#   '1',
#   '1',
#   '3',
#   '0',
#   '0',
#   '100.00'],
#  ['Tim Southee', 'not out', '4', '1', '1', '1', '0', '400.00'],
#  ['Pathum Nissanka', 'lbw b Southee', '0', '5', '5', '0', '0', '0.00'],
#  ['Kusal Mendis\xa0†', 'c †Conway b Boult', '4', '3', '9', '1', '0', '133.33'],
#  ['Dhananjaya de Silva', 'b Boult', '0', '3', '8', '0', '0', '0.00'],
#  ['Charith Asalanka', 'c Allen b Boult', '4', '8', '11', '0', '0', '50.00'],
#  ['Bhanuka Rajapaksa',
#   'c Williamson b Ferguson',
#   '34',
#   '22',
#   '38',
#   '3',
#   '2',
#   '154.54'],
#  ['Chamika Karunaratne',
#   'c Boult b Santner',
#   '3',
#   '8',
#   '13',
#   '0',
#   '0',
#   '37.50'],
#  ['Dasun Shanaka\xa0(c)',
#   'c Mitchell b Boult',
#   '35',
#   '32',
#   '49',
#   '4',
#   '1',
#   '109.37'],
#  ['Wanindu Hasaranga de Silva',
#   'c Williamson b Sodhi',
#   '4',
#   '6',
#   '6',
#   '1',
#   '0',
#   '66.66'],
#  ['Maheesh Theekshana',
#   'c Neesham b Santner',
#   '0',
#   '3',
#   '5',
#   '0',
#   '0',
#   '0.00'],
#  ['Kasun Rajitha', 'not out', '8', '21', '30', '0', '0', '38.09'],
#  ['Lahiru Kumara', 'st †Conway b Sodhi', '4', '5', '10', '1', '0', '80.00'],
#  ['Najmul Hossain Shanto',
#   'c Ervine b Sikandar Raza',
#   '71',
#   '55',
#   '77',
#   '7',
#   '1',
#   '129.09'],
#  ['Soumya Sarkar',
#   'c †Chakabva b Muzarabani',
#   '0',
#   '2',
#   '9',
#   '0',
#   '0',
#   '0.00'],
#  ['Litton Das',
#   'c Chatara b Muzarabani',
#   '14',
#   '12',
#   '22',
#   '3',
#   '0',
#   '116.66'],
#  ['Shakib Al Hasan\xa0(c)',
#   'c Muzarabani b Williams',
#   '23',
#   '20',
#   '32',
#   '1',
#   '0',
#   '115.00'],
#  ['Afif Hossain', 'lbw b Ngarava', '29', '19', '40', '1', '1', '152.63'],
#  ['Mosaddek Hossain',
#   'c Chatara b Ngarava',
#   '7',
#   '10',
#   '18',
#   '0',
#   '0',
#   '70.00'],
#  ['Nurul Hasan\xa0†',
#   'run out (Williams/†Chakabva)',
#   '1',
#   '1',
#   '5',
#   '0',
#   '0',
#   '100.00'],
#  ['Yasir Ali', 'not out', '1', '1', '3', '0', '0', '100.00'],
#  ['Wessly Madhevere',
#   'c Mustafizur Rahman b Taskin Ahmed',
#   '4',
#   '3',
#   '1',
#   '1',
#   '0',
#   '133.33'],
#  ['Craig Ervine\xa0(c)',
#   'c †Nurul Hasan b Taskin Ahmed',
#   '8',
#   '7',
#   '16',
#   '2',
#   '0',
#   '114.28'],
#  ['Milton Shumba',
#   'c Shakib Al Hasan b Mustafizur Rahman',
#   '8',
#   '15',
#   '24',
#   '1',
#   '0',
#   '53.33'],
#  ['Sean Williams',
#   'run out (Shakib Al Hasan)',
#   '64',
#   '42',
#   '75',
#   '8',
#   '0',
#   '152.38'],
#  ['Sikandar Raza',
#   'c Afif Hossain b Mustafizur Rahman',
#   '0',
#   '3',
#   '4',
#   '0',
#   '0',
#   '0.00'],
#  ['Regis Chakabva\xa0†',
#   'c †Nurul Hasan b Taskin Ahmed',
#   '15',
#   '19',
#   '24',
#   '0',
#   '0',
#   '78.94'],
#  ['Ryan Burl', 'not out', '27', '25', '50', '2', '1', '108.00'],
#  ['Brad Evans',
#   'c Afif Hossain b Mosaddek Hossain',
#   '2',
#   '2',
#   '5',
#   '0',
#   '0',
#   '100.00'],
#  ['Richard Ngarava',
#   'st †Nurul Hasan b Mosaddek Hossain',
#   '6',
#   '3',
#   '6',
#   '0',
#   '1',
#   '200.00'],
#  ['Blessing Muzarabani', 'not out', '0', '2', '6', '0', '0', '0.00'],
#  ['Stephan Myburgh',
#   'c Mohammad Wasim b Shaheen Shah Afridi',
#   '6',
#   '11',
#   '13',
#   '1',
#   '0',
#   '54.54'],
#  ["Max O'Dowd", 'lbw b Shadab Khan', '8', '13', '41', '0', '0', '61.53'],
#  ['Bas de Leede', 'retired hurt', '6', '16', '15', '1', '0', '37.50'],
#  ['Tom Cooper',
#   'c Mohammad Wasim b Shadab Khan',
#   '1',
#   '2',
#   '4',
#   '0',
#   '0',
#   '50.00'],
#  ['Colin Ackermann',
#   'lbw b Shadab Khan',
#   '27',
#   '27',
#   '40',
#   '2',
#   '0',
#   '100.00'],
#  ['Scott Edwards\xa0(c)†',
#   'c Iftikhar Ahmed b Naseem Shah',
#   '15',
#   '20',
#   '38',
#   '1',
#   '0',
#   '75.00'],
#  ['Roelof van der Merwe', 'b Haris Rauf', '5', '6', '12', '0', '0', '83.33'],
#  ['Tim Pringle', 'b Mohammad Wasim', '5', '8', '15', '0', '0', '62.50'],
#  ['Logan van Beek', 'not out', '6', '9', '18', '0', '0', '66.66'],
#  ['Fred Klaassen', 'b Mohammad Wasim', '0', '1', '1', '0', '0', '0.00'],
#  ['Paul van Meekeren',
#   'run out (Shadab Khan/†Mohammad Rizwan)',
#   '7',
#   '7',
#   '8',
#   '0',
#   '0',
#   '100.00'],
#  ['Mohammad Rizwan\xa0†',
#   'c †Edwards b van Meekeren',
#   '49',
#   '39',
#   '66',
#   '5',
#   '0',
#   '125.64'],
#  ['Babar Azam\xa0(c)',
#   'run out (van der Merwe)',
#   '4',
#   '5',
#   '10',
#   '1',
#   '0',
#   '80.00'],
#  ['Fakhar Zaman', 'c †Edwards b Glover', '20', '16', '27', '3', '0', '125.00'],
#  ['Shan Masood',
#   'c van Meekeren b Glover',
#   '12',
#   '16',
#   '35',
#   '0',
#   '0',
#   '75.00'],
#  ['Iftikhar Ahmed', 'not out', '6', '5', '10', '0', '0', '120.00'],
#  ['Shadab Khan', 'not out', '4', '2', '2', '1', '0', '200.00'],
#  ['KL Rahul', 'c Markram b Ngidi', '9', '14', '25', '0', '1', '64.28'],
#  ['Rohit Sharma\xa0(c)', 'c & b Ngidi', '15', '14', '22', '1', '1', '107.14'],
#  ['Virat Kohli', 'c Rabada b Ngidi', '12', '11', '13', '2', '0', '109.09'],
#  ['Suryakumar Yadav',
#   'c Maharaj b Parnell',
#   '68',
#   '40',
#   '68',
#   '6',
#   '3',
#   '170.00'],
#  ['Deepak Hooda', 'c †de Kock b Nortje', '0', '3', '4', '0', '0', '0.00'],
#  ['Hardik Pandya', 'c Rabada b Ngidi', '2', '3', '6', '0', '0', '66.66'],
#  ['Dinesh Karthik\xa0†',
#   'c Rossouw b Parnell',
#   '6',
#   '15',
#   '33',
#   '0',
#   '0',
#   '40.00'],
#  ['Ravichandran Ashwin',
#   'c Rabada b Parnell',
#   '7',
#   '11',
#   '15',
#   '0',
#   '0',
#   '63.63'],
#  ['Bhuvneshwar Kumar', 'not out', '4', '6', '9', '0', '0', '66.66'],
#  ['Mohammed Shami', 'run out (Nortje)', '0', '2', '5', '0', '0', '0.00'],
#  ['Arshdeep Singh', 'not out', '2', '1', '2', '0', '0', '200.00'],
#  ['Quinton de Kock\xa0†',
#   'c Rahul b Arshdeep Singh',
#   '1',
#   '3',
#   '7',
#   '0',
#   '0',
#   '33.33'],
#  ['Temba Bavuma\xa0(c)',
#   'c †Karthik b Mohammed Shami',
#   '10',
#   '15',
#   '30',
#   '0',
#   '1',
#   '66.66'],
#  ['Rilee Rossouw', 'lbw b Arshdeep Singh', '0', '2', '4', '0', '0', '0.00'],
#  ['Aiden Markram', 'c Yadav b Pandya', '52', '41', '72', '6', '1', '126.82'],
#  ['David Miller', 'not out', '59', '46', '78', '4', '3', '128.26'],
#  ['Tristan Stubbs', 'lbw b Ashwin', '6', '6', '15', '1', '0', '100.00'],
#  ['Wayne Parnell', 'not out', '2', '5', '11', '0', '0', '40.00'],
#  ['David Warner', 'c Adair b McCarthy', '3', '7', '13', '0', '0', '42.85'],
#  ['Aaron Finch\xa0(c)',
#   'c Adair b McCarthy',
#   '63',
#   '44',
#   '87',
#   '5',
#   '3',
#   '143.18'],
#  ['Mitchell Marsh',
#   'c †Tucker b McCarthy',
#   '28',
#   '22',
#   '28',
#   '2',
#   '2',
#   '127.27'],
#  ['Glenn Maxwell', 'c †Tucker b Little', '13', '9', '18', '0', '1', '144.44'],
#  ['Marcus Stoinis',
#   'c Dockrell b Little',
#   '35',
#   '25',
#   '41',
#   '3',
#   '1',
#   '140.00'],
#  ['Tim David', 'not out', '15', '10', '15', '2', '0', '150.00'],
#  ['Matthew Wade\xa0†', 'not out', '7', '3', '7', '1', '0', '233.33'],
#  ['Paul Stirling', 'c Cummins b Maxwell', '11', '7', '11', '1', '1', '157.14'],
#  ['Andy Balbirnie\xa0(c)', 'b Cummins', '6', '7', '11', '0', '1', '85.71'],
#  ['Lorcan Tucker\xa0†', 'not out', '71', '48', '81', '9', '1', '147.91'],
#  ['Harry Tector',
#   'c sub (SPD Smith) b Maxwell',
#   '6',
#   '4',
#   '3',
#   '1',
#   '0',
#   '150.00'],
#  ['Curtis Campher', 'b Starc', '0', '1', '5', '0', '0', '0.00'],
#  ['George Dockrell', 'b Starc', '0', '4', '4', '0', '0', '0.00'],
#  ['Gareth Delany',
#   'c Maxwell b Stoinis',
#   '14',
#   '10',
#   '27',
#   '2',
#   '0',
#   '140.00'],
#  ['Mark Adair', 'st †Wade b Zampa', '11', '11', '13', '1', '0', '100.00'],
#  ['Fionn Hand', 'b Zampa', '6', '6', '10', '1', '0', '100.00'],
#  ['Barry McCarthy',
#   'c sub (SPD Smith) b Cummins',
#   '3',
#   '7',
#   '16',
#   '0',
#   '0',
#   '42.85'],
#  ['Josh Little', 'run out (Marsh/Maxwell)', '1', '5', '6', '0', '0', '20.00'],
#  ['Rahmanullah Gurbaz\xa0†', 'b Kumara', '28', '24', '33', '2', '2', '116.66'],
#  ['Usman Ghani',
#   'c Shanaka b PWH de Silva',
#   '27',
#   '27',
#   '54',
#   '2',
#   '1',
#   '100.00'],
#  ['Ibrahim Zadran',
#   'c Rajapaksa b Kumara',
#   '22',
#   '18',
#   '35',
#   '1',
#   '1',
#   '122.22'],
#  ['Najibullah Zadran',
#   'c PWH de Silva b DM de Silva',
#   '18',
#   '16',
#   '29',
#   '1',
#   '0',
#   '112.50'],
#  ['Gulbadin Naib',
#   'run out (Nissanka/†Mendis)',
#   '12',
#   '14',
#   '25',
#   '0',
#   '0',
#   '85.71'],
#  ['Mohammad Nabi\xa0(c)',
#   'c Shanaka b Rajitha',
#   '13',
#   '8',
#   '15',
#   '1',
#   '0',
#   '162.50'],
#  ['Rashid Khan', 'b PWH de Silva', '9', '8', '10', '1', '0', '112.50'],
#  ['Azmatullah Omarzai', 'not out', '3', '4', '3', '0', '0', '75.00'],
#  ['Mujeeb Ur Rahman',
#   'st †Mendis b PWH de Silva',
#   '1',
#   '2',
#   '1',
#   '0',
#   '0',
#   '50.00'],
#  ['Pathum Nissanka',
#   'b Mujeeb Ur Rahman',
#   '10',
#   '10',
#   '10',
#   '2',
#   '0',
#   '100.00'],
#  ['Kusal Mendis\xa0†',
#   'c †Rahmanullah Gurbaz b Rashid Khan',
#   '25',
#   '27',
#   '33',
#   '2',
#   '1',
#   '92.59'],
#  ['Dhananjaya de Silva', 'not out', '66', '42', '78', '6', '2', '157.14'],
#  ['Charith Asalanka',
#   'c Azmatullah Omarzai b Rashid Khan',
#   '19',
#   '18',
#   '27',
#   '1',
#   '0',
#   '105.55'],
#  ['Bhanuka Rajapaksa',
#   'c †Rahmanullah Gurbaz b Mujeeb Ur Rahman',
#   '18',
#   '14',
#   '24',
#   '3',
#   '0',
#   '128.57'],
#  ['Dasun Shanaka\xa0(c)', 'not out', '0', '0', '4', '0', '0', '-'],
#  ['Jos Buttler\xa0(c)†',
#   'run out (Williamson/Southee)',
#   '73',
#   '47',
#   '82',
#   '7',
#   '2',
#   '155.31'],
#  ['Alex Hales', 'st †Conway b Santner', '52', '40', '46', '7', '1', '130.00'],
#  ['Moeen Ali', 'c Boult b Sodhi', '5', '6', '13', '0', '0', '83.33'],
#  ['Liam Livingstone', 'b Ferguson', '20', '14', '20', '1', '1', '142.85'],
#  ['Harry Brook', 'c Allen b Southee', '7', '3', '6', '0', '1', '233.33'],
#  ['Ben Stokes', 'lbw b Ferguson', '8', '7', '11', '0', '0', '114.28'],
#  ['Sam Curran', 'not out', '6', '3', '7', '0', '1', '200.00'],
#  ['Dawid Malan', 'not out', '3', '1', '1', '0', '0', '300.00'],
#  ['Finn Allen', 'c Stokes b Curran', '16', '11', '25', '0', '1', '145.45'],
#  ['Devon Conway\xa0†',
#   'c †Buttler b Woakes',
#   '3',
#   '9',
#   '12',
#   '0',
#   '0',
#   '33.33'],
#  ['Kane Williamson\xa0(c)',
#   'c Rashid b Stokes',
#   '40',
#   '40',
#   '57',
#   '3',
#   '0',
#   '100.00'],
#  ['Glenn Phillips',
#   'c sub (CJ Jordan) b Curran',
#   '62',
#   '36',
#   '64',
#   '4',
#   '3',
#   '172.22'],
#  ['James Neesham', 'c Curran b Wood', '6', '3', '7', '1', '0', '200.00'],
#  ['Daryl Mitchell',
#   'c sub (CJ Jordan) b Woakes',
#   '3',
#   '5',
#   '10',
#   '0',
#   '0',
#   '60.00'],
#  ['Mitchell Santner', 'not out', '16', '10', '19', '0', '1', '160.00'],
#  ['Ish Sodhi', 'not out', '6', '6', '4', '0', '0', '100.00'],
#  ['Wessly Madhevere', 'b van Meekeren', '1', '5', '9', '0', '0', '20.00'],
#  ['Craig Ervine\xa0(c)',
#   'c †Edwards b Glover',
#   '3',
#   '12',
#   '18',
#   '0',
#   '0',
#   '25.00'],
#  ['Regis Chakabva\xa0†', 'lbw b Glover', '5', '16', '18', '1', '0', '31.25'],
#  ['Sean Williams',
#   "c O'Dowd b van Meekeren",
#   '28',
#   '23',
#   '39',
#   '3',
#   '0',
#   '121.73'],
#  ['Sikandar Raza',
#   'c Klaassen b de Leede',
#   '40',
#   '24',
#   '46',
#   '3',
#   '3',
#   '166.66'],
#  ['Milton Shumba', 'c Myburgh b van Beek', '2', '3', '6', '0', '0', '66.66'],
#  ['Ryan Burl', 'b van Meekeren', '2', '7', '19', '0', '0', '28.57'],
#  ['Luke Jongwe', 'c van Beek b de Leede', '6', '8', '12', '0', '0', '75.00'],
#  ['Richard Ngarava',
#   'c Myburgh b Klaassen',
#   '9',
#   '7',
#   '12',
#   '0',
#   '1',
#   '128.57'],
#  ['Tendai Chatara', 'not out', '6', '7', '15', '0', '0', '85.71'],
#  ['Blessing Muzarabani',
#   'c Glover b van Beek',
#   '1',
#   '4',
#   '9',
#   '0',
#   '0',
#   '25.00'],
#  ['Stephan Myburgh',
#   'c Burl b Muzarabani',
#   '8',
#   '7',
#   '15',
#   '0',
#   '1',
#   '114.28'],
#  ["Max O'Dowd", 'c Shumba b Muzarabani', '52', '47', '70', '8', '1', '110.63'],
#  ['Tom Cooper', 'c Madhevere b Jongwe', '32', '29', '42', '2', '1', '110.34'],
#  ['Colin Ackermann', 'c Jongwe b Ngarava', '1', '5', '6', '0', '0', '20.00'],
#  ['Bas de Leede', 'not out', '12', '12', '21', '2', '0', '100.00'],
#  ['Scott Edwards\xa0(c)†',
#   'c †Chakabva b Ngarava',
#   '5',
#   '6',
#   '8',
#   '1',
#   '0',
#   '83.33'],
#  ['Roelof van der Merwe', 'not out', '0', '3', '6', '0', '0', '0.00'],
#  ['KL Rahul',
#   'c Mustafizur Rahman b Shakib Al Hasan',
#   '50',
#   '32',
#   '49',
#   '3',
#   '4',
#   '156.25'],
#  ['Rohit Sharma\xa0(c)',
#   'c Yasir Ali b Hasan Mahmud',
#   '2',
#   '8',
#   '18',
#   '0',
#   '0',
#   '25.00'],
#  ['Virat Kohli', 'not out', '64', '44', '84', '8', '1', '145.45'],
#  ['Suryakumar Yadav',
#   'b Shakib Al Hasan',
#   '30',
#   '16',
#   '18',
#   '4',
#   '0',
#   '187.50'],
#  ['Hardik Pandya',
#   'c Yasir Ali b Hasan Mahmud',
#   '5',
#   '6',
#   '8',
#   '0',
#   '0',
#   '83.33'],
#  ['Dinesh Karthik\xa0†',
#   'run out (Shakib Al Hasan/Shoriful Islam)',
#   '7',
#   '5',
#   '12',
#   '1',
#   '0',
#   '140.00'],
#  ['Axar Patel',
#   'c Shakib Al Hasan b Hasan Mahmud',
#   '7',
#   '6',
#   '6',
#   '1',
#   '0',
#   '116.66'],
#  ['Ravichandran Ashwin', 'not out', '13', '6', '9', '1', '1', '216.66'],
#  ['Najmul Hossain Shanto',
#   'c Yadav b Mohammed Shami',
#   '21',
#   '25',
#   '50',
#   '1',
#   '1',
#   '84.00'],
#  ['Litton Das', 'run out (Rahul)', '60', '27', '40', '7', '3', '222.22'],
#  ['Shakib Al Hasan\xa0(c)',
#   'c sub (DJ Hooda) b Arshdeep Singh',
#   '13',
#   '12',
#   '24',
#   '2',
#   '0',
#   '108.33'],
#  ['Afif Hossain',
#   'c Yadav b Arshdeep Singh',
#   '3',
#   '5',
#   '12',
#   '0',
#   '0',
#   '60.00'],
#  ['Yasir Ali', 'c Arshdeep Singh b Pandya', '1', '3', '8', '0', '0', '33.33'],
#  ['Nurul Hasan\xa0†', 'not out', '25', '14', '29', '2', '1', '178.57'],
#  ['Mosaddek Hossain', 'b Pandya', '6', '3', '4', '0', '1', '200.00'],
#  ['Taskin Ahmed', 'not out', '12', '7', '22', '1', '1', '171.42'],
#  ['Mohammad Rizwan\xa0†', 'b Parnell', '4', '4', '4', '1', '0', '100.00'],
#  ['Babar Azam\xa0(c)', 'c Rabada b Ngidi', '6', '15', '29', '0', '0', '40.00'],
#  ['Mohammad Haris', 'lbw b Nortje', '28', '11', '19', '2', '3', '254.54'],
#  ['Shan Masood', 'c Bavuma b Nortje', '2', '6', '11', '0', '0', '33.33'],
#  ['Iftikhar Ahmed',
#   'c Rossouw b Rabada',
#   '51',
#   '35',
#   '73',
#   '3',
#   '2',
#   '145.71'],
#  ['Mohammad Nawaz', 'lbw b Shamsi', '28', '22', '32', '4', '1', '127.27'],
#  ['Shadab Khan', 'c Stubbs b Nortje', '52', '22', '31', '3', '4', '236.36'],
#  ['Mohammad Wasim', 'c Bavuma b Nortje', '0', '1', '1', '0', '0', '0.00'],
#  ['Naseem Shah', 'not out', '5', '3', '3', '0', '0', '166.66'],
#  ['Haris Rauf', 'run out (Klaasen/Bavuma)', '3', '2', '2', '0', '0', '150.00'],
#  ['Temba Bavuma\xa0(c)',
#   'c †Mohammad Rizwan b Shadab Khan',
#   '36',
#   '19',
#   '39',
#   '4',
#   '1',
#   '189.47'],
#  ['Quinton de Kock\xa0†',
#   'c Mohammad Haris b Shaheen Shah Afridi',
#   '0',
#   '5',
#   '6',
#   '0',
#   '0',
#   '0.00'],
#  ['Rilee Rossouw',
#   'c Naseem Shah b Shaheen Shah Afridi',
#   '7',
#   '6',
#   '10',
#   '0',
#   '1',
#   '116.66'],
#  ['Aiden Markram', 'b Shadab Khan', '20', '14', '28', '4', '0', '142.85'],
#  ['Heinrich Klaasen',
#   'c Mohammad Wasim b Shaheen Shah Afridi',
#   '15',
#   '9',
#   '18',
#   '3',
#   '0',
#   '166.66'],
#  ['Tristan Stubbs',
#   'c Mohammad Nawaz b Naseem Shah',
#   '18',
#   '18',
#   '28',
#   '0',
#   '1',
#   '100.00'],
#  ['Wayne Parnell', 'lbw b Mohammad Wasim', '3', '4', '9', '0', '0', '75.00'],
#  ['Kagiso Rabada',
#   'run out (Mohammad Nawaz/Haris Rauf)',
#   '1',
#   '2',
#   '11',
#   '0',
#   '0',
#   '50.00'],
#  ['Anrich Nortje',
#   'c Mohammad Haris b Haris Rauf',
#   '1',
#   '5',
#   '8',
#   '0',
#   '0',
#   '20.00'],
#  ['Lungi Ngidi', 'not out', '4', '1', '5', '1', '0', '400.00'],
#  ['Tabraiz Shamsi', 'not out', '1', '1', '3', '0', '0', '100.00'],
#  ['Finn Allen', 'c Hand b Adair', '32', '18', '30', '5', '1', '177.77'],
#  ['Devon Conway\xa0†',
#   'c Adair b Delany',
#   '28',
#   '33',
#   '55',
#   '2',
#   '0',
#   '84.84'],
#  ['Kane Williamson\xa0(c)',
#   'c Delany b Little',
#   '61',
#   '35',
#   '59',
#   '5',
#   '3',
#   '174.28'],
#  ['Glenn Phillips', 'c Dockrell b Delany', '17', '9', '9', '2', '1', '188.88'],
#  ['Daryl Mitchell', 'not out', '31', '21', '35', '2', '0', '147.61'],
#  ['James Neesham', 'lbw b Little', '0', '1', '3', '0', '0', '0.00'],
#  ['Mitchell Santner', 'lbw b Little', '0', '1', '2', '0', '0', '0.00'],
#  ['Tim Southee', 'not out', '1', '2', '7', '0', '0', '50.00'],
#  ['Paul Stirling', 'b Sodhi', '37', '27', '39', '3', '1', '137.03'],
#  ['Andy Balbirnie\xa0(c)', 'b Santner', '30', '25', '36', '0', '3', '120.00'],
#  ['Lorcan Tucker\xa0†',
#   'c Allen b Sodhi',
#   '13',
#   '14',
#   '30',
#   '0',
#   '0',
#   '92.85'],
#  ['Harry Tector', 'c Southee b Santner', '2', '7', '4', '0', '0', '28.57'],
#  ['Gareth Delany',
#   'c †Conway b Ferguson',
#   '10',
#   '8',
#   '12',
#   '2',
#   '0',
#   '125.00'],
#  ['George Dockrell',
#   'c Williamson b Ferguson',
#   '23',
#   '15',
#   '24',
#   '3',
#   '0',
#   '153.33'],
#  ['Curtis Campher', 'c Allen b Southee', '7', '7', '10', '1', '0', '100.00'],
#  ['Fionn Hand', 'c & b Ferguson', '5', '3', '7', '1', '0', '166.66'],
#  ['Mark Adair', 'c Phillips b Southee', '4', '5', '9', '0', '0', '80.00'],
#  ['Barry McCarthy', 'not out', '6', '5', '10', '0', '0', '120.00'],
#  ['Josh Little', 'not out', '8', '4', '3', '0', '1', '200.00'],
#  ['David Warner', 'b Naveen-ul-Haq', '25', '18', '28', '5', '0', '138.88'],
#  ['Cameron Green',
#   'c Gulbadin Naib b Fazalhaq Farooqi',
#   '3',
#   '2',
#   '12',
#   '0',
#   '0',
#   '150.00'],
#  ['Mitchell Marsh',
#   'c †Rahmanullah Gurbaz b Mujeeb Ur Rahman',
#   '45',
#   '30',
#   '42',
#   '3',
#   '2',
#   '150.00'],
#  ['Steven Smith', 'lbw b Naveen-ul-Haq', '4', '4', '6', '1', '0', '100.00'],
#  ['Marcus Stoinis',
#   'c Usman Ghani b Rashid Khan',
#   '25',
#   '21',
#   '41',
#   '0',
#   '2',
#   '119.04'],
#  ['Glenn Maxwell', 'not out', '54', '32', '46', '6', '2', '168.75'],
#  ['Matthew Wade\xa0(c)†',
#   'b Fazalhaq Farooqi',
#   '6',
#   '8',
#   '14',
#   '1',
#   '0',
#   '75.00'],
#  ['Pat Cummins',
#   'c Rashid Khan b Naveen-ul-Haq',
#   '0',
#   '2',
#   '4',
#   '0',
#   '0',
#   '0.00'],
#  ['Kane Richardson',
#   'run out (Naveen-ul-Haq)',
#   '1',
#   '1',
#   '6',
#   '0',
#   '0',
#   '100.00'],
#  ['Adam Zampa', 'not out', '1', '1', '5', '0', '0', '100.00'],
#  ['Rahmanullah Gurbaz\xa0†',
#   'c Warner b Richardson',
#   '30',
#   '17',
#   '31',
#   '2',
#   '2',
#   '176.47'],
#  ['Usman Ghani', 'c Cummins b Hazlewood', '2', '7', '16', '0', '0', '28.57'],
#  ['Ibrahim Zadran', 'c Marsh b Zampa', '26', '33', '55', '2', '0', '78.78'],
#  ['Gulbadin Naib', 'run out (Maxwell)', '39', '23', '38', '3', '2', '169.56'],
#  ['Mohammad Nabi\xa0(c)',
#   'c Warner b Hazlewood',
#   '1',
#   '2',
#   '10',
#   '0',
#   '0',
#   '50.00'],
#  ['Najibullah Zadran', 'c Maxwell b Zampa', '0', '2', '3', '0', '0', '0.00'],
#  ['Darwish Rasooli',
#   'run out (†Wade/Stoinis)',
#   '15',
#   '13',
#   '28',
#   '1',
#   '0',
#   '115.38'],
#  ['Rashid Khan', 'not out', '48', '23', '27', '3', '4', '208.69'],
#  ['Naveen-ul-Haq', 'not out', '0', '0', '4', '0', '0', '-'],
#  ['Pathum Nissanka',
#   'c sub (CJ Jordan) b Rashid',
#   '67',
#   '45',
#   '70',
#   '2',
#   '5',
#   '148.88'],
#  ['Kusal Mendis\xa0†',
#   'c Livingstone b Woakes',
#   '18',
#   '14',
#   '21',
#   '1',
#   '1',
#   '128.57'],
#  ['Dhananjaya de Silva',
#   'c Stokes b Curran',
#   '9',
#   '11',
#   '17',
#   '0',
#   '0',
#   '81.81'],
#  ['Charith Asalanka', 'c Malan b Stokes', '8', '9', '15', '0', '0', '88.88'],
#  ['Bhanuka Rajapaksa',
#   'c Curran b Wood',
#   '22',
#   '22',
#   '41',
#   '3',
#   '0',
#   '100.00'],
#  ['Dasun Shanaka\xa0(c)',
#   'c †Buttler b Wood',
#   '3',
#   '8',
#   '12',
#   '0',
#   '0',
#   '37.50'],
#  ['Wanindu Hasaranga de Silva',
#   'run out (†Buttler/Wood)',
#   '9',
#   '9',
#   '13',
#   '1',
#   '0',
#   '100.00'],
#  ['Chamika Karunaratne', 'c Hales b Wood', '0', '2', '3', '0', '0', '0.00'],
#  ['Maheesh Theekshana', 'not out', '0', '0', '2', '0', '0', '-'],
#  ['Jos Buttler\xa0(c)†',
#   'c Karunaratne b PWH de Silva',
#   '28',
#   '23',
#   '35',
#   '2',
#   '1',
#   '121.73'],
#  ['Alex Hales', 'c & b PWH de Silva', '47', '30', '42', '7', '1', '156.66'],
#  ['Ben Stokes', 'not out', '42', '36', '59', '2', '0', '116.66'],
#  ['Harry Brook', 'c & b DM de Silva', '4', '5', '9', '0', '0', '80.00'],
#  ['Liam Livingstone',
#   'c DM de Silva b Kumara',
#   '4',
#   '6',
#   '10',
#   '0',
#   '0',
#   '66.66'],
#  ['Moeen Ali', 'c Shanaka b DM de Silva', '1', '5', '8', '0', '0', '20.00'],
#  ['Sam Curran', 'c Rajitha b Kumara', '6', '11', '16', '0', '0', '54.54'],
#  ['Chris Woakes', 'not out', '5', '3', '11', '1', '0', '166.66'],
#  ['Stephan Myburgh',
#   'c Rossouw b Markram',
#   '37',
#   '30',
#   '41',
#   '7',
#   '0',
#   '123.33'],
#  ["Max O'Dowd", 'c Rabada b Maharaj', '29', '31', '61', '1', '1', '93.54'],
#  ['Tom Cooper', 'c †de Kock b Maharaj', '35', '19', '30', '2', '2', '184.21'],
#  ['Colin Ackermann', 'not out', '41', '26', '31', '3', '2', '157.69'],
#  ['Bas de Leede', 'b Nortje', '1', '7', '11', '0', '0', '14.28'],
#  ['Scott Edwards\xa0(c)†', 'not out', '12', '7', '11', '2', '0', '171.42'],
#  ['Quinton de Kock\xa0†',
#   'c †Edwards b Klaassen',
#   '13',
#   '13',
#   '12',
#   '1',
#   '1',
#   '100.00'],
#  ['Temba Bavuma\xa0(c)',
#   'b van Meekeren',
#   '20',
#   '20',
#   '26',
#   '2',
#   '0',
#   '100.00'],
#  ['Rilee Rossouw', "c O'Dowd b Glover", '25', '19', '29', '2', '0', '131.57'],
#  ['Aiden Markram',
#   'c Myburgh b Klaassen',
#   '17',
#   '13',
#   '30',
#   '2',
#   '0',
#   '130.76'],
#  ['David Miller',
#   'c van der Merwe b Glover',
#   '17',
#   '17',
#   '28',
#   '1',
#   '0',
#   '100.00'],
#  ['Heinrich Klaasen',
#   'c van Beek b de Leede',
#   '21',
#   '18',
#   '27',
#   '0',
#   '1',
#   '116.66'],
#  ['Wayne Parnell', 'c †Edwards b Glover', '0', '2', '3', '0', '0', '0.00'],
#  ['Keshav Maharaj',
#   "c O'Dowd b de Leede",
#   '13',
#   '12',
#   '20',
#   '0',
#   '1',
#   '108.33'],
#  ['Kagiso Rabada', 'not out', '9', '8', '13', '0', '0', '112.50'],
#  ['Anrich Nortje', 'not out', '4', '1', '2', '1', '0', '400.00'],
#  ['Najmul Hossain Shanto',
#   'b Iftikhar Ahmed',
#   '54',
#   '48',
#   '66',
#   '7',
#   '0',
#   '112.50'],
#  ['Litton Das',
#   'c Shan Masood b Shaheen Shah Afridi',
#   '10',
#   '8',
#   '15',
#   '0',
#   '1',
#   '125.00'],
#  ['Soumya Sarkar',
#   'c Shan Masood b Shadab Khan',
#   '20',
#   '17',
#   '38',
#   '1',
#   '1',
#   '117.64'],
#  ['Shakib Al Hasan\xa0(c)',
#   'lbw b Shadab Khan',
#   '0',
#   '1',
#   '4',
#   '0',
#   '0',
#   '0.00'],
#  ['Afif Hossain', 'not out', '24', '20', '47', '3', '0', '120.00'],
#  ['Mosaddek Hossain',
#   'b Shaheen Shah Afridi',
#   '5',
#   '11',
#   '17',
#   '0',
#   '0',
#   '45.45'],
#  ['Nurul Hasan\xa0†',
#   'c Mohammad Haris b Shaheen Shah Afridi',
#   '0',
#   '3',
#   '4',
#   '0',
#   '0',
#   '0.00'],
#  ['Taskin Ahmed',
#   'c Babar Azam b Shaheen Shah Afridi',
#   '1',
#   '5',
#   '8',
#   '0',
#   '0',
#   '20.00'],
#  ['Nasum Ahmed',
#   'c Mohammad Wasim b Haris Rauf',
#   '7',
#   '6',
#   '9',
#   '1',
#   '0',
#   '116.66'],
#  ['Mustafizur Rahman', 'not out', '0', '1', '1', '0', '0', '0.00'],
#  ['Mohammad Rizwan\xa0†',
#   'c Najmul Hossain Shanto b Ebadot Hossain',
#   '32',
#   '32',
#   '51',
#   '2',
#   '1',
#   '100.00'],
#  ['Babar Azam\xa0(c)',
#   'c Mustafizur Rahman b Nasum Ahmed',
#   '25',
#   '33',
#   '46',
#   '2',
#   '0',
#   '75.75'],
#  ['Mohammad Nawaz',
#   'run out (Litton Das)',
#   '4',
#   '11',
#   '27',
#   '0',
#   '0',
#   '36.36'],
#  ['Mohammad Haris',
#   'c Nasum Ahmed b Shakib Al Hasan',
#   '31',
#   '18',
#   '31',
#   '1',
#   '2',
#   '172.22'],
#  ['Shan Masood', 'not out', '24', '14', '20', '2', '0', '171.42'],
#  ['Iftikhar Ahmed',
#   'c Najmul Hossain Shanto b Mustafizur Rahman',
#   '1',
#   '3',
#   '8',
#   '0',
#   '0',
#   '33.33'],
#  ['Shadab Khan', 'not out', '0', '0', '2', '0', '0', '-'],
#  ['KL Rahul',
#   'c Masakadza b Sikandar Raza',
#   '51',
#   '35',
#   '59',
#   '3',
#   '3',
#   '145.71'],
#  ['Rohit Sharma\xa0(c)',
#   'c Masakadza b Muzarabani',
#   '15',
#   '13',
#   '20',
#   '2',
#   '0',
#   '115.38'],
#  ['Virat Kohli', 'c Burl b Williams', '26', '25', '36', '2', '0', '104.00'],
#  ['Suryakumar Yadav', 'not out', '61', '25', '44', '6', '4', '244.00'],
#  ['Rishabh Pant\xa0†', 'c Burl b Williams', '3', '5', '7', '0', '0', '60.00'],
#  ['Hardik Pandya',
#   'c Muzarabani b Ngarava',
#   '18',
#   '18',
#   '29',
#   '2',
#   '0',
#   '100.00'],
#  ['Axar Patel', 'not out', '0', '0', '6', '0', '0', '-'],
#  ['Wessly Madhevere', 'c Kohli b Kumar', '0', '1', '1', '0', '0', '0.00'],
#  ['Craig Ervine\xa0(c)', 'c & b Pandya', '13', '15', '37', '2', '0', '86.66'],
#  ['Regis Chakabva\xa0†', 'b Arshdeep Singh', '0', '6', '9', '0', '0', '0.00'],
#  ['Sean Williams',
#   'c Kumar b Mohammed Shami',
#   '11',
#   '18',
#   '22',
#   '0',
#   '1',
#   '61.11'],
#  ['Sikandar Raza', 'c Yadav b Pandya', '34', '24', '53', '3', '0', '141.66'],
#  ['Tony Munyonga', 'lbw b Mohammed Shami', '5', '4', '6', '1', '0', '125.00'],
#  ['Ryan Burl', 'b Ashwin', '35', '22', '27', '5', '1', '159.09'],
#  ['Wellington Masakadza',
#   'c Sharma b Ashwin',
#   '1',
#   '7',
#   '8',
#   '0',
#   '0',
#   '14.28'],
#  ['Richard Ngarava', 'b Ashwin', '1', '2', '4', '0', '0', '50.00'],
#  ['Tendai Chatara', 'c & b Patel', '4', '4', '11', '1', '0', '100.00'],
#  ['Blessing Muzarabani', 'not out', '0', '2', '5', '0', '0', '0.00'],
#  ['Finn Allen',
#   'lbw b Shaheen Shah Afridi',
#   '4',
#   '3',
#   '6',
#   '1',
#   '0',
#   '133.33'],
#  ['Devon Conway\xa0†',
#   'run out (Shadab Khan)',
#   '21',
#   '20',
#   '35',
#   '3',
#   '0',
#   '105.00'],
#  ['Kane Williamson\xa0(c)',
#   'b Shaheen Shah Afridi',
#   '46',
#   '42',
#   '81',
#   '1',
#   '1',
#   '109.52'],
#  ['Glenn Phillips', 'c & b Mohammad Nawaz', '6', '8', '9', '1', '0', '75.00'],
#  ['Daryl Mitchell', 'not out', '53', '35', '60', '3', '1', '151.42'],
#  ['James Neesham', 'not out', '16', '12', '19', '1', '0', '133.33'],
#  ['Mohammad Rizwan\xa0†',
#   'c Phillips b Boult',
#   '57',
#   '43',
#   '77',
#   '5',
#   '0',
#   '132.55'],
#  ['Babar Azam\xa0(c)',
#   'c Mitchell b Boult',
#   '53',
#   '42',
#   '56',
#   '7',
#   '0',
#   '126.19'],
#  ['Mohammad Haris', 'c Allen b Santner', '30', '26', '32', '2', '1', '115.38'],
#  ['Shan Masood', 'not out', '3', '4', '13', '0', '0', '75.00'],
#  ['Iftikhar Ahmed', 'not out', '0', '0', '3', '0', '0', '-'],
#  ['KL Rahul', 'c †Buttler b Woakes', '5', '5', '8', '1', '0', '100.00'],
#  ['Rohit Sharma\xa0(c)',
#   'c Curran b Jordan',
#   '27',
#   '28',
#   '37',
#   '4',
#   '0',
#   '96.42'],
#  ['Virat Kohli', 'c Rashid b Jordan', '50', '40', '75', '4', '1', '125.00'],
#  ['Suryakumar Yadav', 'c Salt b Rashid', '14', '10', '14', '1', '1', '140.00'],
#  ['Hardik Pandya',
#   'hit wicket b Jordan',
#   '63',
#   '33',
#   '47',
#   '4',
#   '5',
#   '190.90'],
#  ['Rishabh Pant\xa0†',
#   'run out (†Buttler/Jordan)',
#   '6',
#   '4',
#   '13',
#   '1',
#   '0',
#   '150.00'],
#  ['Ravichandran Ashwin', 'not out', '0', '0', '4', '0', '0', '-'],
#  ['Jos Buttler\xa0(c)†', 'not out', '80', '49', '74', '9', '3', '163.26'],
#  ['Alex Hales', 'not out', '86', '47', '74', '4', '7', '182.97'],
#  ['Mohammad Rizwan\xa0†', 'b Curran', '15', '14', '24', '0', '1', '107.14'],
#  ['Babar Azam\xa0(c)', 'c & b Rashid', '32', '28', '58', '2', '0', '114.28'],
#  ['Mohammad Haris', 'c Stokes b Rashid', '8', '12', '15', '1', '0', '66.66'],
#  ['Shan Masood',
#   'c Livingstone b Curran',
#   '38',
#   '28',
#   '46',
#   '2',
#   '1',
#   '135.71'],
#  ['Iftikhar Ahmed', 'c †Buttler b Stokes', '0', '6', '8', '0', '0', '0.00'],
#  ['Shadab Khan', 'c Woakes b Jordan', '20', '14', '26', '2', '0', '142.85'],
#  ['Mohammad Nawaz',
#   'c Livingstone b Curran',
#   '5',
#   '7',
#   '11',
#   '0',
#   '0',
#   '71.42'],
#  ['Mohammad Wasim',
#   'c Livingstone b Jordan',
#   '4',
#   '8',
#   '12',
#   '0',
#   '0',
#   '50.00'],
#  ['Shaheen Shah Afridi', 'not out', '5', '3', '8', '1', '0', '166.66'],
#  ['Haris Rauf', 'not out', '1', '1', '3', '0', '0', '100.00'],
#  ['Jos Buttler\xa0(c)†',
#   'c †Mohammad Rizwan b Haris Rauf',
#   '26',
#   '17',
#   '33',
#   '3',
#   '1',
#   '152.94'],
#  ['Alex Hales', 'b Shaheen Shah Afridi', '1', '2', '6', '0', '0', '50.00'],
#  ['Phil Salt',
#   'c Iftikhar Ahmed b Haris Rauf',
#   '10',
#   '9',
#   '16',
#   '2',
#   '0',
#   '111.11'],
#  ['Ben Stokes', 'not out', '52', '49', '81', '5', '1', '106.12'],
#  ['Harry Brook',
#   'c Shaheen Shah Afridi b Shadab Khan',
#   '20',
#   '23',
#   '36',
#   '1',
#   '0',
#   '86.95'],
#  ['Moeen Ali', 'b Mohammad Wasim', '19', '13', '30', '3', '0', '146.15'],
#  ['Liam Livingstone', 'not out', '1', '1', '3', '0', '0', '100.00']]

# %%
scorecard = pd.DataFrame(score_card)
scorecard.tail(22)
# Out:
#                        0                                    1   2   3   4  5  \
# 677        Hardik Pandya                  hit wicket b Jordan  63  33  47  4
# 678       Rishabh Pant †            run out (†Buttler/Jordan)   6   4  13  1
# 679  Ravichandran Ashwin                              not out   0   0   4  0
# 680     Jos Buttler (c)†                              not out  80  49  74  9
# 681           Alex Hales                              not out  86  47  74  4
# 682    Mohammad Rizwan †                             b Curran  15  14  24  0
# 683       Babar Azam (c)                         c & b Rashid  32  28  58  2
# 684       Mohammad Haris                    c Stokes b Rashid   8  12  15  1
# 685          Shan Masood               c Livingstone b Curran  38  28  46  2
# 686       Iftikhar Ahmed                  c †Buttler b Stokes   0   6   8  0
# 687          Shadab Khan                    c Woakes b Jordan  20  14  26  2
# 688       Mohammad Nawaz               c Livingstone b Curran   5   7  11  0
# 689       Mohammad Wasim               c Livingstone b Jordan   4   8  12  0
# 690  Shaheen Shah Afridi                              not out   5   3   8  1
# 691           Haris Rauf                              not out   1   1   3  0
# 692     Jos Buttler (c)†      c †Mohammad Rizwan b Haris Rauf  26  17  33  3
# 693           Alex Hales                b Shaheen Shah Afridi   1   2   6  0
# 694            Phil Salt        c Iftikhar Ahmed b Haris Rauf  10   9  16  2
# 695           Ben Stokes                              not out  52  49  81  5
# 696          Harry Brook  c Shaheen Shah Afridi b Shadab Khan  20  23  36  1
# 697            Moeen Ali                     b Mohammad Wasim  19  13  30  3
# 698     Liam Livingstone                              not out   1   1   3  0
#
#      6       7
# 677  5  190.90
# 678  0  150.00
# 679  0       -
# 680  3  163.26
# 681  7  182.97
# 682  1  107.14
# 683  0  114.28
# 684  0   66.66
# 685  1  135.71
# 686  0    0.00
# 687  0  142.85
# 688  0   71.42
# 689  0   50.00
# 690  0  166.66
# 691  0  100.00
# 692  1  152.94
# 693  0   50.00
# 694  0  111.11
# 695  1  106.12
# 696  0   86.95
# 697  0  146.15
# 698  0  100.00

# %%
scorecard.to_csv("scorecard.csv")

# %%
scorecard.rename(columns={0:"Batsman",1:"Dismisal",2:"Runs",3:"Balls",4:"Minutes Batted",5:"Fours",6:"Sixes",7:"Strike Rate"},inplace=True)

# %%
scorecard.head()
# Out:
#                   Batsman                         Dismisal Runs Balls  \
# 0      Michael van Lingen     c Pramod Madushan b Chameera    3     6
# 1           Divan la Cock      c Shanaka b Pramod Madushan    9     9
# 2  Jan Nicol Loftie-Eaton          c †Mendis b Karunaratne   20    12
# 3           Stephan Baard  c DM de Silva b Pramod Madushan   26    24
# 4     Gerhard Erasmus (c)     c Gunathilaka b PWH de Silva   20    24
#
#   Minutes Batted Fours Sixes Strike Rate
# 0              7     0     0       50.00
# 1             15     1     0      100.00
# 2             18     1     2      166.66
# 3             49     2     0      108.33
# 4             30     0     0       83.33

# %%
match.head()
# Out:
#              0            1            2          3        4             5  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#              6
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %%
match.rename(columns={0:"Team1",1:"Team2",2:"Result",3:"Margin",4:"Venue",5:"Date",6:"Match ID"},inplace=True)

# %%
match.to_csv("match_summary.csv")

# %%
scorecard_link.head()
# Out:
#                                0
# 0  /ci/engine/match/1298135.html
# 1  /ci/engine/match/1298136.html
# 2  /ci/engine/match/1298137.html
# 3  /ci/engine/match/1298138.html
# 4  /ci/engine/match/1298139.html

# %%
scorecard_link.rename(columns={0:"Link"},inplace=True)

# %%
scorecard_link.to_csv("Link.csv")

# %%
i=0
bowling_summary=[]
for link in links:
    url_check = "https://stats.espncricinfo.com" + link
    
    response_link = requests.get(url_check)
    
    soup_check = BeautifulSoup(response_link.content,'html.parser')
    
    tables_link = soup_check.find_all('table')
    
    bowling_datas_team1 = tables_link[1].find_all("tr")
    for datas in bowling_datas_team1:
        data = datas.find_all("td") 
        if len(data) >4:
            bowler =  data[0].text.strip()
            over = data[1].text.strip()
            maiden = data[2].text.strip()
            runs = data[3].text.strip()
            wicket = data[4].text.strip()
            economy = data[5].text.strip()
            dot = data[6].text.strip()
            fours = data[7].text.strip()
            sixes= data[8].text.strip()
            wide = data[9].text.strip()
            no_balls = data[10].text.strip()
            bowling_summary.append([bowler,over,maiden,runs,wicket,economy,dot,fours,sixes,wide,no_balls])
            print(len(bowling_summary))
            # print(bowler,over,maiden,wicket,economy,dot,fours,sixes,wide,no_balls)
    i=i+1
    print("Innings: ",i)
    
    bowling_datas_team2 = tables_link[1].find_all("tr")
    for datas in bowling_datas_team2:
        data = datas.find_all("td") 
        if len(data) >4:
            bowler =  data[0].text.strip()
            over = data[1].text.strip()
            maiden = data[2].text.strip()
            runs = data[3].text.strip()
            wicket = data[4].text.strip()
            economy = data[5].text.strip()
            dot = data[6].text.strip()
            fours = data[7].text.strip()
            sixes= data[8].text.strip()
            wide = data[9].text.strip()
            no_balls = data[10].text.strip()
            bowling_summary.append([bowler,over,maiden,runs,wicket,economy,dot,fours,sixes,wide,no_balls])
            print(len(bowling_summary))
            # print(bowler,over,maiden,wicket,economy,dot,fours,sixes,wide,no_balls)
    i=i+1
    print("Innings: ",i)
# Out:
# 1
# 2
# 3
# 4
# 5
# Innings:  1
# 6
# 7
# 8
# 9
# 10
# Innings:  2
# 11
# 12
# 13
# 14
# 15
# 16
# Innings:  3
# 17
# 18
# 19
# 20
# 21
# 22
# Innings:  4
# 23
# 24
# 25
# 26
# 27
# 28
# Innings:  5
# 29
# 30
# 31
# 32
# 33
# 34
# Innings:  6
# 35
# 36
# 37
# 38
# 39
# 40
# Innings:  7
# 41
# 42
# 43
# 44
# 45
# 46
# Innings:  8
# 47
# 48
# 49
# 50
# 51
# 52
# 53
# Innings:  9
# 54
# 55
# 56
# 57
# 58
# 59
# 60
# Innings:  10
# 61
# 62
# 63
# 64
# 65
# 66
# 67
# Innings:  11
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# Innings:  12
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# Innings:  13
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# Innings:  14
# 89
# 90
# 91
# 92
# 93
# 94
# Innings:  15
# 95
# 96
# 97
# 98
# 99
# 100
# Innings:  16
# 101
# 102
# 103
# 104
# 105
# 106
# Innings:  17
# 107
# 108
# 109
# 110
# 111
# 112
# Innings:  18
# 113
# 114
# 115
# 116
# 117
# 118
# Innings:  19
# 119
# 120
# 121
# 122
# 123
# 124
# Innings:  20
# 125
# 126
# 127
# 128
# 129
# 130
# Innings:  21
# 131
# 132
# 133
# 134
# 135
# 136
# Innings:  22
# 137
# 138
# 139
# 140
# 141
# 142
# Innings:  23
# 143
# 144
# 145
# 146
# 147
# 148
# Innings:  24
# 149
# 150
# 151
# 152
# 153
# Innings:  25
# 154
# 155
# 156
# 157
# 158
# Innings:  26
# 159
# 160
# 161
# 162
# 163
# Innings:  27
# 164
# 165
# 166
# 167
# 168
# Innings:  28
# 169
# 170
# 171
# 172
# 173
# 174
# Innings:  29
# 175
# 176
# 177
# 178
# 179
# 180
# Innings:  30
# 181
# 182
# 183
# 184
# 185
# 186
# Innings:  31
# 187
# 188
# 189
# 190
# 191
# 192
# Innings:  32
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# Innings:  33
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# Innings:  34
# 207
# 208
# 209
# 210
# 211
# Innings:  35
# 212
# 213
# 214
# 215
# 216
# Innings:  36
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# Innings:  37
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# Innings:  38
# 231
# 232
# 233
# 234
# 235
# 236
# Innings:  39
# 237
# 238
# 239
# 240
# 241
# 242
# Innings:  40
# Innings:  41
# Innings:  42
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# Innings:  43
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# Innings:  44
# 257
# 258
# 259
# 260
# 261
# 262
# Innings:  45
# 263
# 264
# 265
# 266
# 267
# 268
# Innings:  46
# 269
# 270
# 271
# 272
# 273
# Innings:  47
# 274
# 275
# 276
# 277
# 278
# Innings:  48
# Innings:  49
# Innings:  50
# Innings:  51
# Innings:  52
# 279
# 280
# 281
# 282
# 283
# 284
# Innings:  53
# 285
# 286
# 287
# 288
# 289
# 290
# Innings:  54
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# Innings:  55
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# Innings:  56
# 305
# 306
# 307
# 308
# 309
# 310
# Innings:  57
# 311
# 312
# 313
# 314
# 315
# 316
# Innings:  58
# 317
# 318
# 319
# 320
# 321
# 322
# Innings:  59
# 323
# 324
# 325
# 326
# 327
# 328
# Innings:  60
# 329
# 330
# 331
# 332
# 333
# 334
# Innings:  61
# 335
# 336
# 337
# 338
# 339
# 340
# Innings:  62
# 341
# 342
# 343
# 344
# 345
# 346
# Innings:  63
# 347
# 348
# 349
# 350
# 351
# 352
# Innings:  64
# 353
# 354
# 355
# 356
# 357
# Innings:  65
# 358
# 359
# 360
# 361
# 362
# Innings:  66
# 363
# 364
# 365
# 366
# 367
# 368
# Innings:  67
# 369
# 370
# 371
# 372
# 373
# 374
# Innings:  68
# 375
# 376
# 377
# 378
# 379
# Innings:  69
# 380
# 381
# 382
# 383
# 384
# Innings:  70
# 385
# 386
# 387
# 388
# 389
# Innings:  71
# 390
# 391
# 392
# 393
# 394
# Innings:  72
# 395
# 396
# 397
# 398
# 399
# 400
# Innings:  73
# 401
# 402
# 403
# 404
# 405
# 406
# Innings:  74
# 407
# 408
# 409
# 410
# 411
# 412
# Innings:  75
# 413
# 414
# 415
# 416
# 417
# 418
# Innings:  76
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# Innings:  77
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# Innings:  78
# 433
# 434
# 435
# 436
# 437
# 438
# Innings:  79
# 439
# 440
# 441
# 442
# 443
# 444
# Innings:  80
# 445
# 446
# 447
# 448
# 449
# 450
# Innings:  81
# 451
# 452
# 453
# 454
# 455
# 456
# Innings:  82
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# Innings:  83
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# Innings:  84
# 471
# 472
# 473
# 474
# 475
# 476
# Innings:  85
# 477
# 478
# 479
# 480
# 481
# 482
# Innings:  86
# 483
# 484
# 485
# 486
# 487
# 488
# Innings:  87
# 489
# 490
# 491
# 492
# 493
# 494
# Innings:  88
# 495
# 496
# 497
# 498
# 499
# 500
# Innings:  89
# 501
# 502
# 503
# 504
# 505
# 506
# Innings:  90

# %%
bowling_summary
# Out:
# [['Maheesh Theekshana', '4', '0', '23', '1', '5.75', '7', '0', '0', '2', '0'],
#  ['Dushmantha Chameera', '4', '0', '39', '1', '9.75', '6', '3', '1', '2', '0'],
#  ['Pramod Madushan', '4', '0', '37', '2', '9.25', '6', '3', '1', '0', '0'],
#  ['Chamika Karunaratne', '4', '0', '36', '1', '9.00', '7', '3', '1', '1', '0'],
#  ['Wanindu Hasaranga de Silva',
#   '4',
#   '0',
#   '27',
#   '1',
#   '6.75',
#   '8',
#   '1',
#   '1',
#   '0',
#   '0'],
#  ['Maheesh Theekshana', '4', '0', '23', '1', '5.75', '7', '0', '0', '2', '0'],
#  ['Dushmantha Chameera', '4', '0', '39', '1', '9.75', '6', '3', '1', '2', '0'],
#  ['Pramod Madushan', '4', '0', '37', '2', '9.25', '6', '3', '1', '0', '0'],
#  ['Chamika Karunaratne', '4', '0', '36', '1', '9.00', '7', '3', '1', '1', '0'],
#  ['Wanindu Hasaranga de Silva',
#   '4',
#   '0',
#   '27',
#   '1',
#   '6.75',
#   '8',
#   '1',
#   '1',
#   '0',
#   '0'],
#  ['Fred Klaassen', '4', '0', '13', '2', '3.25', '18', '0', '0', '3', '0'],
#  ['Tim Pringle', '4', '0', '13', '1', '3.25', '11', '0', '0', '0', '0'],
#  ['Logan van Beek', '2', '0', '19', '0', '9.50', '5', '0', '2', '1', '0'],
#  ['Bas de Leede', '3', '0', '19', '3', '6.33', '9', '2', '0', '2', '0'],
#  ['Paul van Meekeren', '4', '0', '21', '0', '5.25', '11', '1', '0', '0', '0'],
#  ['Roelof van der Merwe',
#   '3',
#   '0',
#   '19',
#   '1',
#   '6.33',
#   '7',
#   '0',
#   '1',
#   '0',
#   '0'],
#  ['Fred Klaassen', '4', '0', '13', '2', '3.25', '18', '0', '0', '3', '0'],
#  ['Tim Pringle', '4', '0', '13', '1', '3.25', '11', '0', '0', '0', '0'],
#  ['Logan van Beek', '2', '0', '19', '0', '9.50', '5', '0', '2', '1', '0'],
#  ['Bas de Leede', '3', '0', '19', '3', '6.33', '9', '2', '0', '2', '0'],
#  ['Paul van Meekeren', '4', '0', '21', '0', '5.25', '11', '1', '0', '0', '0'],
#  ['Roelof van der Merwe',
#   '3',
#   '0',
#   '19',
#   '1',
#   '6.33',
#   '7',
#   '0',
#   '1',
#   '0',
#   '0'],
#  ['Kyle Mayers', '2', '0', '24', '0', '12.00', '5', '5', '0', '2', '0'],
#  ['Akeal Hosein', '4', '0', '31', '0', '7.75', '8', '2', '1', '0', '0'],
#  ['Alzarri Joseph', '4', '0', '28', '2', '7.00', '9', '3', '0', '2', '0'],
#  ['Obed McCoy', '3', '0', '25', '0', '8.33', '6', '4', '0', '0', '0'],
#  ['Jason Holder', '3', '0', '14', '2', '4.66', '8', '1', '0', '0', '0'],
#  ['Odean Smith', '4', '0', '31', '1', '7.75', '6', '3', '0', '1', '0'],
#  ['Kyle Mayers', '2', '0', '24', '0', '12.00', '5', '5', '0', '2', '0'],
#  ['Akeal Hosein', '4', '0', '31', '0', '7.75', '8', '2', '1', '0', '0'],
#  ['Alzarri Joseph', '4', '0', '28', '2', '7.00', '9', '3', '0', '2', '0'],
#  ['Obed McCoy', '3', '0', '25', '0', '8.33', '6', '4', '0', '0', '0'],
#  ['Jason Holder', '3', '0', '14', '2', '4.66', '8', '1', '0', '0', '0'],
#  ['Odean Smith', '4', '0', '31', '1', '7.75', '6', '3', '0', '1', '0'],
#  ['Josh Little', '4', '0', '24', '3', '6.00', '11', '3', '0', '0', '0'],
#  ['Mark Adair', '4', '0', '39', '2', '9.75', '6', '3', '1', '2', '0'],
#  ['Barry McCarthy', '4', '0', '24', '0', '6.00', '11', '2', '0', '2', '0'],
#  ['Curtis Campher', '3', '0', '29', '0', '9.66', '6', '2', '2', '0', '0'],
#  ['Simi Singh', '3', '0', '31', '2', '10.33', '5', '2', '2', '1', '0'],
#  ['Gareth Delany', '2', '0', '21', '0', '10.50', '4', '2', '1', '1', '0'],
#  ['Josh Little', '4', '0', '24', '3', '6.00', '11', '3', '0', '0', '0'],
#  ['Mark Adair', '4', '0', '39', '2', '9.75', '6', '3', '1', '2', '0'],
#  ['Barry McCarthy', '4', '0', '24', '0', '6.00', '11', '2', '0', '2', '0'],
#  ['Curtis Campher', '3', '0', '29', '0', '9.66', '6', '2', '2', '0', '0'],
#  ['Simi Singh', '3', '0', '31', '2', '10.33', '5', '2', '2', '1', '0'],
#  ['Gareth Delany', '2', '0', '21', '0', '10.50', '4', '2', '1', '1', '0'],
#  ['Fred Klaassen', '3', '0', '15', '0', '5.00', '11', '1', '0', '0', '0'],
#  ['Tim Pringle', '3', '0', '15', '1', '5.00', '8', '0', '0', '0', '0'],
#  ['Bas de Leede', '3', '0', '18', '2', '6.00', '6', '1', '0', '0', '0'],
#  ['Colin Ackermann', '3', '0', '17', '1', '5.66', '8', '2', '0', '0', '0'],
#  ['Paul van Meekeren', '4', '0', '18', '1', '4.50', '11', '1', '0', '1', '0'],
#  ['Timm van der Gugten', '3', '0', '29', '0', '9.66', '4', '1', '1', '2', '0'],
#  ['Roelof van der Merwe', '1', '0', '6', '1', '6.00', '1', '0', '0', '1', '0'],
#  ['Fred Klaassen', '3', '0', '15', '0', '5.00', '11', '1', '0', '0', '0'],
#  ['Tim Pringle', '3', '0', '15', '1', '5.00', '8', '0', '0', '0', '0'],
#  ['Bas de Leede', '3', '0', '18', '2', '6.00', '6', '1', '0', '0', '0'],
#  ['Colin Ackermann', '3', '0', '17', '1', '5.66', '8', '2', '0', '0', '0'],
#  ['Paul van Meekeren', '4', '0', '18', '1', '4.50', '11', '1', '0', '1', '0'],
#  ['Timm van der Gugten', '3', '0', '29', '0', '9.66', '4', '1', '1', '2', '0'],
#  ['Roelof van der Merwe', '1', '0', '6', '1', '6.00', '1', '0', '0', '1', '0'],
#  ['Junaid Siddique', '4', '0', '36', '0', '9.00', '8', '2', '1', '2', '0'],
#  ['Kashif Daud', '1', '0', '14', '0', '14.00', '0', '2', '0', '0', '0'],
#  ['Zahoor Khan', '4', '0', '26', '2', '6.50', '10', '3', '0', '0', '0'],
#  ['Aayan Afzal Khan', '3', '0', '16', '1', '5.33', '7', '1', '0', '0', '0'],
#  ['Aryan Lakra', '3', '0', '24', '1', '8.00', '5', '3', '0', '0', '0'],
#  ['Karthik Meiyappan', '4', '0', '19', '3', '4.75', '12', '0', '1', '0', '0'],
#  ['Basil Hameed', '1', '0', '13', '0', '13.00', '1', '1', '1', '0', '0'],
#  ['Junaid Siddique', '4', '0', '36', '0', '9.00', '8', '2', '1', '2', '0'],
#  ['Kashif Daud', '1', '0', '14', '0', '14.00', '0', '2', '0', '0', '0'],
#  ['Zahoor Khan', '4', '0', '26', '2', '6.50', '10', '3', '0', '0', '0'],
#  ['Aayan Afzal Khan', '3', '0', '16', '1', '5.33', '7', '1', '0', '0', '0'],
#  ['Aryan Lakra', '3', '0', '24', '1', '8.00', '5', '3', '0', '0', '0'],
#  ['Karthik Meiyappan', '4', '0', '19', '3', '4.75', '12', '0', '1', '0', '0'],
#  ['Basil Hameed', '1', '0', '13', '0', '13.00', '1', '1', '1', '0', '0'],
#  ['Josh Little', '4', '0', '30', '1', '7.50', '10', '2', '1', '1', '0'],
#  ['Mark Adair', '4', '0', '23', '1', '5.75', '12', '2', '0', '2', '0'],
#  ['Barry McCarthy', '4', '0', '59', '0', '14.75', '4', '6', '3', '1', '1'],
#  ['Gareth Delany', '3', '0', '28', '0', '9.33', '3', '2', '1', '0', '0'],
#  ['Simi Singh', '2', '0', '16', '0', '8.00', '2', '2', '0', '0', '0'],
#  ['Curtis Campher', '2', '0', '9', '2', '4.50', '7', '1', '0', '0', '0'],
#  ['George Dockrell', '1', '0', '9', '0', '9.00', '1', '1', '0', '0', '0'],
#  ['Josh Little', '4', '0', '30', '1', '7.50', '10', '2', '1', '1', '0'],
#  ['Mark Adair', '4', '0', '23', '1', '5.75', '12', '2', '0', '2', '0'],
#  ['Barry McCarthy', '4', '0', '59', '0', '14.75', '4', '6', '3', '1', '1'],
#  ['Gareth Delany', '3', '0', '28', '0', '9.33', '3', '2', '1', '0', '0'],
#  ['Simi Singh', '2', '0', '16', '0', '8.00', '2', '2', '0', '0', '0'],
#  ['Curtis Campher', '2', '0', '9', '2', '4.50', '7', '1', '0', '0', '0'],
#  ['George Dockrell', '1', '0', '9', '0', '9.00', '1', '1', '0', '0', '0'],
#  ['Richard Ngarava', '3', '0', '20', '0', '6.66', '9', '1', '1', '1', '0'],
#  ['Tendai Chatara', '3', '0', '22', '0', '7.33', '5', '2', '0', '2', '0'],
#  ['Blessing Muzarabani',
#   '4',
#   '0',
#   '38',
#   '2',
#   '9.50',
#   '10',
#   '2',
#   '2',
#   '2',
#   '1'],
#  ['Ryan Burl', '3', '0', '27', '0', '9.00', '5', '3', '1', '0', '0'],
#  ['Sikandar Raza', '4', '0', '19', '3', '4.75', '7', '0', '0', '0', '0'],
#  ['Sean Williams', '3', '0', '17', '1', '5.66', '7', '1', '0', '0', '1'],
#  ['Richard Ngarava', '3', '0', '20', '0', '6.66', '9', '1', '1', '1', '0'],
#  ['Tendai Chatara', '3', '0', '22', '0', '7.33', '5', '2', '0', '2', '0'],
#  ['Blessing Muzarabani',
#   '4',
#   '0',
#   '38',
#   '2',
#   '9.50',
#   '10',
#   '2',
#   '2',
#   '2',
#   '1'],
#  ['Ryan Burl', '3', '0', '27', '0', '9.00', '5', '3', '1', '0', '0'],
#  ['Sikandar Raza', '4', '0', '19', '3', '4.75', '7', '0', '0', '0', '0'],
#  ['Sean Williams', '3', '0', '17', '1', '5.66', '7', '1', '0', '0', '1'],
#  ['Fred Klaassen', '4', '0', '34', '1', '8.50', '9', '1', '2', '0', '0'],
#  ['Tim Pringle', '3', '0', '22', '0', '7.33', '8', '0', '2', '0', '0'],
#  ['Roelof van der Merwe',
#   '3',
#   '0',
#   '16',
#   '0',
#   '5.33',
#   '10',
#   '2',
#   '0',
#   '0',
#   '0'],
#  ['Paul van Meekeren', '4', '0', '25', '2', '6.25', '11', '3', '0', '1', '0'],
#  ['Bas de Leede', '3', '0', '31', '2', '10.33', '5', '2', '2', '0', '0'],
#  ['Timm van der Gugten',
#   '3',
#   '0',
#   '31',
#   '1',
#   '10.33',
#   '3',
#   '2',
#   '1',
#   '0',
#   '0'],
#  ['Fred Klaassen', '4', '0', '34', '1', '8.50', '9', '1', '2', '0', '0'],
#  ['Tim Pringle', '3', '0', '22', '0', '7.33', '8', '0', '2', '0', '0'],
#  ['Roelof van der Merwe',
#   '3',
#   '0',
#   '16',
#   '0',
#   '5.33',
#   '10',
#   '2',
#   '0',
#   '0',
#   '0'],
#  ['Paul van Meekeren', '4', '0', '25', '2', '6.25', '11', '3', '0', '1', '0'],
#  ['Bas de Leede', '3', '0', '31', '2', '10.33', '5', '2', '2', '0', '0'],
#  ['Timm van der Gugten',
#   '3',
#   '0',
#   '31',
#   '1',
#   '10.33',
#   '3',
#   '2',
#   '1',
#   '0',
#   '0'],
#  ['Ruben Trumpelmann', '4', '0', '22', '0', '5.50', '10', '0', '0', '3', '0'],
#  ['David Wiese', '4', '0', '27', '1', '6.75', '12', '2', '1', '1', '0'],
#  ['Bernard Scholtz', '4', '0', '22', '1', '5.50', '11', '1', '1', '0', '0'],
#  ['JJ Smit', '4', '0', '39', '0', '9.75', '11', '2', '3', '0', '0'],
#  ['Jan Frylinck', '3', '0', '30', '0', '10.00', '3', '2', '1', '1', '0'],
#  ['Ben Shikongo', '1', '0', '8', '1', '8.00', '1', '1', '0', '0', '0'],
#  ['Ruben Trumpelmann', '4', '0', '22', '0', '5.50', '10', '0', '0', '3', '0'],
#  ['David Wiese', '4', '0', '27', '1', '6.75', '12', '2', '1', '1', '0'],
#  ['Bernard Scholtz', '4', '0', '22', '1', '5.50', '11', '1', '1', '0', '0'],
#  ['JJ Smit', '4', '0', '39', '0', '9.75', '11', '2', '3', '0', '0'],
#  ['Jan Frylinck', '3', '0', '30', '0', '10.00', '3', '2', '1', '1', '0'],
#  ['Ben Shikongo', '1', '0', '8', '1', '8.00', '1', '1', '0', '0', '0'],
#  ['Josh Little', '4', '0', '31', '0', '7.75', '8', '1', '2', '1', '0'],
#  ['Mark Adair', '4', '0', '26', '0', '6.50', '12', '1', '1', '4', '0'],
#  ['Barry McCarthy', '4', '0', '33', '1', '8.25', '9', '3', '1', '1', '0'],
#  ['Curtis Campher', '2', '0', '28', '0', '14.00', '2', '4', '1', '0', '0'],
#  ['Simi Singh', '2', '0', '11', '1', '5.50', '4', '1', '0', '0', '0'],
#  ['Gareth Delany', '4', '0', '16', '3', '4.00', '12', '1', '0', '1', '0'],
#  ['Josh Little', '4', '0', '31', '0', '7.75', '8', '1', '2', '1', '0'],
#  ['Mark Adair', '4', '0', '26', '0', '6.50', '12', '1', '1', '4', '0'],
#  ['Barry McCarthy', '4', '0', '33', '1', '8.25', '9', '3', '1', '1', '0'],
#  ['Curtis Campher', '2', '0', '28', '0', '14.00', '2', '4', '1', '0', '0'],
#  ['Simi Singh', '2', '0', '11', '1', '5.50', '4', '1', '0', '0', '0'],
#  ['Gareth Delany', '4', '0', '16', '3', '4.00', '12', '1', '0', '1', '0'],
#  ['Tendai Chatara', '4', '1', '14', '2', '3.50', '14', '1', '0', '0', '0'],
#  ['Richard Ngarava', '4', '0', '28', '2', '7.00', '12', '4', '0', '1', '1'],
#  ['Blessing Muzarabani', '4', '0', '34', '1', '8.50', '9', '5', '0', '0', '2'],
#  ['Sean Williams', '3', '0', '19', '0', '6.33', '4', '1', '0', '0', '0'],
#  ['Sikandar Raza', '4', '0', '20', '1', '5.00', '10', '0', '0', '2', '0'],
#  ['Wessly Madhevere', '1', '0', '7', '0', '7.00', '1', '0', '0', '0', '0'],
#  ['Tendai Chatara', '4', '1', '14', '2', '3.50', '14', '1', '0', '0', '0'],
#  ['Richard Ngarava', '4', '0', '28', '2', '7.00', '12', '4', '0', '1', '1'],
#  ['Blessing Muzarabani', '4', '0', '34', '1', '8.50', '9', '5', '0', '0', '2'],
#  ['Sean Williams', '3', '0', '19', '0', '6.33', '4', '1', '0', '0', '0'],
#  ['Sikandar Raza', '4', '0', '20', '1', '5.00', '10', '0', '0', '2', '0'],
#  ['Wessly Madhevere', '1', '0', '7', '0', '7.00', '1', '0', '0', '0', '0'],
#  ['Mitchell Starc', '4', '0', '36', '0', '9.00', '5', '3', '1', '0', '0'],
#  ['Josh Hazlewood', '4', '0', '41', '2', '10.25', '8', '5', '1', '1', '0'],
#  ['Pat Cummins', '4', '0', '46', '0', '11.50', '8', '4', '2', '2', '0'],
#  ['Marcus Stoinis', '4', '0', '38', '0', '9.50', '3', '1', '2', '1', '0'],
#  ['Adam Zampa', '4', '0', '39', '1', '9.75', '4', '2', '2', '1', '0'],
#  ['Mitchell Starc', '4', '0', '36', '0', '9.00', '5', '3', '1', '0', '0'],
#  ['Josh Hazlewood', '4', '0', '41', '2', '10.25', '8', '5', '1', '1', '0'],
#  ['Pat Cummins', '4', '0', '46', '0', '11.50', '8', '4', '2', '2', '0'],
#  ['Marcus Stoinis', '4', '0', '38', '0', '9.50', '3', '1', '2', '1', '0'],
#  ['Adam Zampa', '4', '0', '39', '1', '9.75', '4', '2', '2', '1', '0'],
#  ['Ben Stokes', '4', '0', '19', '2', '4.75', '14', '2', '0', '1', '0'],
#  ['Chris Woakes', '4', '0', '24', '1', '6.00', '15', '2', '1', '1', '0'],
#  ['Mark Wood', '4', '0', '23', '2', '5.75', '14', '2', '1', '0', '0'],
#  ['Sam Curran', '3.4', '0', '10', '5', '2.72', '16', '1', '0', '1', '0'],
#  ['Adil Rashid', '4', '0', '32', '0', '8.00', '4', '1', '1', '0', '0'],
#  ['Ben Stokes', '4', '0', '19', '2', '4.75', '14', '2', '0', '1', '0'],
#  ['Chris Woakes', '4', '0', '24', '1', '6.00', '15', '2', '1', '1', '0'],
#  ['Mark Wood', '4', '0', '23', '2', '5.75', '14', '2', '1', '0', '0'],
#  ['Sam Curran', '3.4', '0', '10', '5', '2.72', '16', '1', '0', '1', '0'],
#  ['Adil Rashid', '4', '0', '32', '0', '8.00', '4', '1', '1', '0', '0'],
#  ['Binura Fernando', '4', '0', '27', '1', '6.75', '10', '3', '0', '1', '0'],
#  ['Lahiru Kumara', '2', '0', '12', '1', '6.00', '6', '2', '0', '0', '0'],
#  ['Maheesh Theekshana', '4', '0', '19', '2', '4.75', '8', '1', '0', '0', '0'],
#  ['Chamika Karunaratne', '4', '0', '29', '1', '7.25', '7', '2', '1', '0', '0'],
#  ['Wanindu Hasaranga de Silva',
#   '4',
#   '0',
#   '25',
#   '2',
#   '6.25',
#   '6',
#   '0',
#   '1',
#   '0',
#   '0'],
#  ['Dhananjaya de Silva', '2', '0', '13', '1', '6.50', '3', '1', '0', '0', '0'],
#  ['Binura Fernando', '4', '0', '27', '1', '6.75', '10', '3', '0', '1', '0'],
#  ['Lahiru Kumara', '2', '0', '12', '1', '6.00', '6', '2', '0', '0', '0'],
#  ['Maheesh Theekshana', '4', '0', '19', '2', '4.75', '8', '1', '0', '0', '0'],
#  ['Chamika Karunaratne', '4', '0', '29', '1', '7.25', '7', '2', '1', '0', '0'],
#  ['Wanindu Hasaranga de Silva',
#   '4',
#   '0',
#   '25',
#   '2',
#   '6.25',
#   '6',
#   '0',
#   '1',
#   '0',
#   '0'],
#  ['Dhananjaya de Silva', '2', '0', '13', '1', '6.50', '3', '1', '0', '0', '0'],
#  ['Bhuvneshwar Kumar', '4', '0', '22', '1', '5.50', '17', '1', '1', '3', '0'],
#  ['Arshdeep Singh', '4', '0', '32', '3', '8.00', '10', '3', '1', '1', '0'],
#  ['Mohammed Shami', '4', '0', '25', '1', '6.25', '14', '4', '0', '1', '0'],
#  ['Hardik Pandya', '4', '0', '30', '3', '7.50', '10', '4', '0', '0', '0'],
#  ['Ravichandran Ashwin', '3', '0', '23', '0', '7.66', '5', '0', '1', '1', '0'],
#  ['Axar Patel', '1', '0', '21', '0', '21.00', '2', '0', '3', '0', '0'],
#  ['Bhuvneshwar Kumar', '4', '0', '22', '1', '5.50', '17', '1', '1', '3', '0'],
#  ['Arshdeep Singh', '4', '0', '32', '3', '8.00', '10', '3', '1', '1', '0'],
#  ['Mohammed Shami', '4', '0', '25', '1', '6.25', '14', '4', '0', '1', '0'],
#  ['Hardik Pandya', '4', '0', '30', '3', '7.50', '10', '4', '0', '0', '0'],
#  ['Ravichandran Ashwin', '3', '0', '23', '0', '7.66', '5', '0', '1', '1', '0'],
#  ['Axar Patel', '1', '0', '21', '0', '21.00', '2', '0', '3', '0', '0'],
#  ['Fred Klaassen', '4', '0', '33', '1', '8.25', '10', '5', '0', '3', '0'],
#  ['Colin Ackermann', '1', '0', '4', '0', '4.00', '2', '0', '0', '0', '0'],
#  ['Paul van Meekeren', '4', '0', '21', '2', '5.25', '10', '1', '0', '0', '0'],
#  ['Bas de Leede', '3', '0', '29', '2', '9.66', '9', '3', '1', '3', '0'],
#  ['Tim Pringle', '2', '0', '10', '1', '5.00', '4', '0', '0', '0', '0'],
#  ['Shariz Ahmad', '3', '0', '27', '1', '9.00', '5', '1', '2', '0', '0'],
#  ['Logan van Beek', '3', '0', '12', '1', '4.00', '7', '0', '0', '1', '0'],
#  ['Fred Klaassen', '4', '0', '33', '1', '8.25', '10', '5', '0', '3', '0'],
#  ['Colin Ackermann', '1', '0', '4', '0', '4.00', '2', '0', '0', '0', '0'],
#  ['Paul van Meekeren', '4', '0', '21', '2', '5.25', '10', '1', '0', '0', '0'],
#  ['Bas de Leede', '3', '0', '29', '2', '9.66', '9', '3', '1', '3', '0'],
#  ['Tim Pringle', '2', '0', '10', '1', '5.00', '4', '0', '0', '0', '0'],
#  ['Shariz Ahmad', '3', '0', '27', '1', '9.00', '5', '1', '2', '0', '0'],
#  ['Logan van Beek', '3', '0', '12', '1', '4.00', '7', '0', '0', '1', '0'],
#  ['Kagiso Rabada', '2', '0', '20', '0', '10.00', '4', '2', '1', '0', '0'],
#  ['Wayne Parnell', '2', '0', '6', '1', '3.00', '9', '1', '0', '0', '0'],
#  ['Lungi Ngidi', '2', '0', '20', '2', '10.00', '6', '2', '1', '2', '0'],
#  ['Keshav Maharaj', '1', '0', '10', '0', '10.00', '1', '1', '0', '0', '0'],
#  ['Anrich Nortje', '2', '0', '10', '1', '5.00', '5', '0', '0', '0', '0'],
#  ['Kagiso Rabada', '2', '0', '20', '0', '10.00', '4', '2', '1', '0', '0'],
#  ['Wayne Parnell', '2', '0', '6', '1', '3.00', '9', '1', '0', '0', '0'],
#  ['Lungi Ngidi', '2', '0', '20', '2', '10.00', '6', '2', '1', '2', '0'],
#  ['Keshav Maharaj', '1', '0', '10', '0', '10.00', '1', '1', '0', '0', '0'],
#  ['Anrich Nortje', '2', '0', '10', '1', '5.00', '5', '0', '0', '0', '0'],
#  ['Josh Hazlewood', '4', '0', '26', '1', '6.50', '13', '3', '0', '3', '0'],
#  ['Pat Cummins', '4', '0', '36', '1', '9.00', '12', '5', '1', '2', '0'],
#  ['Mitchell Starc', '4', '0', '23', '1', '5.75', '13', '1', '0', '1', '0'],
#  ['Ashton Agar', '4', '0', '25', '1', '6.25', '8', '1', '0', '1', '0'],
#  ['Marcus Stoinis', '2', '0', '17', '0', '8.50', '1', '1', '0', '1', '0'],
#  ['Mitchell Marsh', '1', '0', '14', '0', '14.00', '1', '1', '1', '0', '0'],
#  ['Glenn Maxwell', '1', '0', '5', '1', '5.00', '2', '0', '0', '0', '0'],
#  ['Josh Hazlewood', '4', '0', '26', '1', '6.50', '13', '3', '0', '3', '0'],
#  ['Pat Cummins', '4', '0', '36', '1', '9.00', '12', '5', '1', '2', '0'],
#  ['Mitchell Starc', '4', '0', '23', '1', '5.75', '13', '1', '0', '1', '0'],
#  ['Ashton Agar', '4', '0', '25', '1', '6.25', '8', '1', '0', '1', '0'],
#  ['Marcus Stoinis', '2', '0', '17', '0', '8.50', '1', '1', '0', '1', '0'],
#  ['Mitchell Marsh', '1', '0', '14', '0', '14.00', '1', '1', '1', '0', '0'],
#  ['Glenn Maxwell', '1', '0', '5', '1', '5.00', '2', '0', '0', '0', '0'],
#  ['Ben Stokes', '2.2', '0', '8', '1', '3.42', '7', '0', '0', '0', '0'],
#  ['Chris Woakes', '3', '0', '41', '0', '13.66', '4', '6', '1', '2', '0'],
#  ['Mark Wood', '4', '0', '34', '3', '8.50', '13', '4', '1', '2', '0'],
#  ['Sam Curran', '3', '0', '31', '2', '10.33', '7', '1', '2', '0', '0'],
#  ['Adil Rashid', '4', '0', '24', '0', '6.00', '6', '1', '0', '0', '0'],
#  ['Liam Livingstone', '3', '0', '17', '3', '5.66', '5', '1', '0', '0', '0'],
#  ['Ben Stokes', '2.2', '0', '8', '1', '3.42', '7', '0', '0', '0', '0'],
#  ['Chris Woakes', '3', '0', '41', '0', '13.66', '4', '6', '1', '2', '0'],
#  ['Mark Wood', '4', '0', '34', '3', '8.50', '13', '4', '1', '2', '0'],
#  ['Sam Curran', '3', '0', '31', '2', '10.33', '7', '1', '2', '0', '0'],
#  ['Adil Rashid', '4', '0', '24', '0', '6.00', '6', '1', '0', '0', '0'],
#  ['Liam Livingstone', '3', '0', '17', '3', '5.66', '5', '1', '0', '0', '0'],
#  ['Taskin Ahmed', '3', '0', '46', '1', '15.33', '7', '6', '2', '0', '3'],
#  ['Mehidy Hasan Miraz', '3', '0', '32', '0', '10.66', '4', '2', '2', '0', '0'],
#  ['Hasan Mahmud', '4', '0', '36', '1', '9.00', '11', '3', '2', '2', '0'],
#  ['Mustafizur Rahman', '4', '0', '25', '0', '6.25', '7', '1', '1', '0', '0'],
#  ['Mosaddek Hossain', '2', '0', '16', '0', '8.00', '5', '1', '1', '0', '0'],
#  ['Shakib Al Hasan', '3', '0', '33', '2', '11.00', '7', '1', '3', '0', '1'],
#  ['Afif Hossain', '1', '0', '11', '1', '11.00', '1', '2', '0', '0', '0'],
#  ['Taskin Ahmed', '3', '0', '46', '1', '15.33', '7', '6', '2', '0', '3'],
#  ['Mehidy Hasan Miraz', '3', '0', '32', '0', '10.66', '4', '2', '2', '0', '0'],
#  ['Hasan Mahmud', '4', '0', '36', '1', '9.00', '11', '3', '2', '2', '0'],
#  ['Mustafizur Rahman', '4', '0', '25', '0', '6.25', '7', '1', '1', '0', '0'],
#  ['Mosaddek Hossain', '2', '0', '16', '0', '8.00', '5', '1', '1', '0', '0'],
#  ['Shakib Al Hasan', '3', '0', '33', '2', '11.00', '7', '1', '3', '0', '1'],
#  ['Afif Hossain', '1', '0', '11', '1', '11.00', '1', '2', '0', '0', '0'],
#  ['Fred Klaassen', '4', '0', '33', '1', '8.25', '9', '2', '1', '2', '0'],
#  ['Tim Pringle', '4', '0', '30', '0', '7.50', '6', '3', '0', '0', '0'],
#  ['Paul van Meekeren', '4', '0', '32', '1', '8.00', '9', '3', '1', '0', '0'],
#  ['Bas de Leede', '3', '0', '33', '0', '11.00', '6', '5', '1', '1', '0'],
#  ['Logan van Beek', '4', '0', '45', '0', '11.25', '3', '2', '3', '0', '0'],
#  ['Shariz Ahmad', '1', '0', '5', '0', '5.00', '2', '0', '0', '0', '0'],
#  ['Fred Klaassen', '4', '0', '33', '1', '8.25', '9', '2', '1', '2', '0'],
#  ['Tim Pringle', '4', '0', '30', '0', '7.50', '6', '3', '0', '0', '0'],
#  ['Paul van Meekeren', '4', '0', '32', '1', '8.00', '9', '3', '1', '0', '0'],
#  ['Bas de Leede', '3', '0', '33', '0', '11.00', '6', '5', '1', '1', '0'],
#  ['Logan van Beek', '4', '0', '45', '0', '11.25', '3', '2', '3', '0', '0'],
#  ['Shariz Ahmad', '1', '0', '5', '0', '5.00', '2', '0', '0', '0', '0'],
#  ['Shaheen Shah Afridi', '4', '0', '29', '0', '7.25', '9', '3', '0', '0', '0'],
#  ['Naseem Shah', '4', '0', '34', '0', '8.50', '7', '4', '0', '2', '0'],
#  ['Mohammad Wasim', '4', '0', '24', '4', '6.00', '16', '2', '1', '4', '0'],
#  ['Haris Rauf', '4', '1', '12', '1', '3.00', '15', '0', '0', '0', '0'],
#  ['Shadab Khan', '4', '0', '23', '3', '5.75', '8', '1', '0', '0', '0'],
#  ['Shaheen Shah Afridi', '4', '0', '29', '0', '7.25', '9', '3', '0', '0', '0'],
#  ['Naseem Shah', '4', '0', '34', '0', '8.50', '7', '4', '0', '2', '0'],
#  ['Mohammad Wasim', '4', '0', '24', '4', '6.00', '16', '2', '1', '4', '0'],
#  ['Haris Rauf', '4', '1', '12', '1', '3.00', '15', '0', '0', '0', '0'],
#  ['Shadab Khan', '4', '0', '23', '3', '5.75', '8', '1', '0', '0', '0'],
#  ['Maheesh Theekshana', '4', '0', '35', '1', '8.75', '7', '2', '2', '1', '0'],
#  ['Kasun Rajitha', '4', '0', '23', '2', '5.75', '16', '3', '0', '1', '2'],
#  ['Dhananjaya de Silva', '2', '0', '14', '1', '7.00', '4', '1', '0', '0', '0'],
#  ['Wanindu Hasaranga de Silva',
#   '4',
#   '0',
#   '22',
#   '1',
#   '5.50',
#   '9',
#   '1',
#   '0',
#   '0',
#   '0'],
#  ['Lahiru Kumara', '3', '0', '37', '1', '12.33', '2', '2', '2', '2', '1'],
#  ['Chamika Karunaratne',
#   '3',
#   '0',
#   '34',
#   '0',
#   '11.33',
#   '5',
#   '3',
#   '1',
#   '1',
#   '0'],
#  ['Maheesh Theekshana', '4', '0', '35', '1', '8.75', '7', '2', '2', '1', '0'],
#  ['Kasun Rajitha', '4', '0', '23', '2', '5.75', '16', '3', '0', '1', '2'],
#  ['Dhananjaya de Silva', '2', '0', '14', '1', '7.00', '4', '1', '0', '0', '0'],
#  ['Wanindu Hasaranga de Silva',
#   '4',
#   '0',
#   '22',
#   '1',
#   '5.50',
#   '9',
#   '1',
#   '0',
#   '0',
#   '0'],
#  ['Lahiru Kumara', '3', '0', '37', '1', '12.33', '2', '2', '2', '2', '1'],
#  ['Chamika Karunaratne',
#   '3',
#   '0',
#   '34',
#   '0',
#   '11.33',
#   '5',
#   '3',
#   '1',
#   '1',
#   '0'],
#  ['Richard Ngarava', '4', '0', '24', '2', '6.00', '11', '2', '0', '2', '0'],
#  ['Blessing Muzarabani', '2', '0', '13', '2', '6.50', '8', '3', '0', '0', '0'],
#  ['Tendai Chatara', '3', '0', '18', '0', '6.00', '7', '1', '0', '0', '0'],
#  ['Sikandar Raza', '4', '0', '35', '1', '8.75', '2', '2', '1', '0', '0'],
#  ['Brad Evans', '3', '0', '32', '0', '10.66', '2', '3', '1', '1', '0'],
#  ['Wessly Madhevere', '2', '0', '18', '0', '9.00', '0', '1', '0', '0', '0'],
#  ['Sean Williams', '2', '0', '10', '1', '5.00', '4', '0', '0', '1', '0'],
#  ['Richard Ngarava', '4', '0', '24', '2', '6.00', '11', '2', '0', '2', '0'],
#  ['Blessing Muzarabani', '2', '0', '13', '2', '6.50', '8', '3', '0', '0', '0'],
#  ['Tendai Chatara', '3', '0', '18', '0', '6.00', '7', '1', '0', '0', '0'],
#  ['Sikandar Raza', '4', '0', '35', '1', '8.75', '2', '2', '1', '0', '0'],
#  ['Brad Evans', '3', '0', '32', '0', '10.66', '2', '3', '1', '1', '0'],
#  ['Wessly Madhevere', '2', '0', '18', '0', '9.00', '0', '1', '0', '0', '0'],
#  ['Sean Williams', '2', '0', '10', '1', '5.00', '4', '0', '0', '1', '0'],
#  ['Shaheen Shah Afridi',
#   '4',
#   '0',
#   '19',
#   '1',
#   '4.75',
#   '13',
#   '1',
#   '0',
#   '1',
#   '0'],
#  ['Naseem Shah', '4', '0', '11', '1', '2.75', '15', '0', '0', '0', '0'],
#  ['Mohammad Wasim', '3', '0', '15', '2', '5.00', '10', '1', '0', '1', '0'],
#  ['Haris Rauf', '3', '0', '10', '1', '3.33', '11', '1', '0', '0', '0'],
#  ['Shadab Khan', '4', '0', '22', '3', '5.50', '11', '2', '0', '0', '0'],
#  ['Mohammad Nawaz', '2', '0', '11', '0', '5.50', '3', '0', '0', '0', '0'],
#  ['Shaheen Shah Afridi',
#   '4',
#   '0',
#   '19',
#   '1',
#   '4.75',
#   '13',
#   '1',
#   '0',
#   '1',
#   '0'],
#  ['Naseem Shah', '4', '0', '11', '1', '2.75', '15', '0', '0', '0', '0'],
#  ['Mohammad Wasim', '3', '0', '15', '2', '5.00', '10', '1', '0', '1', '0'],
#  ['Haris Rauf', '3', '0', '10', '1', '3.33', '11', '1', '0', '0', '0'],
#  ['Shadab Khan', '4', '0', '22', '3', '5.50', '11', '2', '0', '0', '0'],
#  ['Mohammad Nawaz', '2', '0', '11', '0', '5.50', '3', '0', '0', '0', '0'],
#  ['Wayne Parnell', '4', '1', '15', '3', '3.75', '16', '0', '1', '0', '0'],
#  ['Kagiso Rabada', '4', '0', '26', '0', '6.50', '13', '2', '1', '1', '0'],
#  ['Lungi Ngidi', '4', '0', '29', '4', '7.25', '10', '3', '1', '0', '0'],
#  ['Anrich Nortje', '4', '0', '23', '1', '5.75', '12', '1', '1', '0', '0'],
#  ['Keshav Maharaj', '3', '0', '28', '0', '9.33', '5', '3', '1', '0', '0'],
#  ['Aiden Markram', '1', '0', '5', '0', '5.00', '1', '0', '0', '0', '0'],
#  ['Wayne Parnell', '4', '1', '15', '3', '3.75', '16', '0', '1', '0', '0'],
#  ['Kagiso Rabada', '4', '0', '26', '0', '6.50', '13', '2', '1', '1', '0'],
#  ['Lungi Ngidi', '4', '0', '29', '4', '7.25', '10', '3', '1', '0', '0'],
#  ['Anrich Nortje', '4', '0', '23', '1', '5.75', '12', '1', '1', '0', '0'],
#  ['Keshav Maharaj', '3', '0', '28', '0', '9.33', '5', '3', '1', '0', '0'],
#  ['Aiden Markram', '1', '0', '5', '0', '5.00', '1', '0', '0', '0', '0'],
#  ['Josh Little', '4', '0', '21', '2', '5.25', '13', '2', '0', '2', '0'],
#  ['Mark Adair', '4', '0', '59', '0', '14.75', '6', '7', '2', '6', '0'],
#  ['Barry McCarthy', '4', '0', '29', '3', '7.25', '7', '2', '0', '1', '0'],
#  ['Gareth Delany', '3', '0', '29', '0', '9.66', '10', '2', '2', '2', '0'],
#  ['Fionn Hand', '1', '0', '15', '0', '15.00', '2', '0', '2', '1', '0'],
#  ['George Dockrell', '4', '0', '24', '0', '6.00', '8', '0', '1', '0', '0'],
#  ['Josh Little', '4', '0', '21', '2', '5.25', '13', '2', '0', '2', '0'],
#  ['Mark Adair', '4', '0', '59', '0', '14.75', '6', '7', '2', '6', '0'],
#  ['Barry McCarthy', '4', '0', '29', '3', '7.25', '7', '2', '0', '1', '0'],
#  ['Gareth Delany', '3', '0', '29', '0', '9.66', '10', '2', '2', '2', '0'],
#  ['Fionn Hand', '1', '0', '15', '0', '15.00', '2', '0', '2', '1', '0'],
#  ['George Dockrell', '4', '0', '24', '0', '6.00', '8', '0', '1', '0', '0'],
#  ['Kasun Rajitha', '4', '0', '31', '1', '7.75', '11', '2', '1', '1', '1'],
#  ['Pramod Madushan', '3', '0', '24', '0', '8.00', '7', '2', '1', '0', '0'],
#  ['Lahiru Kumara', '4', '0', '30', '2', '7.50', '12', '2', '1', '4', '0'],
#  ['Maheesh Theekshana', '4', '0', '33', '0', '8.25', '5', '1', '1', '1', '0'],
#  ['Wanindu Hasaranga de Silva',
#   '4',
#   '0',
#   '13',
#   '3',
#   '3.25',
#   '12',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['Dhananjaya de Silva', '1', '0', '9', '1', '9.00', '1', '1', '0', '0', '0'],
#  ['Kasun Rajitha', '4', '0', '31', '1', '7.75', '11', '2', '1', '1', '1'],
#  ['Pramod Madushan', '3', '0', '24', '0', '8.00', '7', '2', '1', '0', '0'],
#  ['Lahiru Kumara', '4', '0', '30', '2', '7.50', '12', '2', '1', '4', '0'],
#  ['Maheesh Theekshana', '4', '0', '33', '0', '8.25', '5', '1', '1', '1', '0'],
#  ['Wanindu Hasaranga de Silva',
#   '4',
#   '0',
#   '13',
#   '3',
#   '3.25',
#   '12',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['Dhananjaya de Silva', '1', '0', '9', '1', '9.00', '1', '1', '0', '0', '0'],
#  ['Trent Boult', '4', '0', '40', '0', '10.00', '8', '4', '1', '1', '0'],
#  ['Tim Southee', '4', '0', '43', '1', '10.75', '9', '3', '3', '0', '0'],
#  ['Mitchell Santner', '4', '0', '25', '1', '6.25', '8', '2', '0', '0', '0'],
#  ['Lockie Ferguson', '4', '0', '45', '2', '11.25', '6', '4', '2', '0', '1'],
#  ['Ish Sodhi', '4', '0', '23', '1', '5.75', '10', '2', '0', '0', '0'],
#  ['Trent Boult', '4', '0', '40', '0', '10.00', '8', '4', '1', '1', '0'],
#  ['Tim Southee', '4', '0', '43', '1', '10.75', '9', '3', '3', '0', '0'],
#  ['Mitchell Santner', '4', '0', '25', '1', '6.25', '8', '2', '0', '0', '0'],
#  ['Lockie Ferguson', '4', '0', '45', '2', '11.25', '6', '4', '2', '0', '1'],
#  ['Ish Sodhi', '4', '0', '23', '1', '5.75', '10', '2', '0', '0', '0'],
#  ['Fred Klaassen', '4', '0', '17', '1', '4.25', '17', '0', '1', '2', '0'],
#  ['Paul van Meekeren', '4', '0', '29', '3', '7.25', '13', '3', '0', '2', '0'],
#  ['Brandon Glover', '4', '1', '29', '2', '7.25', '15', '2', '2', '2', '0'],
#  ['Logan van Beek', '2.2', '0', '17', '2', '7.28', '8', '1', '1', '1', '0'],
#  ['Bas de Leede', '4', '0', '14', '2', '3.50', '11', '0', '0', '0', '0'],
#  ['Roelof van der Merwe', '1', '0', '8', '0', '8.00', '2', '1', '0', '0', '0'],
#  ['Fred Klaassen', '4', '0', '17', '1', '4.25', '17', '0', '1', '2', '0'],
#  ['Paul van Meekeren', '4', '0', '29', '3', '7.25', '13', '3', '0', '2', '0'],
#  ['Brandon Glover', '4', '1', '29', '2', '7.25', '15', '2', '2', '2', '0'],
#  ['Logan van Beek', '2.2', '0', '17', '2', '7.28', '8', '1', '1', '1', '0'],
#  ['Bas de Leede', '4', '0', '14', '2', '3.50', '11', '0', '0', '0', '0'],
#  ['Roelof van der Merwe', '1', '0', '8', '0', '8.00', '2', '1', '0', '0', '0'],
#  ['Taskin Ahmed', '4', '0', '15', '0', '3.75', '16', '2', '0', '0', '0'],
#  ['Shoriful Islam', '4', '0', '57', '0', '14.25', '7', '4', '4', '2', '2'],
#  ['Hasan Mahmud', '4', '0', '47', '3', '11.75', '7', '6', '2', '0', '1'],
#  ['Mustafizur Rahman', '4', '0', '31', '0', '7.75', '9', '4', '0', '0', '0'],
#  ['Shakib Al Hasan', '4', '0', '33', '2', '8.25', '3', '2', '0', '0', '0'],
#  ['Taskin Ahmed', '4', '0', '15', '0', '3.75', '16', '2', '0', '0', '0'],
#  ['Shoriful Islam', '4', '0', '57', '0', '14.25', '7', '4', '4', '2', '2'],
#  ['Hasan Mahmud', '4', '0', '47', '3', '11.75', '7', '6', '2', '0', '1'],
#  ['Mustafizur Rahman', '4', '0', '31', '0', '7.75', '9', '4', '0', '0', '0'],
#  ['Shakib Al Hasan', '4', '0', '33', '2', '8.25', '3', '2', '0', '0', '0'],
#  ['Wayne Parnell', '4', '0', '31', '1', '7.75', '10', '3', '1', '0', '0'],
#  ['Kagiso Rabada', '4', '0', '44', '1', '11.00', '7', '4', '2', '0', '0'],
#  ['Lungi Ngidi', '4', '0', '32', '1', '8.00', '11', '3', '1', '2', '0'],
#  ['Anrich Nortje', '4', '0', '41', '4', '10.25', '11', '1', '4', '0', '1'],
#  ['Tabraiz Shamsi', '4', '0', '36', '1', '9.00', '8', '2', '2', '2', '0'],
#  ['Wayne Parnell', '4', '0', '31', '1', '7.75', '10', '3', '1', '0', '0'],
#  ['Kagiso Rabada', '4', '0', '44', '1', '11.00', '7', '4', '2', '0', '0'],
#  ['Lungi Ngidi', '4', '0', '32', '1', '8.00', '11', '3', '1', '2', '0'],
#  ['Anrich Nortje', '4', '0', '41', '4', '10.25', '11', '1', '4', '0', '1'],
#  ['Tabraiz Shamsi', '4', '0', '36', '1', '9.00', '8', '2', '2', '2', '0'],
#  ['Josh Little', '4', '0', '22', '3', '5.50', '10', '2', '0', '1', '0'],
#  ['Mark Adair', '4', '0', '39', '1', '9.75', '9', '3', '1', '3', '0'],
#  ['Barry McCarthy', '4', '0', '46', '0', '11.50', '4', '4', '2', '0', '0'],
#  ['Gareth Delany', '4', '0', '30', '2', '7.50', '11', '3', '1', '1', '0'],
#  ['Fionn Hand', '2', '0', '22', '0', '11.00', '2', '2', '1', '0', '0'],
#  ['George Dockrell', '2', '0', '18', '0', '9.00', '4', '2', '0', '2', '0'],
#  ['Josh Little', '4', '0', '22', '3', '5.50', '10', '2', '0', '1', '0'],
#  ['Mark Adair', '4', '0', '39', '1', '9.75', '9', '3', '1', '3', '0'],
#  ['Barry McCarthy', '4', '0', '46', '0', '11.50', '4', '4', '2', '0', '0'],
#  ['Gareth Delany', '4', '0', '30', '2', '7.50', '11', '3', '1', '1', '0'],
#  ['Fionn Hand', '2', '0', '22', '0', '11.00', '2', '2', '1', '0', '0'],
#  ['George Dockrell', '2', '0', '18', '0', '9.00', '4', '2', '0', '2', '0'],
#  ['Fazalhaq Farooqi', '4', '0', '29', '2', '7.25', '13', '4', '1', '0', '0'],
#  ['Mujeeb Ur Rahman', '4', '0', '42', '1', '10.50', '5', '4', '1', '1', '0'],
#  ['Naveen-ul-Haq', '4', '0', '21', '3', '5.25', '11', '2', '0', '0', '0'],
#  ['Gulbadin Naib', '3', '0', '31', '0', '10.33', '6', '3', '2', '0', '0'],
#  ['Rashid Khan', '4', '0', '29', '1', '7.25', '9', '2', '1', '1', '0'],
#  ['Mohammad Nabi', '1', '0', '14', '0', '14.00', '1', '1', '1', '0', '0'],
#  ['Fazalhaq Farooqi', '4', '0', '29', '2', '7.25', '13', '4', '1', '0', '0'],
#  ['Mujeeb Ur Rahman', '4', '0', '42', '1', '10.50', '5', '4', '1', '1', '0'],
#  ['Naveen-ul-Haq', '4', '0', '21', '3', '5.25', '11', '2', '0', '0', '0'],
#  ['Gulbadin Naib', '3', '0', '31', '0', '10.33', '6', '3', '2', '0', '0'],
#  ['Rashid Khan', '4', '0', '29', '1', '7.25', '9', '2', '1', '1', '0'],
#  ['Mohammad Nabi', '1', '0', '14', '0', '14.00', '1', '1', '1', '0', '0'],
#  ['Ben Stokes', '3', '0', '24', '1', '8.00', '8', '1', '2', '0', '0'],
#  ['Chris Woakes', '3', '0', '24', '1', '8.00', '5', '3', '0', '1', '0'],
#  ['Mark Wood', '3', '0', '26', '3', '8.66', '8', '1', '2', '1', '0'],
#  ['Sam Curran', '4', '0', '27', '1', '6.75', '10', '2', '1', '0', '0'],
#  ['Adil Rashid', '4', '0', '16', '1', '4.00', '11', '0', '0', '0', '0'],
#  ['Liam Livingstone', '2', '0', '16', '0', '8.00', '2', '0', '1', '0', '0'],
#  ['Moeen Ali', '1', '0', '5', '0', '5.00', '1', '0', '0', '0', '0'],
#  ['Ben Stokes', '3', '0', '24', '1', '8.00', '8', '1', '2', '0', '0'],
#  ['Chris Woakes', '3', '0', '24', '1', '8.00', '5', '3', '0', '1', '0'],
#  ['Mark Wood', '3', '0', '26', '3', '8.66', '8', '1', '2', '1', '0'],
#  ['Sam Curran', '4', '0', '27', '1', '6.75', '10', '2', '1', '0', '0'],
#  ['Adil Rashid', '4', '0', '16', '1', '4.00', '11', '0', '0', '0', '0'],
#  ['Liam Livingstone', '2', '0', '16', '0', '8.00', '2', '0', '1', '0', '0'],
#  ['Moeen Ali', '1', '0', '5', '0', '5.00', '1', '0', '0', '0', '0'],
#  ['Wayne Parnell', '4', '0', '32', '0', '8.00', '10', '2', '2', '1', '0'],
#  ['Kagiso Rabada', '3', '0', '37', '0', '12.33', '6', '7', '0', '0', '0'],
#  ['Lungi Ngidi', '3', '0', '35', '0', '11.66', '3', '5', '0', '0', '0'],
#  ['Anrich Nortje', '4', '0', '10', '1', '2.50', '14', '0', '0', '0', '0'],
#  ['Keshav Maharaj', '4', '0', '27', '2', '6.75', '12', '1', '2', '0', '0'],
#  ['Aiden Markram', '2', '0', '16', '1', '8.00', '3', '0', '1', '1', '0'],
#  ['Wayne Parnell', '4', '0', '32', '0', '8.00', '10', '2', '2', '1', '0'],
#  ['Kagiso Rabada', '3', '0', '37', '0', '12.33', '6', '7', '0', '0', '0'],
#  ['Lungi Ngidi', '3', '0', '35', '0', '11.66', '3', '5', '0', '0', '0'],
#  ['Anrich Nortje', '4', '0', '10', '1', '2.50', '14', '0', '0', '0', '0'],
#  ['Keshav Maharaj', '4', '0', '27', '2', '6.75', '12', '1', '2', '0', '0'],
#  ['Aiden Markram', '2', '0', '16', '1', '8.00', '3', '0', '1', '1', '0'],
#  ['Shaheen Shah Afridi',
#   '4',
#   '0',
#   '22',
#   '4',
#   '5.50',
#   '13',
#   '2',
#   '1',
#   '0',
#   '0'],
#  ['Naseem Shah', '3', '0', '15', '0', '5.00', '9', '2', '0', '0', '0'],
#  ['Mohammad Wasim', '2', '0', '19', '0', '9.50', '5', '1', '1', '1', '0'],
#  ['Haris Rauf', '4', '0', '21', '1', '5.25', '11', '2', '0', '0', '0'],
#  ['Shadab Khan', '4', '0', '30', '2', '7.50', '8', '3', '0', '0', '0'],
#  ['Iftikhar Ahmed', '3', '0', '15', '1', '5.00', '9', '2', '0', '0', '0'],
#  ['Shaheen Shah Afridi',
#   '4',
#   '0',
#   '22',
#   '4',
#   '5.50',
#   '13',
#   '2',
#   '1',
#   '0',
#   '0'],
#  ['Naseem Shah', '3', '0', '15', '0', '5.00', '9', '2', '0', '0', '0'],
#  ['Mohammad Wasim', '2', '0', '19', '0', '9.50', '5', '1', '1', '1', '0'],
#  ['Haris Rauf', '4', '0', '21', '1', '5.25', '11', '2', '0', '0', '0'],
#  ['Shadab Khan', '4', '0', '30', '2', '7.50', '8', '3', '0', '0', '0'],
#  ['Iftikhar Ahmed', '3', '0', '15', '1', '5.00', '9', '2', '0', '0', '0'],
#  ['Richard Ngarava', '4', '1', '44', '1', '11.00', '12', '2', '4', '1', '1'],
#  ['Tendai Chatara', '4', '0', '34', '0', '8.50', '5', '3', '1', '0', '0'],
#  ['Blessing Muzarabani',
#   '4',
#   '0',
#   '50',
#   '1',
#   '12.50',
#   '5',
#   '8',
#   '0',
#   '1',
#   '0'],
#  ['Wellington Masakadza',
#   '2',
#   '0',
#   '12',
#   '0',
#   '6.00',
#   '5',
#   '1',
#   '0',
#   '1',
#   '0'],
#  ['Ryan Burl', '1', '0', '14', '0', '14.00', '1', '1', '1', '0', '0'],
#  ['Sikandar Raza', '3', '0', '18', '1', '6.00', '5', '0', '1', '0', '0'],
#  ['Sean Williams', '2', '0', '9', '2', '4.50', '6', '0', '0', '2', '0'],
#  ['Richard Ngarava', '4', '1', '44', '1', '11.00', '12', '2', '4', '1', '1'],
#  ['Tendai Chatara', '4', '0', '34', '0', '8.50', '5', '3', '1', '0', '0'],
#  ['Blessing Muzarabani',
#   '4',
#   '0',
#   '50',
#   '1',
#   '12.50',
#   '5',
#   '8',
#   '0',
#   '1',
#   '0'],
#  ['Wellington Masakadza',
#   '2',
#   '0',
#   '12',
#   '0',
#   '6.00',
#   '5',
#   '1',
#   '0',
#   '1',
#   '0'],
#  ['Ryan Burl', '1', '0', '14', '0', '14.00', '1', '1', '1', '0', '0'],
#  ['Sikandar Raza', '3', '0', '18', '1', '6.00', '5', '0', '1', '0', '0'],
#  ['Sean Williams', '2', '0', '9', '2', '4.50', '6', '0', '0', '2', '0'],
#  ['Shaheen Shah Afridi',
#   '4',
#   '0',
#   '24',
#   '2',
#   '6.00',
#   '11',
#   '2',
#   '0',
#   '0',
#   '0'],
#  ['Naseem Shah', '4', '0', '30', '0', '7.50', '8', '3', '0', '0', '0'],
#  ['Haris Rauf', '4', '0', '32', '0', '8.00', '6', '2', '0', '0', '0'],
#  ['Mohammad Wasim', '2', '0', '15', '0', '7.50', '3', '0', '1', '0', '0'],
#  ['Shadab Khan', '4', '0', '33', '0', '8.25', '7', '3', '1', '0', '0'],
#  ['Mohammad Nawaz', '2', '0', '12', '1', '6.00', '2', '0', '0', '0', '0'],
#  ['Shaheen Shah Afridi',
#   '4',
#   '0',
#   '24',
#   '2',
#   '6.00',
#   '11',
#   '2',
#   '0',
#   '0',
#   '0'],
#  ['Naseem Shah', '4', '0', '30', '0', '7.50', '8', '3', '0', '0', '0'],
#  ['Haris Rauf', '4', '0', '32', '0', '8.00', '6', '2', '0', '0', '0'],
#  ['Mohammad Wasim', '2', '0', '15', '0', '7.50', '3', '0', '1', '0', '0'],
#  ['Shadab Khan', '4', '0', '33', '0', '8.25', '7', '3', '1', '0', '0'],
#  ['Mohammad Nawaz', '2', '0', '12', '1', '6.00', '2', '0', '0', '0', '0'],
#  ['Ben Stokes', '2', '0', '18', '0', '9.00', '5', '2', '1', '0', '0'],
#  ['Chris Woakes', '3', '0', '24', '1', '8.00', '5', '1', '1', '2', '0'],
#  ['Sam Curran', '4', '0', '42', '0', '10.50', '9', '5', '2', '0', '0'],
#  ['Adil Rashid', '4', '0', '20', '1', '5.00', '8', '1', '0', '0', '0'],
#  ['Liam Livingstone', '3', '0', '21', '0', '7.00', '7', '3', '0', '0', '0'],
#  ['Chris Jordan', '4', '0', '43', '3', '10.75', '8', '3', '3', '1', '0'],
#  ['Ben Stokes', '2', '0', '18', '0', '9.00', '5', '2', '1', '0', '0'],
#  ['Chris Woakes', '3', '0', '24', '1', '8.00', '5', '1', '1', '2', '0'],
#  ['Sam Curran', '4', '0', '42', '0', '10.50', '9', '5', '2', '0', '0'],
#  ['Adil Rashid', '4', '0', '20', '1', '5.00', '8', '1', '0', '0', '0'],
#  ['Liam Livingstone', '3', '0', '21', '0', '7.00', '7', '3', '0', '0', '0'],
#  ['Chris Jordan', '4', '0', '43', '3', '10.75', '8', '3', '3', '1', '0'],
#  ['Ben Stokes', '4', '0', '32', '1', '8.00', '6', '1', '0', '2', '1'],
#  ['Chris Woakes', '3', '0', '26', '0', '8.66', '7', '2', '1', '2', '0'],
#  ['Sam Curran', '4', '0', '12', '3', '3.00', '15', '0', '0', '0', '0'],
#  ['Adil Rashid', '4', '1', '22', '2', '5.50', '10', '1', '0', '1', '0'],
#  ['Chris Jordan', '4', '0', '27', '2', '6.75', '9', '3', '0', '0', '0'],
#  ['Liam Livingstone', '1', '0', '16', '0', '16.00', '1', '1', '1', '1', '0'],
#  ['Ben Stokes', '4', '0', '32', '1', '8.00', '6', '1', '0', '2', '1'],
#  ['Chris Woakes', '3', '0', '26', '0', '8.66', '7', '2', '1', '2', '0'],
#  ['Sam Curran', '4', '0', '12', '3', '3.00', '15', '0', '0', '0', '0'],
#  ['Adil Rashid', '4', '1', '22', '2', '5.50', '10', '1', '0', '1', '0'],
#  ['Chris Jordan', '4', '0', '27', '2', '6.75', '9', '3', '0', '0', '0'],
#  ['Liam Livingstone', '1', '0', '16', '0', '16.00', '1', '1', '1', '1', '0']]

# %%
bowling_dataframe = pd.DataFrame(bowling_summary)

# %%
bowling_dataframe.head()
# Out:
#                        Bowler Overs Maidens Runs Wickets Economy Dot Balls  \
# 0          Maheesh Theekshana     4       0   23       1    5.75         7
# 1         Dushmantha Chameera     4       0   39       1    9.75         6
# 2             Pramod Madushan     4       0   37       2    9.25         6
# 3         Chamika Karunaratne     4       0   36       1    9.00         7
# 4  Wanindu Hasaranga de Silva     4       0   27       1    6.75         8
#
#   Fours Sixes Wide No Balls
# 0     0     0    2        0
# 1     3     1    2        0
# 2     3     1    0        0
# 3     3     1    1        0
# 4     1     1    0        0

# %%
bowling_dataframe.rename(columns={0:"Bowler",1:"Overs",2:"Maidens",3:"Runs",4:"Wickets",5:"Economy",6:"Dot Balls",7:"Fours",8:"Sixes",9:"Wide",10:"No Balls"},inplace=True)

# %%
bowling_dataframe.head(15)
# Out:
#                         Bowler Overs Maidens Runs Wickets Economy Dot Balls  \
# 0           Maheesh Theekshana     4       0   23       1    5.75         7
# 1          Dushmantha Chameera     4       0   39       1    9.75         6
# 2              Pramod Madushan     4       0   37       2    9.25         6
# 3          Chamika Karunaratne     4       0   36       1    9.00         7
# 4   Wanindu Hasaranga de Silva     4       0   27       1    6.75         8
# 5           Maheesh Theekshana     4       0   23       1    5.75         7
# 6          Dushmantha Chameera     4       0   39       1    9.75         6
# 7              Pramod Madushan     4       0   37       2    9.25         6
# 8          Chamika Karunaratne     4       0   36       1    9.00         7
# 9   Wanindu Hasaranga de Silva     4       0   27       1    6.75         8
# 10               Fred Klaassen     4       0   13       2    3.25        18
# 11                 Tim Pringle     4       0   13       1    3.25        11
# 12              Logan van Beek     2       0   19       0    9.50         5
# 13                Bas de Leede     3       0   19       3    6.33         9
# 14           Paul van Meekeren     4       0   21       0    5.25        11
#
#    Fours Sixes Wide No Balls
# 0      0     0    2        0
# 1      3     1    2        0
# 2      3     1    0        0
# 3      3     1    1        0
# 4      1     1    0        0
# 5      0     0    2        0
# 6      3     1    2        0
# 7      3     1    0        0
# 8      3     1    1        0
# 9      1     1    0        0
# 10     0     0    3        0
# 11     0     0    0        0
# 12     0     2    1        0
# 13     2     0    2        0
# 14     1     0    0        0

# %%
bowling_dataframe.to_csv("bowling_summary.csv")

# %%
player_details = []
number=0

# %%
for link in links:
    url_check = "https://stats.espncricinfo.com" + link
    response_link = requests.get(url_check)
    soup_check = BeautifulSoup(response_link.content,'html.parser')
    tables_link = soup_check.find_all('table',{'class':'ci-scorecard-table'})

    for table in tables_link:
        player_link = table.find_all("a")

        for i in player_link:
            player_link = "https://www.espncricinfo.com" + i.get("href") 
            print(player_link)
            
            player_detail_link = requests.get(player_link)
            soup_player = BeautifulSoup(player_detail_link.content,'html.parser')
            
            divs = soup_player.find_all("div")
            for div in divs:
                if len(div) > 1:
                    heading = div.find_all("p")
                    value = div.find_all("span")
                    
                    if len(heading)>1:
                        
                        if heading[0].text.strip() =="Full Name" and heading[1].text.strip() =="Born" and heading[2].text.strip() =="Age":
                            if len(value) >1:
                                name = value[0].text.strip()
                                born = value[1].text.strip()
                                age = value[2].text.strip()
                                batting = value[3].text.strip()
                                role = value[4].text.strip()
                                
                                player_details.append([name, born, age, batting, role])
                                print(name, born, age, batting, role)
            # number=number+1
            # print("Player: ",number)
# Out:
# https://www.espncricinfo.com/cricketers/michael-van-lingen-833777
# Overview Stats Records Matches News
# Michael van Lingen October 24, 1997 25y 151d Left hand Bat Left arm Medium
# Michael van Lingen October 24, 1997 25y 151d Left hand Bat Left arm Medium
# https://www.espncricinfo.com/cricketers/divan-la-cock-1178065
# Overview Stats Records Matches News
# Divan la Cock February 23, 2003 20y 29d Right hand Bat Legbreak
# Divan la Cock February 23, 2003 20y 29d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/jan-nicol-loftie-eaton-1071473
# Overview Stats Records Matches News
# Jan Nicol Loftie-Eaton March 15, 2001 22y 9d Left hand Bat Right arm Medium, Legbreak
# Jan Nicol Loftie-Eaton March 15, 2001 22y 9d Left hand Bat Right arm Medium, Legbreak
# https://www.espncricinfo.com/cricketers/stephan-baard-437927
# Overview Stats Records Matches Videos
# Stephan Julian Baard April 29, 1992, Namibia 30y 329d Right hand Bat Right arm Medium fast
# Stephan Julian Baard April 29, 1992, Namibia 30y 329d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/gerhard-erasmus-519070
# Overview Stats Records Matches Videos
# Merwe Gerhard Erasmus April 11, 1995, Windhoek, Namibia 27y 347d Right hand Bat Right arm Offbreak
# Merwe Gerhard Erasmus April 11, 1995, Windhoek, Namibia 27y 347d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/jan-frylinck-482478
# Overview Stats Records Matches News
# Jan Nicolaas Frylinck April 06, 1994, Bellville, Western Cape 28y 352d Left hand Bat Left arm Fast medium
# Jan Nicolaas Frylinck April 06, 1994, Bellville, Western Cape 28y 352d Left hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/david-wiese-221140
# Overview Stats Records Matches Videos
# David Wiese May 18, 1985, Roodepoort 37y 310d Right hand Bat Right arm Medium fast
# David Wiese May 18, 1985, Roodepoort 37y 310d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/jj-smit-553821
# Overview Stats Records Matches News
# Johannes Jonathan Smit November 10, 1995, keetmanshoop 27y 134d Right hand Bat Left arm Medium fast
# Johannes Jonathan Smit November 10, 1995, keetmanshoop 27y 134d Right hand Bat Left arm Medium fast
# https://www.espncricinfo.com/cricketers/zane-green-596664
# Overview Stats Records Matches News
# Zane Edward Green October 11, 1996, Namibia 26y 164d Left hand Bat Wicketkeeper
# Zane Edward Green October 11, 1996, Namibia 26y 164d Left hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/bernard-scholtz-330223
# Overview Stats Records Matches News
# Bernard Martinus Scholtz October 03, 1990, Keetmanshoop, Namibia 32y 172d Right hand Bat Slow Left arm Orthodox
# Bernard Martinus Scholtz October 03, 1990, Keetmanshoop, Namibia 32y 172d Right hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/ben-shikongo-1069820
# Overview Stats Records Matches News
# Ben Shikongo May 08, 2000 22y 320d Right hand Bat Right arm Medium fast
# Ben Shikongo May 08, 2000 22y 320d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/pathum-nissanka-1028655
# Overview Stats Records Matches Videos
# Pathum Nissanka Silva May 18, 1998, Galle 24y 310d Right hand Bat Top order Batter
# Pathum Nissanka Silva May 18, 1998, Galle 24y 310d Right hand Bat Top order Batter
# https://www.espncricinfo.com/cricketers/kusal-mendis-629074
# Overview Stats Records Matches Videos
# Balapuwaduge Kusal Gimhan Mendis February 02, 1995, Moratuwa 28y 50d Right hand Bat Legbreak
# Balapuwaduge Kusal Gimhan Mendis February 02, 1995, Moratuwa 28y 50d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/dhananjaya-de-silva-465793
# Overview Stats Records Matches Videos
# Dhananjaya Maduranga de Silva September 06, 1991, Colombo 31y 199d Right hand Bat Right arm Offbreak
# Dhananjaya Maduranga de Silva September 06, 1991, Colombo 31y 199d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/danushka-gunathilaka-345821
# Overview Stats Records Matches News
# Mashtayage Danushka Gunathilaka March 17, 1991, Panadura 32y 7d Dana Left hand Bat
# Mashtayage Danushka Gunathilaka March 17, 1991, Panadura 32y 7d Dana Left hand Bat
# https://www.espncricinfo.com/cricketers/bhanuka-rajapaksa-342619
# Overview Stats Records Matches Videos
# Pramod Bhanuka Bandara Rajapaksa October 24, 1991, Colombo 31y 151d Left hand Bat Right arm Medium
# Pramod Bhanuka Bandara Rajapaksa October 24, 1991, Colombo 31y 151d Left hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/dasun-shanaka-437316
# Overview Stats Records Matches Videos
# Madagamagamage Dasun Shanaka September 09, 1991, Negombo 31y 196d Right hand Bat Right arm Medium
# Madagamagamage Dasun Shanaka September 09, 1991, Negombo 31y 196d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/wanindu-hasaranga-de-silva-784379
# Overview Stats Records Matches Videos
# Pinnaduwage Wanindu Hasaranga de Silva July 29, 1997, Galle 25y 238d Right hand Bat Legbreak
# Pinnaduwage Wanindu Hasaranga de Silva July 29, 1997, Galle 25y 238d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/chamika-karunaratne-623695
# Overview Stats Records Matches Videos
# Chamika Karunaratne May 29, 1996, Colombo 26y 299d Right hand Bat Right arm Medium fast
# Chamika Karunaratne May 29, 1996, Colombo 26y 299d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/pramod-madushan-826689
# Overview Stats Records Matches Videos
# Pramod Madushan Liyanagamage December 14, 1993, Hambantota 29y 100d Right hand Bat Right arm Medium fast
# Pramod Madushan Liyanagamage December 14, 1993, Hambantota 29y 100d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/dushmantha-chameera-552152
# Overview Stats Records Matches Videos
# Pathira Vasan Dushmantha Chameera January 11, 1992, Ragama 31y 72d Right hand Bat Right arm Fast
# Pathira Vasan Dushmantha Chameera January 11, 1992, Ragama 31y 72d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/maheesh-theekshana-1138316
# Overview Stats Records Matches Videos
# Morawakage Maheesh Theekshana August 01, 2000, Colombo 22y 235d Right hand Bat Right arm Offbreak
# Morawakage Maheesh Theekshana August 01, 2000, Colombo 22y 235d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/chirag-suri-534734
# Overview Stats Records Matches News
# Chirag Suri February 18, 1995, New Delhi, India 28y 34d Right hand Bat Right arm Offbreak, Legbreak Googly
# Chirag Suri February 18, 1995, New Delhi, India 28y 34d Right hand Bat Right arm Offbreak, Legbreak Googly
# https://www.espncricinfo.com/cricketers/muhammad-waseem-1241277
# Overview Stats Records Matches News
# Muhammad Waseem February 12, 1994 29y 40d Right hand Bat Right arm Medium
# Muhammad Waseem February 12, 1994 29y 40d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/kashif-daud-229225
# Overview Stats Records Matches News
# Kashif Daud February 10, 1986, Sialkot, Punjab 37y 42d Right hand Bat Right arm Medium fast
# Kashif Daud February 10, 1986, Sialkot, Punjab 37y 42d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/vriitya-aravind-1178586
# Overview Stats Records Matches News
# Vriitya Aravind June 11, 2002, Chennai, India 20y 286d Right hand Bat Wicketkeeper
# Vriitya Aravind June 11, 2002, Chennai, India 20y 286d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/zawar-farid-1196500
# Overview Stats Matches News Photos
# Zawar Farid July 25, 1992, Sahiwal 30y 242d Right hand Bat Right arm Medium
# Zawar Farid July 25, 1992, Sahiwal 30y 242d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/basil-hameed-1209110
# Overview Stats Records Matches Photos
# Basil Hameed April 15, 1992, Panniyankara, Kozhikode, Kerala 30y 343d Right hand Bat Right arm Offbreak
# Basil Hameed April 15, 1992, Panniyankara, Kozhikode, Kerala 30y 343d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/chundangapoyil-rizwan-474760
# Overview Stats Records Matches Videos
# Chundangapoyil Puthiyapurayil Rizwan April 19, 1988, Tellicherry, Kerala 34y 339d Right hand Bat Legbreak Googly
# Chundangapoyil Puthiyapurayil Rizwan April 19, 1988, Tellicherry, Kerala 34y 339d Right hand Bat Legbreak Googly
# https://www.espncricinfo.com/cricketers/aayan-afzal-khan-1241265
# Overview Stats Records Matches News
# Aayan Afzal Khan November 15, 2005 17y 129d Right hand Bat Slow Left arm Orthodox
# Aayan Afzal Khan November 15, 2005 17y 129d Right hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/karthik-meiyappan-1058987
# Overview Stats Records Matches Videos
# Karthik Palaniapan Meiyappan October 08, 2000, Chennai, India 22y 167d Right hand Bat Legbreak
# Karthik Palaniapan Meiyappan October 08, 2000, Chennai, India 22y 167d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/junaid-siddique-1203754
# Overview Stats Records Matches Photos
# Muhammad Junaid Siddique December 06, 1992, Multan, Pakistan 30y 108d Right hand Bat Right arm Medium fast
# Muhammad Junaid Siddique December 06, 1992, Multan, Pakistan 30y 108d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/zahoor-khan-384525
# Overview Stats Records Matches News
# Zahoor Khan May 25, 1989, Faisalabad, Punjab 33y 303d Right hand Bat Right arm Medium fast
# Zahoor Khan May 25, 1989, Faisalabad, Punjab 33y 303d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/vikramjit-singh-1153767
# Overview Stats Records Matches News
# Vikramjit Singh January 09, 2003, Cheema Khurd, Punjab 20y 74d Left hand Bat Right arm Medium fast
# Vikramjit Singh January 09, 2003, Cheema Khurd, Punjab 20y 74d Left hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/max-o-dowd-643197
# Overview Stats Records Matches Videos
# Maxwell Patrick O'Dowd March 04, 1994, Auckland 29y 20d Right hand Bat Right arm Offbreak
# Maxwell Patrick O'Dowd March 04, 1994, Auckland 29y 20d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/bas-de-leede-1036191
# Overview Stats Records Matches Videos
# Bas de Leede November 15, 1999 23y 129d Right hand Bat Right arm Fast medium
# Bas de Leede November 15, 1999 23y 129d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/colin-ackermann-379774
# Overview Stats Matches News Photos
# Colin Niel Ackermann April 04, 1991, George, South Africa 31y 354d Ackers Right hand Bat
# Colin Niel Ackermann April 04, 1991, George, South Africa 31y 354d Ackers Right hand Bat
# https://www.espncricinfo.com/cricketers/tom-cooper-219885
# Overview Stats Records Matches Videos
# Tom Lexley William Cooper November 26, 1986, Wollongong, New South Wales 36y 118d Coops Right hand Bat
# Tom Lexley William Cooper November 26, 1986, Wollongong, New South Wales 36y 118d Coops Right hand Bat
# https://www.espncricinfo.com/cricketers/scott-edwards-1127317
# Overview Stats Records Matches Videos
# Scott Andrew Edwards August 23, 1996, Tonga 26y 213d Right hand Bat Wicketkeeper
# Scott Andrew Edwards August 23, 1996, Tonga 26y 213d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/roelof-van-der-merwe-47850
# Overview Stats Records Matches Videos
# Roelof Erasmus van der Merwe December 31, 1984, Johannesburg, Transvaal 38y 83d Roela, Bulldog Right hand Bat
# Roelof Erasmus van der Merwe December 31, 1984, Johannesburg, Transvaal 38y 83d Roela, Bulldog Right hand Bat
# https://www.espncricinfo.com/cricketers/tim-pringle-1193548
# Overview Stats Records Matches Videos
# Timothy James Gerard Pringle August 29, 2002, The Hague 20y 207d Right hand Bat Slow Left arm Orthodox
# Timothy James Gerard Pringle August 29, 2002, The Hague 20y 207d Right hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/logan-van-beek-440522
# Overview Stats Records Matches News
# Logan Verjus van Beek September 07, 1990, Christchurch, Canterbury 32y 198d Right hand Bat Right arm Medium fast
# Logan Verjus van Beek September 07, 1990, Christchurch, Canterbury 32y 198d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/fred-klaassen-1104703
# Overview Stats Records Matches News
# Frederick Jack Klaassen November 13, 1992, Haywards Heath, Sussex 30y 131d Right hand Bat Left arm Fast medium
# Frederick Jack Klaassen November 13, 1992, Haywards Heath, Sussex 30y 131d Right hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/paul-van-meekeren-348109
# Overview Stats Records Matches Videos
# Paul Adriaan van Meekeren January 15, 1993, Amsterdam, Netherlands 30y 68d Right hand Bat Right arm Fast medium
# Paul Adriaan van Meekeren January 15, 1993, Amsterdam, Netherlands 30y 68d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/george-munsey-671805
# Overview Stats Records Matches Videos
# Henry George Munsey February 21, 1993, Oxford 30y 31d Left hand Bat Right arm Medium fast
# Henry George Munsey February 21, 1993, Oxford 30y 31d Left hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/michael-jones-1093091
# Overview Stats Records Matches News
# Michael Alexander Jones January 05, 1998, Ormskirk, Lancashire 25y 78d Right hand Bat Right arm Offbreak
# Michael Alexander Jones January 05, 1998, Ormskirk, Lancashire 25y 78d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/matthew-cross-417268
# Overview Stats Records Matches News
# Matthew Henry Cross October 15, 1992, Aberdeen 30y 160d Right hand Bat Wicketkeeper
# Matthew Henry Cross October 15, 1992, Aberdeen 30y 160d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/richie-berrington-25490
# Overview Stats Records Matches Videos
# Richard Douglas Berrington April 03, 1987, Pretoria, South Africa 35y 355d Right hand Bat Right arm Medium fast
# Richard Douglas Berrington April 03, 1987, Pretoria, South Africa 35y 355d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/calum-macleod-232435
# Overview Stats Records Matches News
# Calum Scott MacLeod November 15, 1988, Glasgow, Lanarkshire 34y 129d Cloudy, Highlander, Scot Right hand Bat
# Calum Scott MacLeod November 15, 1988, Glasgow, Lanarkshire 34y 129d Cloudy, Highlander, Scot Right hand Bat
# https://www.espncricinfo.com/cricketers/michael-leask-414966
# Overview Stats Records Matches News
# Michael Alexander Leask October 29, 1990, Aberdeen 32y 146d Right hand Bat Right arm Offbreak
# Michael Alexander Leask October 29, 1990, Aberdeen 32y 146d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/chris-greaves-873199
# Overview Stats Records Matches News
# Christopher Nicholas Greaves October 12, 1990 32y 163d Right hand Bat Legbreak
# Christopher Nicholas Greaves October 12, 1990 32y 163d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/mark-watt-659081
# Overview Stats Records Matches News
# Mark Robert James Watt July 29, 1996, Eastern General Hospital, Edinburgh 26y 238d Left hand Bat Slow Left arm Orthodox
# Mark Robert James Watt July 29, 1996, Eastern General Hospital, Edinburgh 26y 238d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/josh-davey-407265
# Overview Stats Records Matches Videos
# Joshua Henry Davey August 03, 1990, Aberdeen 32y 233d Wavey Right hand Bat
# Joshua Henry Davey August 03, 1990, Aberdeen 32y 233d Wavey Right hand Bat
# https://www.espncricinfo.com/cricketers/safyaan-sharif-414970
# Overview Stats Records Matches Videos
# Safyaan Mohammed Sharif May 24, 1991, Huddersfield, Yorkshire 31y 304d Right hand Bat Right arm Medium fast
# Safyaan Mohammed Sharif May 24, 1991, Huddersfield, Yorkshire 31y 304d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/brad-wheal-807535
# Overview Stats Matches News Photos
# Bradley Thomas James Wheal August 28, 1996, Durban, KwaZulu-Natal 26y 208d Right hand Bat Right arm Fast medium
# Bradley Thomas James Wheal August 28, 1996, Durban, KwaZulu-Natal 26y 208d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/kyle-mayers-348056
# Overview Stats Records Matches Videos
# Kyle Rico Mayers September 08, 1992, Barbados 30y 197d Left hand Bat Right arm Medium
# Kyle Rico Mayers September 08, 1992, Barbados 30y 197d Left hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/evin-lewis-431901
# Overview Stats Records Matches Videos
# Evin Lewis December 27, 1991, Port of Spain, Trinidad 31y 87d Left hand Bat Opening Batter
# Evin Lewis December 27, 1991, Port of Spain, Trinidad 31y 87d Left hand Bat Opening Batter
# https://www.espncricinfo.com/cricketers/brandon-king-670035
# Overview Stats Matches Videos News
# Brandon Alexander King December 16, 1994, Kingston, Jamaica 28y 98d Right hand Bat Top order Batter
# Brandon Alexander King December 16, 1994, Kingston, Jamaica 28y 98d Right hand Bat Top order Batter
# https://www.espncricinfo.com/cricketers/nicholas-pooran-604302
# Overview Stats Records Matches Videos
# Nicholas Pooran October 02, 1995, Trinidad 27y 173d Left hand Bat Right arm Offbreak
# Nicholas Pooran October 02, 1995, Trinidad 27y 173d Left hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/shamarh-brooks-230555
# Overview Stats Records Matches Videos
# Shamarh Shaqad Joshua Brooks October 01, 1988, St. Michael, Barbados 34y 174d Right hand Bat Legbreak
# Shamarh Shaqad Joshua Brooks October 01, 1988, St. Michael, Barbados 34y 174d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/rovman-powell-820351
# Overview Stats Records Matches Videos
# Rovman Powell July 23, 1993, Jamaica 29y 244d Right hand Bat Right arm Medium fast
# Rovman Powell July 23, 1993, Jamaica 29y 244d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/jason-holder-391485
# Overview Stats Records Matches Videos
# Jason Omar Holder November 05, 1991, Barbados 31y 139d Right hand Bat Right arm Medium fast
# Jason Omar Holder November 05, 1991, Barbados 31y 139d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/akeal-hosein-530812
# Overview Stats Records Matches Videos
# Akeal Jerome Hosein April 25, 1993, Port-of-Spain 29y 333d Left hand Bat Slow Left arm Orthodox
# Akeal Jerome Hosein April 25, 1993, Port-of-Spain 29y 333d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/alzarri-joseph-670031
# Overview Stats Records Matches Videos
# Alzarri Shaheim Joseph November 20, 1996, Antigua 26y 124d Right hand Bat Right arm Fast
# Alzarri Shaheim Joseph November 20, 1996, Antigua 26y 124d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/odean-smith-820691
# Overview Stats Records Matches Videos
# Odean Fabian Smith November 01, 1996, St. Elizabeth, Jamaica 26y 143d Right hand Bat Right arm Fast medium
# Odean Fabian Smith November 01, 1996, St. Elizabeth, Jamaica 26y 143d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/obed-mccoy-906783
# Overview Stats Records Matches News
# Obed  Christopher McCoy January 04, 1997 26y 79d Left hand Bat Left arm Fast medium
# Obed  Christopher McCoy January 04, 1997 26y 79d Left hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/regis-chakabva-293831
# Overview Stats Records Matches Videos
# Regis Wiriranai Chakabva September 20, 1987, Harare 35y 185d Right hand Bat Right arm Offbreak
# Regis Wiriranai Chakabva September 20, 1987, Harare 35y 185d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/craig-ervine-55412
# Overview Stats Records Matches Videos
# Craig Richard Ervine August 19, 1985, Harare 37y 217d Left hand Bat Right arm Offbreak
# Craig Richard Ervine August 19, 1985, Harare 37y 217d Left hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/wessly-madhevere-938959
# Overview Stats Records Matches News
# Wessly Nyasha Madhevere September 04, 2000, Harare 22y 201d Right hand Bat Right arm Offbreak
# Wessly Nyasha Madhevere September 04, 2000, Harare 22y 201d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/sean-williams-55870
# Overview Stats Records Matches Videos
# Sean Colin Williams September 26, 1986, Bulawayo 36y 179d Left hand Bat Slow Left arm Orthodox
# Sean Colin Williams September 26, 1986, Bulawayo 36y 179d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/sikandar-raza-299572
# Overview Stats Records Matches Videos
# Sikandar Raza Butt April 24, 1986, Sialkot, Punjab, Pakistan 36y 334d Right hand Bat Right arm Offbreak
# Sikandar Raza Butt April 24, 1986, Sialkot, Punjab, Pakistan 36y 334d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/milton-shumba-951781
# Overview Stats Records Matches News
# Milton Shumba October 19, 2000, Chitungwiza 22y 156d Left hand Bat Slow Left arm Orthodox
# Milton Shumba October 19, 2000, Chitungwiza 22y 156d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/ryan-burl-495964
# Overview Stats Records Matches News
# Ryan Ponsonby Burl April 15, 1994, Marondera 28y 343d Left hand Bat Legbreak
# Ryan Ponsonby Burl April 15, 1994, Marondera 28y 343d Left hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/luke-jongwe-541224
# Overview Stats Records Matches Videos
# Luke Mafuwa Jongwe February 06, 1995, Harare 28y 46d Right hand Bat Right arm Fast medium
# Luke Mafuwa Jongwe February 06, 1995, Harare 28y 46d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/tendai-chatara-425639
# Overview Stats Records Matches Videos
# Tendai Larry Chatara February 28, 1991, Chimanimani 32y 24d Right hand Bat Right arm Fast medium
# Tendai Larry Chatara February 28, 1991, Chimanimani 32y 24d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/richard-ngarava-806241
# Overview Stats Records Matches News
# Richard Ngarava December 28, 1997, Harare 25y 86d Left hand Bat Left arm Fast medium
# Richard Ngarava December 28, 1997, Harare 25y 86d Left hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/blessing-muzarabani-827051
# Overview Stats Records Matches Videos
# Blessing Muzarabani October 02, 1996, Harare 26y 173d Right hand Bat Right arm Fast medium
# Blessing Muzarabani October 02, 1996, Harare 26y 173d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/paul-stirling-303427
# Overview Stats Records Matches Videos
# Paul Robert Stirling September 03, 1990, Belfast 32y 202d Right hand Bat Right arm Offbreak
# Paul Robert Stirling September 03, 1990, Belfast 32y 202d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/andy-balbirnie-303423
# Overview Stats Records Matches Videos
# Andrew Balbirnie December 28, 1990, Dublin, Ireland 32y 86d Right hand Bat Right arm Offbreak
# Andrew Balbirnie December 28, 1990, Dublin, Ireland 32y 86d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/lorcan-tucker-928057
# Overview Stats Records Matches Videos
# Lorcan John Tucker September 10, 1996, Dublin 26y 195d Right hand Bat Wicketkeeper
# Lorcan John Tucker September 10, 1996, Dublin 26y 195d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/harry-tector-961407
# Overview Stats Records Matches Videos
# Harry Tom Tector December 06, 1999, Dublin 23y 108d Right hand Bat Right arm Offbreak
# Harry Tom Tector December 06, 1999, Dublin 23y 108d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/curtis-campher-595921
# Overview Stats Records Matches News
# Curtis Campher April 20, 1999, Johannesburg 23y 338d Right hand Bat Right arm Medium fast
# Curtis Campher April 20, 1999, Johannesburg 23y 338d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/george-dockrell-348034
# Overview Stats Records Matches Videos
# George Henry Dockrell July 22, 1992, Dublin 30y 245d Right hand Bat Slow Left arm Orthodox
# George Henry Dockrell July 22, 1992, Dublin 30y 245d Right hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/gareth-delany-1099379
# Overview Stats Records Matches Videos
# Gareth James Delany April 28, 1997, Dublin 25y 330d Right hand Bat Legbreak Googly
# Gareth James Delany April 28, 1997, Dublin 25y 330d Right hand Bat Legbreak Googly
# https://www.espncricinfo.com/cricketers/mark-adair-526441
# Overview Stats Records Matches News
# Mark Richard Adair March 27, 1996, Holywood, Northern Ireland 26y 362d Right hand Bat Right arm Fast medium
# Mark Richard Adair March 27, 1996, Holywood, Northern Ireland 26y 362d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/simi-singh-1005257
# Overview Stats Records Matches Videos
# Simi Singh February 04, 1987, Bathlana, Punjab, India 36y 48d Right hand Bat Right arm Offbreak, Legbreak Googly
# Simi Singh February 04, 1987, Bathlana, Punjab, India 36y 48d Right hand Bat Right arm Offbreak, Legbreak Googly
# https://www.espncricinfo.com/cricketers/barry-mccarthy-348059
# Overview Stats Records Matches Videos
# Barry John McCarthy September 13, 1992 30y 192d Right hand Bat Right arm Fast medium
# Barry John McCarthy September 13, 1992 30y 192d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/josh-little-928067
# Overview Stats Records Matches News
# Joshua Brian Little November 01, 1999, Dublin 23y 143d Right hand Bat Left arm Fast medium
# Joshua Brian Little November 01, 1999, Dublin 23y 143d Right hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/michael-van-lingen-833777
# Overview Stats Records Matches News
# Michael van Lingen October 24, 1997 25y 151d Left hand Bat Left arm Medium
# Michael van Lingen October 24, 1997 25y 151d Left hand Bat Left arm Medium
# https://www.espncricinfo.com/cricketers/divan-la-cock-1178065
# Overview Stats Records Matches News
# Divan la Cock February 23, 2003 20y 29d Right hand Bat Legbreak
# Divan la Cock February 23, 2003 20y 29d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/stephan-baard-437927
# Overview Stats Records Matches Videos
# Stephan Julian Baard April 29, 1992, Namibia 30y 329d Right hand Bat Right arm Medium fast
# Stephan Julian Baard April 29, 1992, Namibia 30y 329d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/jan-nicol-loftie-eaton-1071473
# Overview Stats Records Matches News
# Jan Nicol Loftie-Eaton March 15, 2001 22y 9d Left hand Bat Right arm Medium, Legbreak
# Jan Nicol Loftie-Eaton March 15, 2001 22y 9d Left hand Bat Right arm Medium, Legbreak
# https://www.espncricinfo.com/cricketers/jan-frylinck-482478
# Overview Stats Records Matches News
# Jan Nicolaas Frylinck April 06, 1994, Bellville, Western Cape 28y 352d Left hand Bat Left arm Fast medium
# Jan Nicolaas Frylinck April 06, 1994, Bellville, Western Cape 28y 352d Left hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/gerhard-erasmus-519070
# Overview Stats Records Matches Videos
# Merwe Gerhard Erasmus April 11, 1995, Windhoek, Namibia 27y 347d Right hand Bat Right arm Offbreak
# Merwe Gerhard Erasmus April 11, 1995, Windhoek, Namibia 27y 347d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/david-wiese-221140
# Overview Stats Records Matches Videos
# David Wiese May 18, 1985, Roodepoort 37y 310d Right hand Bat Right arm Medium fast
# David Wiese May 18, 1985, Roodepoort 37y 310d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/jj-smit-553821
# Overview Stats Records Matches News
# Johannes Jonathan Smit November 10, 1995, keetmanshoop 27y 134d Right hand Bat Left arm Medium fast
# Johannes Jonathan Smit November 10, 1995, keetmanshoop 27y 134d Right hand Bat Left arm Medium fast
# https://www.espncricinfo.com/cricketers/zane-green-596664
# Overview Stats Records Matches News
# Zane Edward Green October 11, 1996, Namibia 26y 164d Left hand Bat Wicketkeeper
# Zane Edward Green October 11, 1996, Namibia 26y 164d Left hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/bernard-scholtz-330223
# Overview Stats Records Matches News
# Bernard Martinus Scholtz October 03, 1990, Keetmanshoop, Namibia 32y 172d Right hand Bat Slow Left arm Orthodox
# Bernard Martinus Scholtz October 03, 1990, Keetmanshoop, Namibia 32y 172d Right hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/ben-shikongo-1069820
# Overview Stats Records Matches News
# Ben Shikongo May 08, 2000 22y 320d Right hand Bat Right arm Medium fast
# Ben Shikongo May 08, 2000 22y 320d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/max-o-dowd-643197
# Overview Stats Records Matches Videos
# Maxwell Patrick O'Dowd March 04, 1994, Auckland 29y 20d Right hand Bat Right arm Offbreak
# Maxwell Patrick O'Dowd March 04, 1994, Auckland 29y 20d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/vikramjit-singh-1153767
# Overview Stats Records Matches News
# Vikramjit Singh January 09, 2003, Cheema Khurd, Punjab 20y 74d Left hand Bat Right arm Medium fast
# Vikramjit Singh January 09, 2003, Cheema Khurd, Punjab 20y 74d Left hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/bas-de-leede-1036191
# Overview Stats Records Matches Videos
# Bas de Leede November 15, 1999 23y 129d Right hand Bat Right arm Fast medium
# Bas de Leede November 15, 1999 23y 129d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/tom-cooper-219885
# Overview Stats Records Matches Videos
# Tom Lexley William Cooper November 26, 1986, Wollongong, New South Wales 36y 118d Coops Right hand Bat
# Tom Lexley William Cooper November 26, 1986, Wollongong, New South Wales 36y 118d Coops Right hand Bat
# https://www.espncricinfo.com/cricketers/colin-ackermann-379774
# Overview Stats Matches News Photos
# Colin Niel Ackermann April 04, 1991, George, South Africa 31y 354d Ackers Right hand Bat
# Colin Niel Ackermann April 04, 1991, George, South Africa 31y 354d Ackers Right hand Bat
# https://www.espncricinfo.com/cricketers/scott-edwards-1127317
# Overview Stats Records Matches Videos
# Scott Andrew Edwards August 23, 1996, Tonga 26y 213d Right hand Bat Wicketkeeper
# Scott Andrew Edwards August 23, 1996, Tonga 26y 213d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/tim-pringle-1193548
# Overview Stats Records Matches Videos
# Timothy James Gerard Pringle August 29, 2002, The Hague 20y 207d Right hand Bat Slow Left arm Orthodox
# Timothy James Gerard Pringle August 29, 2002, The Hague 20y 207d Right hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/roelof-van-der-merwe-47850
# Overview Stats Records Matches Videos
# Roelof Erasmus van der Merwe December 31, 1984, Johannesburg, Transvaal 38y 83d Roela, Bulldog Right hand Bat
# Roelof Erasmus van der Merwe December 31, 1984, Johannesburg, Transvaal 38y 83d Roela, Bulldog Right hand Bat
# https://www.espncricinfo.com/cricketers/timm-van-der-gugten-333782
# Overview Stats Records Matches News
# Timm van der Gugten February 25, 1991, Hornsby, Upper North Shore, Sydney 32y 27d Right hand Bat Right arm Fast medium
# Timm van der Gugten February 25, 1991, Hornsby, Upper North Shore, Sydney 32y 27d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/fred-klaassen-1104703
# Overview Stats Records Matches News
# Frederick Jack Klaassen November 13, 1992, Haywards Heath, Sussex 30y 131d Right hand Bat Left arm Fast medium
# Frederick Jack Klaassen November 13, 1992, Haywards Heath, Sussex 30y 131d Right hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/paul-van-meekeren-348109
# Overview Stats Records Matches Videos
# Paul Adriaan van Meekeren January 15, 1993, Amsterdam, Netherlands 30y 68d Right hand Bat Right arm Fast medium
# Paul Adriaan van Meekeren January 15, 1993, Amsterdam, Netherlands 30y 68d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/pathum-nissanka-1028655
# Overview Stats Records Matches Videos
# Pathum Nissanka Silva May 18, 1998, Galle 24y 310d Right hand Bat Top order Batter
# Pathum Nissanka Silva May 18, 1998, Galle 24y 310d Right hand Bat Top order Batter
# https://www.espncricinfo.com/cricketers/kusal-mendis-629074
# Overview Stats Records Matches Videos
# Balapuwaduge Kusal Gimhan Mendis February 02, 1995, Moratuwa 28y 50d Right hand Bat Legbreak
# Balapuwaduge Kusal Gimhan Mendis February 02, 1995, Moratuwa 28y 50d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/dhananjaya-de-silva-465793
# Overview Stats Records Matches Videos
# Dhananjaya Maduranga de Silva September 06, 1991, Colombo 31y 199d Right hand Bat Right arm Offbreak
# Dhananjaya Maduranga de Silva September 06, 1991, Colombo 31y 199d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/bhanuka-rajapaksa-342619
# Overview Stats Records Matches Videos
# Pramod Bhanuka Bandara Rajapaksa October 24, 1991, Colombo 31y 151d Left hand Bat Right arm Medium
# Pramod Bhanuka Bandara Rajapaksa October 24, 1991, Colombo 31y 151d Left hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/charith-asalanka-784367
# Overview Stats Records Matches News
# Kariyawasam Indipalage Charith Asalanka June 29, 1997, Elpitiya 25y 268d Left hand Bat Right arm Offbreak
# Kariyawasam Indipalage Charith Asalanka June 29, 1997, Elpitiya 25y 268d Left hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/dasun-shanaka-437316
# Overview Stats Records Matches Videos
# Madagamagamage Dasun Shanaka September 09, 1991, Negombo 31y 196d Right hand Bat Right arm Medium
# Madagamagamage Dasun Shanaka September 09, 1991, Negombo 31y 196d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/wanindu-hasaranga-de-silva-784379
# Overview Stats Records Matches Videos
# Pinnaduwage Wanindu Hasaranga de Silva July 29, 1997, Galle 25y 238d Right hand Bat Legbreak
# Pinnaduwage Wanindu Hasaranga de Silva July 29, 1997, Galle 25y 238d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/chamika-karunaratne-623695
# Overview Stats Records Matches Videos
# Chamika Karunaratne May 29, 1996, Colombo 26y 299d Right hand Bat Right arm Medium fast
# Chamika Karunaratne May 29, 1996, Colombo 26y 299d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/pramod-madushan-826689
# Overview Stats Records Matches Videos
# Pramod Madushan Liyanagamage December 14, 1993, Hambantota 29y 100d Right hand Bat Right arm Medium fast
# Pramod Madushan Liyanagamage December 14, 1993, Hambantota 29y 100d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/dushmantha-chameera-552152
# Overview Stats Records Matches Videos
# Pathira Vasan Dushmantha Chameera January 11, 1992, Ragama 31y 72d Right hand Bat Right arm Fast
# Pathira Vasan Dushmantha Chameera January 11, 1992, Ragama 31y 72d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/maheesh-theekshana-1138316
# Overview Stats Records Matches Videos
# Morawakage Maheesh Theekshana August 01, 2000, Colombo 22y 235d Right hand Bat Right arm Offbreak
# Morawakage Maheesh Theekshana August 01, 2000, Colombo 22y 235d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/muhammad-waseem-1241277
# Overview Stats Records Matches News
# Muhammad Waseem February 12, 1994 29y 40d Right hand Bat Right arm Medium
# Muhammad Waseem February 12, 1994 29y 40d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/chirag-suri-534734
# Overview Stats Records Matches News
# Chirag Suri February 18, 1995, New Delhi, India 28y 34d Right hand Bat Right arm Offbreak, Legbreak Googly
# Chirag Suri February 18, 1995, New Delhi, India 28y 34d Right hand Bat Right arm Offbreak, Legbreak Googly
# https://www.espncricinfo.com/cricketers/aryan-lakra-1058989
# Overview Stats Records Matches News
# Aryan Lakra December 13, 2001, Sonepat, Haryana 21y 101d Left hand Bat Slow Left arm Orthodox
# Aryan Lakra December 13, 2001, Sonepat, Haryana 21y 101d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/chundangapoyil-rizwan-474760
# Overview Stats Records Matches Videos
# Chundangapoyil Puthiyapurayil Rizwan April 19, 1988, Tellicherry, Kerala 34y 339d Right hand Bat Legbreak Googly
# Chundangapoyil Puthiyapurayil Rizwan April 19, 1988, Tellicherry, Kerala 34y 339d Right hand Bat Legbreak Googly
# https://www.espncricinfo.com/cricketers/vriitya-aravind-1178586
# Overview Stats Records Matches News
# Vriitya Aravind June 11, 2002, Chennai, India 20y 286d Right hand Bat Wicketkeeper
# Vriitya Aravind June 11, 2002, Chennai, India 20y 286d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/basil-hameed-1209110
# Overview Stats Records Matches Photos
# Basil Hameed April 15, 1992, Panniyankara, Kozhikode, Kerala 30y 343d Right hand Bat Right arm Offbreak
# Basil Hameed April 15, 1992, Panniyankara, Kozhikode, Kerala 30y 343d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/aayan-afzal-khan-1241265
# Overview Stats Records Matches News
# Aayan Afzal Khan November 15, 2005 17y 129d Right hand Bat Slow Left arm Orthodox
# Aayan Afzal Khan November 15, 2005 17y 129d Right hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/kashif-daud-229225
# Overview Stats Records Matches News
# Kashif Daud February 10, 1986, Sialkot, Punjab 37y 42d Right hand Bat Right arm Medium fast
# Kashif Daud February 10, 1986, Sialkot, Punjab 37y 42d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/karthik-meiyappan-1058987
# Overview Stats Records Matches Videos
# Karthik Palaniapan Meiyappan October 08, 2000, Chennai, India 22y 167d Right hand Bat Legbreak
# Karthik Palaniapan Meiyappan October 08, 2000, Chennai, India 22y 167d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/junaid-siddique-1203754
# Overview Stats Records Matches Photos
# Muhammad Junaid Siddique December 06, 1992, Multan, Pakistan 30y 108d Right hand Bat Right arm Medium fast
# Muhammad Junaid Siddique December 06, 1992, Multan, Pakistan 30y 108d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/zahoor-khan-384525
# Overview Stats Records Matches News
# Zahoor Khan May 25, 1989, Faisalabad, Punjab 33y 303d Right hand Bat Right arm Medium fast
# Zahoor Khan May 25, 1989, Faisalabad, Punjab 33y 303d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/george-munsey-671805
# Overview Stats Records Matches Videos
# Henry George Munsey February 21, 1993, Oxford 30y 31d Left hand Bat Right arm Medium fast
# Henry George Munsey February 21, 1993, Oxford 30y 31d Left hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/michael-jones-1093091
# Overview Stats Records Matches News
# Michael Alexander Jones January 05, 1998, Ormskirk, Lancashire 25y 78d Right hand Bat Right arm Offbreak
# Michael Alexander Jones January 05, 1998, Ormskirk, Lancashire 25y 78d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/matthew-cross-417268
# Overview Stats Records Matches News
# Matthew Henry Cross October 15, 1992, Aberdeen 30y 160d Right hand Bat Wicketkeeper
# Matthew Henry Cross October 15, 1992, Aberdeen 30y 160d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/richie-berrington-25490
# Overview Stats Records Matches Videos
# Richard Douglas Berrington April 03, 1987, Pretoria, South Africa 35y 355d Right hand Bat Right arm Medium fast
# Richard Douglas Berrington April 03, 1987, Pretoria, South Africa 35y 355d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/michael-leask-414966
# Overview Stats Records Matches News
# Michael Alexander Leask October 29, 1990, Aberdeen 32y 146d Right hand Bat Right arm Offbreak
# Michael Alexander Leask October 29, 1990, Aberdeen 32y 146d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/calum-macleod-232435
# Overview Stats Records Matches News
# Calum Scott MacLeod November 15, 1988, Glasgow, Lanarkshire 34y 129d Cloudy, Highlander, Scot Right hand Bat
# Calum Scott MacLeod November 15, 1988, Glasgow, Lanarkshire 34y 129d Cloudy, Highlander, Scot Right hand Bat
# https://www.espncricinfo.com/cricketers/chris-greaves-873199
# Overview Stats Records Matches News
# Christopher Nicholas Greaves October 12, 1990 32y 163d Right hand Bat Legbreak
# Christopher Nicholas Greaves October 12, 1990 32y 163d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/mark-watt-659081
# Overview Stats Records Matches News
# Mark Robert James Watt July 29, 1996, Eastern General Hospital, Edinburgh 26y 238d Left hand Bat Slow Left arm Orthodox
# Mark Robert James Watt July 29, 1996, Eastern General Hospital, Edinburgh 26y 238d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/josh-davey-407265
# Overview Stats Records Matches Videos
# Joshua Henry Davey August 03, 1990, Aberdeen 32y 233d Wavey Right hand Bat
# Joshua Henry Davey August 03, 1990, Aberdeen 32y 233d Wavey Right hand Bat
# https://www.espncricinfo.com/cricketers/safyaan-sharif-414970
# Overview Stats Records Matches Videos
# Safyaan Mohammed Sharif May 24, 1991, Huddersfield, Yorkshire 31y 304d Right hand Bat Right arm Medium fast
# Safyaan Mohammed Sharif May 24, 1991, Huddersfield, Yorkshire 31y 304d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/brad-wheal-807535
# Overview Stats Matches News Photos
# Bradley Thomas James Wheal August 28, 1996, Durban, KwaZulu-Natal 26y 208d Right hand Bat Right arm Fast medium
# Bradley Thomas James Wheal August 28, 1996, Durban, KwaZulu-Natal 26y 208d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/paul-stirling-303427
# Overview Stats Records Matches Videos
# Paul Robert Stirling September 03, 1990, Belfast 32y 202d Right hand Bat Right arm Offbreak
# Paul Robert Stirling September 03, 1990, Belfast 32y 202d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/andy-balbirnie-303423
# Overview Stats Records Matches Videos
# Andrew Balbirnie December 28, 1990, Dublin, Ireland 32y 86d Right hand Bat Right arm Offbreak
# Andrew Balbirnie December 28, 1990, Dublin, Ireland 32y 86d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/lorcan-tucker-928057
# Overview Stats Records Matches Videos
# Lorcan John Tucker September 10, 1996, Dublin 26y 195d Right hand Bat Wicketkeeper
# Lorcan John Tucker September 10, 1996, Dublin 26y 195d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/harry-tector-961407
# Overview Stats Records Matches Videos
# Harry Tom Tector December 06, 1999, Dublin 23y 108d Right hand Bat Right arm Offbreak
# Harry Tom Tector December 06, 1999, Dublin 23y 108d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/curtis-campher-595921
# Overview Stats Records Matches News
# Curtis Campher April 20, 1999, Johannesburg 23y 338d Right hand Bat Right arm Medium fast
# Curtis Campher April 20, 1999, Johannesburg 23y 338d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/george-dockrell-348034
# Overview Stats Records Matches Videos
# George Henry Dockrell July 22, 1992, Dublin 30y 245d Right hand Bat Slow Left arm Orthodox
# George Henry Dockrell July 22, 1992, Dublin 30y 245d Right hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/gareth-delany-1099379
# Overview Stats Records Matches Videos
# Gareth James Delany April 28, 1997, Dublin 25y 330d Right hand Bat Legbreak Googly
# Gareth James Delany April 28, 1997, Dublin 25y 330d Right hand Bat Legbreak Googly
# https://www.espncricinfo.com/cricketers/mark-adair-526441
# Overview Stats Records Matches News
# Mark Richard Adair March 27, 1996, Holywood, Northern Ireland 26y 362d Right hand Bat Right arm Fast medium
# Mark Richard Adair March 27, 1996, Holywood, Northern Ireland 26y 362d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/simi-singh-1005257
# Overview Stats Records Matches Videos
# Simi Singh February 04, 1987, Bathlana, Punjab, India 36y 48d Right hand Bat Right arm Offbreak, Legbreak Googly
# Simi Singh February 04, 1987, Bathlana, Punjab, India 36y 48d Right hand Bat Right arm Offbreak, Legbreak Googly
# https://www.espncricinfo.com/cricketers/barry-mccarthy-348059
# Overview Stats Records Matches Videos
# Barry John McCarthy September 13, 1992 30y 192d Right hand Bat Right arm Fast medium
# Barry John McCarthy September 13, 1992 30y 192d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/josh-little-928067
# Overview Stats Records Matches News
# Joshua Brian Little November 01, 1999, Dublin 23y 143d Right hand Bat Left arm Fast medium
# Joshua Brian Little November 01, 1999, Dublin 23y 143d Right hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/kyle-mayers-348056
# Overview Stats Records Matches Videos
# Kyle Rico Mayers September 08, 1992, Barbados 30y 197d Left hand Bat Right arm Medium
# Kyle Rico Mayers September 08, 1992, Barbados 30y 197d Left hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/johnson-charles-333066
# Overview Stats Records Matches Videos
# Johnson Charles January 14, 1989, St Lucia 34y 69d Right hand Bat Wicketkeeper
# Johnson Charles January 14, 1989, St Lucia 34y 69d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/evin-lewis-431901
# Overview Stats Records Matches Videos
# Evin Lewis December 27, 1991, Port of Spain, Trinidad 31y 87d Left hand Bat Opening Batter
# Evin Lewis December 27, 1991, Port of Spain, Trinidad 31y 87d Left hand Bat Opening Batter
# https://www.espncricinfo.com/cricketers/nicholas-pooran-604302
# Overview Stats Records Matches Videos
# Nicholas Pooran October 02, 1995, Trinidad 27y 173d Left hand Bat Right arm Offbreak
# Nicholas Pooran October 02, 1995, Trinidad 27y 173d Left hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/rovman-powell-820351
# Overview Stats Records Matches Videos
# Rovman Powell July 23, 1993, Jamaica 29y 244d Right hand Bat Right arm Medium fast
# Rovman Powell July 23, 1993, Jamaica 29y 244d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/shamarh-brooks-230555
# Overview Stats Records Matches Videos
# Shamarh Shaqad Joshua Brooks October 01, 1988, St. Michael, Barbados 34y 174d Right hand Bat Legbreak
# Shamarh Shaqad Joshua Brooks October 01, 1988, St. Michael, Barbados 34y 174d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/jason-holder-391485
# Overview Stats Records Matches Videos
# Jason Omar Holder November 05, 1991, Barbados 31y 139d Right hand Bat Right arm Medium fast
# Jason Omar Holder November 05, 1991, Barbados 31y 139d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/akeal-hosein-530812
# Overview Stats Records Matches Videos
# Akeal Jerome Hosein April 25, 1993, Port-of-Spain 29y 333d Left hand Bat Slow Left arm Orthodox
# Akeal Jerome Hosein April 25, 1993, Port-of-Spain 29y 333d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/odean-smith-820691
# Overview Stats Records Matches Videos
# Odean Fabian Smith November 01, 1996, St. Elizabeth, Jamaica 26y 143d Right hand Bat Right arm Fast medium
# Odean Fabian Smith November 01, 1996, St. Elizabeth, Jamaica 26y 143d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/alzarri-joseph-670031
# Overview Stats Records Matches Videos
# Alzarri Shaheim Joseph November 20, 1996, Antigua 26y 124d Right hand Bat Right arm Fast
# Alzarri Shaheim Joseph November 20, 1996, Antigua 26y 124d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/obed-mccoy-906783
# Overview Stats Records Matches News
# Obed  Christopher McCoy January 04, 1997 26y 79d Left hand Bat Left arm Fast medium
# Obed  Christopher McCoy January 04, 1997 26y 79d Left hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/wessly-madhevere-938959
# Overview Stats Records Matches News
# Wessly Nyasha Madhevere September 04, 2000, Harare 22y 201d Right hand Bat Right arm Offbreak
# Wessly Nyasha Madhevere September 04, 2000, Harare 22y 201d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/regis-chakabva-293831
# Overview Stats Records Matches Videos
# Regis Wiriranai Chakabva September 20, 1987, Harare 35y 185d Right hand Bat Right arm Offbreak
# Regis Wiriranai Chakabva September 20, 1987, Harare 35y 185d Right hand Bat Right arm Offbreak
# ...
# Trent Alexander Boult July 22, 1989, Rotorua 33y 245d Right hand Bat Left arm Fast medium
# Trent Alexander Boult July 22, 1989, Rotorua 33y 245d Right hand Bat Left arm Fast medium
# https://www.espncricinfo.com/cricketers/mohammad-rizwan-323389
# Overview Stats Records Matches Videos
# Mohammad Rizwan June 01, 1992, Peshawar, Khyber Pakhtunkhwa 30y 296d Right hand Bat Wicketkeeper
# Mohammad Rizwan June 01, 1992, Peshawar, Khyber Pakhtunkhwa 30y 296d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/babar-azam-348144
# Overview Stats Records Matches Videos
# Mohammad Babar Azam October 15, 1994, Lahore, Punjab 28y 160d Right hand Bat Right arm Offbreak
# Mohammad Babar Azam October 15, 1994, Lahore, Punjab 28y 160d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/mohammad-haris-1205559
# Overview Stats Matches Videos News
# Mohammad Haris March 30, 2001, Peshawar 21y 359d Right hand Bat Right arm Offbreak
# Mohammad Haris March 30, 2001, Peshawar 21y 359d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/shan-masood-233901
# Overview Stats Records Matches Videos
# Shan Masood Khan October 14, 1989, Kuwait 33y 161d Shaan Masood Shaani
# Shan Masood Khan October 14, 1989, Kuwait 33y 161d Shaan Masood Shaani
# https://www.espncricinfo.com/cricketers/iftikhar-ahmed-480603
# Overview Stats Records Matches Videos
# Iftikhar Ahmed September 03, 1990, Peshawar, North-West Frontier Province 32y 202d Right hand Bat Right arm Offbreak
# Iftikhar Ahmed September 03, 1990, Peshawar, North-West Frontier Province 32y 202d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/mohammad-nawaz-348148
# Overview Stats Records Matches Videos
# Mohammad Nawaz March 21, 1994, Rawalpindi, Punjab 29y 3d Left hand Bat Slow Left arm Orthodox
# Mohammad Nawaz March 21, 1994, Rawalpindi, Punjab 29y 3d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/shadab-khan-922943
# Overview Stats Records Matches Videos
# Shadab Khan October 04, 1998, Mianwali 24y 171d Right hand Bat Legbreak
# Shadab Khan October 04, 1998, Mianwali 24y 171d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/mohammad-wasim-1185538
# Overview Stats Records Matches News
# Mohammad Wasim August 25, 2001, North Wazirastan 21y 211d Right hand Bat Right arm Fast medium
# Mohammad Wasim August 25, 2001, North Wazirastan 21y 211d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/naseem-shah-1158088
# Overview Stats Records Matches Videos
# Naseem Shah February 15, 2003 20y 37d Right hand Bat Right arm Fast
# Naseem Shah February 15, 2003 20y 37d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/haris-rauf-1161606
# Overview Stats Records Matches Videos
# Haris Rauf November 07, 1993 29y 137d Right hand Bat Right arm Fast
# Haris Rauf November 07, 1993 29y 137d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/shaheen-shah-afridi-1072470
# Overview Stats Records Matches Videos
# Shaheen Shah Afridi April 06, 2000, Khyber Agency 22y 352d Left hand Bat Left arm Fast
# Shaheen Shah Afridi April 06, 2000, Khyber Agency 22y 352d Left hand Bat Left arm Fast
# https://www.espncricinfo.com/cricketers/kl-rahul-422108
# Overview Stats Records Matches Videos
# Kannaur Lokesh Rahul April 18, 1992, Bangalore, Karnataka 30y 340d Right hand Bat Wicketkeeper
# Kannaur Lokesh Rahul April 18, 1992, Bangalore, Karnataka 30y 340d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/rohit-sharma-34102
# Overview Stats Records Matches Videos
# Rohit Gurunath Sharma April 30, 1987, Bansod, Nagpur, Maharashtra 35y 328d Right hand Bat Right arm Offbreak
# Rohit Gurunath Sharma April 30, 1987, Bansod, Nagpur, Maharashtra 35y 328d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/virat-kohli-253802
# Overview Stats Records Matches Videos
# Virat Kohli November 05, 1988, Delhi 34y 139d Right hand Bat Right arm Medium
# Virat Kohli November 05, 1988, Delhi 34y 139d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/suryakumar-yadav-446507
# Overview Stats Records Matches Videos
# Suryakumar Ashok Yadav September 14, 1990, Mumbai, Maharashtra 32y 191d Right hand Bat Right arm Medium, Right arm Offbreak
# Suryakumar Ashok Yadav September 14, 1990, Mumbai, Maharashtra 32y 191d Right hand Bat Right arm Medium, Right arm Offbreak
# https://www.espncricinfo.com/cricketers/hardik-pandya-625371
# Overview Stats Records Matches Videos
# Hardik Himanshu Pandya October 11, 1993, Choryasi, Gujarat 29y 164d Right hand Bat Right arm Medium fast
# Hardik Himanshu Pandya October 11, 1993, Choryasi, Gujarat 29y 164d Right hand Bat Right arm Medium fast
# https://www.espncricinfo.com/cricketers/rishabh-pant-931581
# Overview Stats Records Matches Videos
# Rishabh Rajendra Pant October 04, 1997, Haridwar, Uttarakhand 25y 171d Left hand Bat Wicketkeeper
# Rishabh Rajendra Pant October 04, 1997, Haridwar, Uttarakhand 25y 171d Left hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/ravichandran-ashwin-26421
# Overview Stats Records Matches Videos
# Ravichandran Ashwin September 17, 1986, Madras (now Chennai), Tamil Nadu 36y 188d Right hand Bat Right arm Offbreak
# Ravichandran Ashwin September 17, 1986, Madras (now Chennai), Tamil Nadu 36y 188d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/axar-patel-554691
# Overview Stats Records Matches Videos
# Axar Rajeshbhai Patel January 20, 1994, Anand, Gujarat 29y 63d Akshar Patel Left hand Bat
# Axar Rajeshbhai Patel January 20, 1994, Anand, Gujarat 29y 63d Akshar Patel Left hand Bat
# https://www.espncricinfo.com/cricketers/bhuvneshwar-kumar-326016
# Overview Stats Records Matches Videos
# Bhuvneshwar Kumar Singh February 05, 1990, Meerut, Uttar Pradesh 33y 47d Right hand Bat Right arm Medium
# Bhuvneshwar Kumar Singh February 05, 1990, Meerut, Uttar Pradesh 33y 47d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/mohammed-shami-481896
# Overview Stats Records Matches Videos
# Mohammed Shami Ahmed September 03, 1990, Amroha, Uttar Pradesh 32y 202d Right hand Bat Right arm Fast
# Mohammed Shami Ahmed September 03, 1990, Amroha, Uttar Pradesh 32y 202d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/arshdeep-singh-1125976
# Overview Stats Records Matches Videos
# Arshdeep Singh February 05, 1999, Guna, Madhya Pradesh 24y 47d Left hand Bat Left arm Medium fast
# Arshdeep Singh February 05, 1999, Guna, Madhya Pradesh 24y 47d Left hand Bat Left arm Medium fast
# https://www.espncricinfo.com/cricketers/jos-buttler-308967
# Overview Stats Records Matches Videos
# Joseph Charles Buttler September 08, 1990, Taunton, Somerset 32y 197d Right hand Bat Wicketkeeper
# Joseph Charles Buttler September 08, 1990, Taunton, Somerset 32y 197d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/alex-hales-249866
# Overview Stats Records Matches Videos
# Alexander Daniel Hales January 03, 1989, Hillingdon, Middlesex 34y 80d Right hand Bat Right arm Medium
# Alexander Daniel Hales January 03, 1989, Hillingdon, Middlesex 34y 80d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/phil-salt-669365
# Overview Stats Records Matches News
# Philip Dean Salt August 28, 1996, Bodelwyddan, North Wales 26y 208d Right hand Bat Right arm Offbreak
# Philip Dean Salt August 28, 1996, Bodelwyddan, North Wales 26y 208d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/ben-stokes-311158
# Overview Stats Records Matches Videos
# Benjamin Andrew Stokes June 04, 1991, Christchurch, Canterbury, New Zealand 31y 293d Left hand Bat Right arm Fast medium
# Benjamin Andrew Stokes June 04, 1991, Christchurch, Canterbury, New Zealand 31y 293d Left hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/harry-brook-911707
# Overview Stats Records Matches Videos
# Harry Cherrington Brook February 22, 1999, Keighley, Yorkshire 24y 30d Right hand Bat Right arm Medium
# Harry Cherrington Brook February 22, 1999, Keighley, Yorkshire 24y 30d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/liam-livingstone-403902
# Overview Stats Records Matches Videos
# Liam Stephen Livingstone August 04, 1993, Barrow-in-Furness, Cumberland 29y 232d Right hand Bat Right arm Offbreak, Legbreak
# Liam Stephen Livingstone August 04, 1993, Barrow-in-Furness, Cumberland 29y 232d Right hand Bat Right arm Offbreak, Legbreak
# https://www.espncricinfo.com/cricketers/moeen-ali-8917
# Overview Stats Records Matches Videos
# Moeen Munir Ali June 18, 1987, Birmingham 35y 279d Moe Left hand Bat
# Moeen Munir Ali June 18, 1987, Birmingham 35y 279d Moe Left hand Bat
# https://www.espncricinfo.com/cricketers/sam-curran-662973
# Overview Stats Records Matches Videos
# Samuel Matthew Curran June 03, 1998, Northampton 24y 294d Left hand Bat Left arm Medium fast
# Samuel Matthew Curran June 03, 1998, Northampton 24y 294d Left hand Bat Left arm Medium fast
# https://www.espncricinfo.com/cricketers/chris-woakes-247235
# Overview Stats Records Matches Videos
# Christopher Roger Woakes March 02, 1989, Birmingham, Warwickshire 34y 22d Right hand Bat Right arm Fast medium
# Christopher Roger Woakes March 02, 1989, Birmingham, Warwickshire 34y 22d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/chris-jordan-288992
# Overview Stats Records Matches Videos
# Christopher James Jordan October 04, 1988, Barbados 34y 171d CJ Right hand Bat
# Christopher James Jordan October 04, 1988, Barbados 34y 171d CJ Right hand Bat
# https://www.espncricinfo.com/cricketers/adil-rashid-244497
# Overview Stats Records Matches Videos
# Adil Usman Rashid February 17, 1988, Bradford, Yorkshire 35y 35d Dilly, Hoover Right hand Bat
# Adil Usman Rashid February 17, 1988, Bradford, Yorkshire 35y 35d Dilly, Hoover Right hand Bat
# https://www.espncricinfo.com/cricketers/mohammad-rizwan-323389
# Overview Stats Records Matches Videos
# Mohammad Rizwan June 01, 1992, Peshawar, Khyber Pakhtunkhwa 30y 296d Right hand Bat Wicketkeeper
# Mohammad Rizwan June 01, 1992, Peshawar, Khyber Pakhtunkhwa 30y 296d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/babar-azam-348144
# Overview Stats Records Matches Videos
# Mohammad Babar Azam October 15, 1994, Lahore, Punjab 28y 160d Right hand Bat Right arm Offbreak
# Mohammad Babar Azam October 15, 1994, Lahore, Punjab 28y 160d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/mohammad-haris-1205559
# Overview Stats Matches Videos News
# Mohammad Haris March 30, 2001, Peshawar 21y 359d Right hand Bat Right arm Offbreak
# Mohammad Haris March 30, 2001, Peshawar 21y 359d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/shan-masood-233901
# Overview Stats Records Matches Videos
# Shan Masood Khan October 14, 1989, Kuwait 33y 161d Shaan Masood Shaani
# Shan Masood Khan October 14, 1989, Kuwait 33y 161d Shaan Masood Shaani
# https://www.espncricinfo.com/cricketers/iftikhar-ahmed-480603
# Overview Stats Records Matches Videos
# Iftikhar Ahmed September 03, 1990, Peshawar, North-West Frontier Province 32y 202d Right hand Bat Right arm Offbreak
# Iftikhar Ahmed September 03, 1990, Peshawar, North-West Frontier Province 32y 202d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/shadab-khan-922943
# Overview Stats Records Matches Videos
# Shadab Khan October 04, 1998, Mianwali 24y 171d Right hand Bat Legbreak
# Shadab Khan October 04, 1998, Mianwali 24y 171d Right hand Bat Legbreak
# https://www.espncricinfo.com/cricketers/mohammad-nawaz-348148
# Overview Stats Records Matches Videos
# Mohammad Nawaz March 21, 1994, Rawalpindi, Punjab 29y 3d Left hand Bat Slow Left arm Orthodox
# Mohammad Nawaz March 21, 1994, Rawalpindi, Punjab 29y 3d Left hand Bat Slow Left arm Orthodox
# https://www.espncricinfo.com/cricketers/mohammad-wasim-1185538
# Overview Stats Records Matches News
# Mohammad Wasim August 25, 2001, North Wazirastan 21y 211d Right hand Bat Right arm Fast medium
# Mohammad Wasim August 25, 2001, North Wazirastan 21y 211d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/shaheen-shah-afridi-1072470
# Overview Stats Records Matches Videos
# Shaheen Shah Afridi April 06, 2000, Khyber Agency 22y 352d Left hand Bat Left arm Fast
# Shaheen Shah Afridi April 06, 2000, Khyber Agency 22y 352d Left hand Bat Left arm Fast
# https://www.espncricinfo.com/cricketers/haris-rauf-1161606
# Overview Stats Records Matches Videos
# Haris Rauf November 07, 1993 29y 137d Right hand Bat Right arm Fast
# Haris Rauf November 07, 1993 29y 137d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/naseem-shah-1158088
# Overview Stats Records Matches Videos
# Naseem Shah February 15, 2003 20y 37d Right hand Bat Right arm Fast
# Naseem Shah February 15, 2003 20y 37d Right hand Bat Right arm Fast
# https://www.espncricinfo.com/cricketers/jos-buttler-308967
# Overview Stats Records Matches Videos
# Joseph Charles Buttler September 08, 1990, Taunton, Somerset 32y 197d Right hand Bat Wicketkeeper
# Joseph Charles Buttler September 08, 1990, Taunton, Somerset 32y 197d Right hand Bat Wicketkeeper
# https://www.espncricinfo.com/cricketers/alex-hales-249866
# Overview Stats Records Matches Videos
# Alexander Daniel Hales January 03, 1989, Hillingdon, Middlesex 34y 80d Right hand Bat Right arm Medium
# Alexander Daniel Hales January 03, 1989, Hillingdon, Middlesex 34y 80d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/phil-salt-669365
# Overview Stats Records Matches News
# Philip Dean Salt August 28, 1996, Bodelwyddan, North Wales 26y 208d Right hand Bat Right arm Offbreak
# Philip Dean Salt August 28, 1996, Bodelwyddan, North Wales 26y 208d Right hand Bat Right arm Offbreak
# https://www.espncricinfo.com/cricketers/ben-stokes-311158
# Overview Stats Records Matches Videos
# Benjamin Andrew Stokes June 04, 1991, Christchurch, Canterbury, New Zealand 31y 293d Left hand Bat Right arm Fast medium
# Benjamin Andrew Stokes June 04, 1991, Christchurch, Canterbury, New Zealand 31y 293d Left hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/harry-brook-911707
# Overview Stats Records Matches Videos
# Harry Cherrington Brook February 22, 1999, Keighley, Yorkshire 24y 30d Right hand Bat Right arm Medium
# Harry Cherrington Brook February 22, 1999, Keighley, Yorkshire 24y 30d Right hand Bat Right arm Medium
# https://www.espncricinfo.com/cricketers/moeen-ali-8917
# Overview Stats Records Matches Videos
# Moeen Munir Ali June 18, 1987, Birmingham 35y 279d Moe Left hand Bat
# Moeen Munir Ali June 18, 1987, Birmingham 35y 279d Moe Left hand Bat
# https://www.espncricinfo.com/cricketers/liam-livingstone-403902
# Overview Stats Records Matches Videos
# Liam Stephen Livingstone August 04, 1993, Barrow-in-Furness, Cumberland 29y 232d Right hand Bat Right arm Offbreak, Legbreak
# Liam Stephen Livingstone August 04, 1993, Barrow-in-Furness, Cumberland 29y 232d Right hand Bat Right arm Offbreak, Legbreak
# https://www.espncricinfo.com/cricketers/sam-curran-662973
# Overview Stats Records Matches Videos
# Samuel Matthew Curran June 03, 1998, Northampton 24y 294d Left hand Bat Left arm Medium fast
# Samuel Matthew Curran June 03, 1998, Northampton 24y 294d Left hand Bat Left arm Medium fast
# https://www.espncricinfo.com/cricketers/chris-woakes-247235
# Overview Stats Records Matches Videos
# Christopher Roger Woakes March 02, 1989, Birmingham, Warwickshire 34y 22d Right hand Bat Right arm Fast medium
# Christopher Roger Woakes March 02, 1989, Birmingham, Warwickshire 34y 22d Right hand Bat Right arm Fast medium
# https://www.espncricinfo.com/cricketers/chris-jordan-288992
# Overview Stats Records Matches Videos
# Christopher James Jordan October 04, 1988, Barbados 34y 171d CJ Right hand Bat
# Christopher James Jordan October 04, 1988, Barbados 34y 171d CJ Right hand Bat
# https://www.espncricinfo.com/cricketers/adil-rashid-244497
# Overview Stats Records Matches Videos
# Adil Usman Rashid February 17, 1988, Bradford, Yorkshire 35y 35d Dilly, Hoover Right hand Bat
# Adil Usman Rashid February 17, 1988, Bradford, Yorkshire 35y 35d Dilly, Hoover Right hand Bat

# %%
player_details
# Out:
# [['Michael van Lingen',
#   'October 24, 1997',
#   '25y 151d',
#   'Left hand Bat',
#   'Left arm Medium'],
#  ['Divan la Cock',
#   'February 23, 2003',
#   '20y 29d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Stephan Julian Baard',
#   'April 29, 1992, Namibia',
#   '30y 329d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Merwe Gerhard Erasmus',
#   'April 11, 1995, Windhoek, Namibia',
#   '27y 347d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Johannes Jonathan Smit',
#   'November 10, 1995, keetmanshoop',
#   '27y 134d',
#   'Right hand Bat',
#   'Left arm Medium fast'],
#  ['Ben Shikongo',
#   'May 08, 2000',
#   '22y 320d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Pathum Nissanka Silva',
#   'May 18, 1998, Galle',
#   '24y 310d',
#   'Right hand Bat',
#   'Top order Batter'],
#  ['Chirag Suri',
#   'February 18, 1995, New Delhi, India',
#   '28y 34d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Muhammad Waseem',
#   'February 12, 1994',
#   '29y 40d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Kashif Daud',
#   'February 10, 1986, Sialkot, Punjab',
#   '37y 42d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Zawar Farid',
#   'July 25, 1992, Sahiwal',
#   '30y 242d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Basil Hameed',
#   'April 15, 1992, Panniyankara, Kozhikode, Kerala',
#   '30y 343d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Chundangapoyil Puthiyapurayil Rizwan',
#   'April 19, 1988, Tellicherry, Kerala',
#   '34y 339d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Aayan Afzal Khan',
#   'November 15, 2005',
#   '17y 129d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Karthik Palaniapan Meiyappan',
#   'October 08, 2000, Chennai, India',
#   '22y 167d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Muhammad Junaid Siddique',
#   'December 06, 1992, Multan, Pakistan',
#   '30y 108d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Zahoor Khan',
#   'May 25, 1989, Faisalabad, Punjab',
#   '33y 303d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Vikramjit Singh',
#   'January 09, 2003, Cheema Khurd, Punjab',
#   '20y 74d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Scott Andrew Edwards',
#   'August 23, 1996, Tonga',
#   '26y 213d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Frederick Jack Klaassen',
#   'November 13, 1992, Haywards Heath, Sussex',
#   '30y 131d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Paul Adriaan van Meekeren',
#   'January 15, 1993, Amsterdam, Netherlands',
#   '30y 68d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Henry George Munsey',
#   'February 21, 1993, Oxford',
#   '30y 31d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Michael Alexander Jones',
#   'January 05, 1998, Ormskirk, Lancashire',
#   '25y 78d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Matthew Henry Cross',
#   'October 15, 1992, Aberdeen',
#   '30y 160d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Richard Douglas Berrington',
#   'April 03, 1987, Pretoria, South Africa',
#   '35y 355d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Michael Alexander Leask',
#   'October 29, 1990, Aberdeen',
#   '32y 146d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Christopher Nicholas Greaves',
#   'October 12, 1990',
#   '32y 163d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Mark Robert James Watt',
#   'July 29, 1996, Eastern General Hospital, Edinburgh',
#   '26y 238d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Safyaan Mohammed Sharif',
#   'May 24, 1991, Huddersfield, Yorkshire',
#   '31y 304d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Bradley Thomas James Wheal',
#   'August 28, 1996, Durban, KwaZulu-Natal',
#   '26y 208d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Kyle Rico Mayers',
#   'September 08, 1992, Barbados',
#   '30y 197d',
#   'Left hand Bat',
#   'Right arm Medium'],
#  ['Shamarh Shaqad Joshua Brooks',
#   'October 01, 1988, St. Michael, Barbados',
#   '34y 174d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Rovman Powell',
#   'July 23, 1993, Jamaica',
#   '29y 244d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Jason Omar Holder',
#   'November 05, 1991, Barbados',
#   '31y 139d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Alzarri Shaheim Joseph',
#   'November 20, 1996, Antigua',
#   '26y 124d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Odean Fabian Smith',
#   'November 01, 1996, St. Elizabeth, Jamaica',
#   '26y 143d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Obed  Christopher McCoy',
#   'January 04, 1997',
#   '26y 79d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Wessly Nyasha Madhevere',
#   'September 04, 2000, Harare',
#   '22y 201d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Michael van Lingen',
#   'October 24, 1997',
#   '25y 151d',
#   'Left hand Bat',
#   'Left arm Medium'],
#  ['Michael van Lingen',
#   'October 24, 1997',
#   '25y 151d',
#   'Left hand Bat',
#   'Left arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Divan la Cock',
#   'February 23, 2003',
#   '20y 29d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Divan la Cock',
#   'February 23, 2003',
#   '20y 29d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Jan Nicol Loftie-Eaton',
#   'March 15, 2001',
#   '22y 9d',
#   'Left hand Bat',
#   'Right arm Medium, Legbreak'],
#  ['Jan Nicol Loftie-Eaton',
#   'March 15, 2001',
#   '22y 9d',
#   'Left hand Bat',
#   'Right arm Medium, Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Stephan Julian Baard',
#   'April 29, 1992, Namibia',
#   '30y 329d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Stephan Julian Baard',
#   'April 29, 1992, Namibia',
#   '30y 329d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Merwe Gerhard Erasmus',
#   'April 11, 1995, Windhoek, Namibia',
#   '27y 347d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Merwe Gerhard Erasmus',
#   'April 11, 1995, Windhoek, Namibia',
#   '27y 347d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Jan Nicolaas Frylinck',
#   'April 06, 1994, Bellville, Western Cape',
#   '28y 352d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Jan Nicolaas Frylinck',
#   'April 06, 1994, Bellville, Western Cape',
#   '28y 352d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['David Wiese',
#   'May 18, 1985, Roodepoort',
#   '37y 310d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['David Wiese',
#   'May 18, 1985, Roodepoort',
#   '37y 310d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Johannes Jonathan Smit',
#   'November 10, 1995, keetmanshoop',
#   '27y 134d',
#   'Right hand Bat',
#   'Left arm Medium fast'],
#  ['Johannes Jonathan Smit',
#   'November 10, 1995, keetmanshoop',
#   '27y 134d',
#   'Right hand Bat',
#   'Left arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Zane Edward Green',
#   'October 11, 1996, Namibia',
#   '26y 164d',
#   'Left hand Bat',
#   'Wicketkeeper'],
#  ['Zane Edward Green',
#   'October 11, 1996, Namibia',
#   '26y 164d',
#   'Left hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Bernard Martinus Scholtz',
#   'October 03, 1990, Keetmanshoop, Namibia',
#   '32y 172d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Bernard Martinus Scholtz',
#   'October 03, 1990, Keetmanshoop, Namibia',
#   '32y 172d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Ben Shikongo',
#   'May 08, 2000',
#   '22y 320d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Ben Shikongo',
#   'May 08, 2000',
#   '22y 320d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pathum Nissanka Silva',
#   'May 18, 1998, Galle',
#   '24y 310d',
#   'Right hand Bat',
#   'Top order Batter'],
#  ['Pathum Nissanka Silva',
#   'May 18, 1998, Galle',
#   '24y 310d',
#   'Right hand Bat',
#   'Top order Batter'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Balapuwaduge Kusal Gimhan Mendis',
#   'February 02, 1995, Moratuwa',
#   '28y 50d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Balapuwaduge Kusal Gimhan Mendis',
#   'February 02, 1995, Moratuwa',
#   '28y 50d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Dhananjaya Maduranga de Silva',
#   'September 06, 1991, Colombo',
#   '31y 199d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Dhananjaya Maduranga de Silva',
#   'September 06, 1991, Colombo',
#   '31y 199d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Mashtayage Danushka Gunathilaka',
#   'March 17, 1991, Panadura',
#   '32y 7d',
#   'Dana',
#   'Left hand Bat'],
#  ['Mashtayage Danushka Gunathilaka',
#   'March 17, 1991, Panadura',
#   '32y 7d',
#   'Dana',
#   'Left hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pramod Bhanuka Bandara Rajapaksa',
#   'October 24, 1991, Colombo',
#   '31y 151d',
#   'Left hand Bat',
#   'Right arm Medium'],
#  ['Pramod Bhanuka Bandara Rajapaksa',
#   'October 24, 1991, Colombo',
#   '31y 151d',
#   'Left hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Madagamagamage Dasun Shanaka',
#   'September 09, 1991, Negombo',
#   '31y 196d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Madagamagamage Dasun Shanaka',
#   'September 09, 1991, Negombo',
#   '31y 196d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pinnaduwage Wanindu Hasaranga de Silva',
#   'July 29, 1997, Galle',
#   '25y 238d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Pinnaduwage Wanindu Hasaranga de Silva',
#   'July 29, 1997, Galle',
#   '25y 238d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Chamika Karunaratne',
#   'May 29, 1996, Colombo',
#   '26y 299d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Chamika Karunaratne',
#   'May 29, 1996, Colombo',
#   '26y 299d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pramod Madushan Liyanagamage',
#   'December 14, 1993, Hambantota',
#   '29y 100d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Pramod Madushan Liyanagamage',
#   'December 14, 1993, Hambantota',
#   '29y 100d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pathira Vasan Dushmantha Chameera',
#   'January 11, 1992, Ragama',
#   '31y 72d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Pathira Vasan Dushmantha Chameera',
#   'January 11, 1992, Ragama',
#   '31y 72d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Morawakage Maheesh Theekshana',
#   'August 01, 2000, Colombo',
#   '22y 235d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Morawakage Maheesh Theekshana',
#   'August 01, 2000, Colombo',
#   '22y 235d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Chirag Suri',
#   'February 18, 1995, New Delhi, India',
#   '28y 34d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Chirag Suri',
#   'February 18, 1995, New Delhi, India',
#   '28y 34d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Muhammad Waseem',
#   'February 12, 1994',
#   '29y 40d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Muhammad Waseem',
#   'February 12, 1994',
#   '29y 40d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Kashif Daud',
#   'February 10, 1986, Sialkot, Punjab',
#   '37y 42d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Kashif Daud',
#   'February 10, 1986, Sialkot, Punjab',
#   '37y 42d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Vriitya Aravind',
#   'June 11, 2002, Chennai, India',
#   '20y 286d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Vriitya Aravind',
#   'June 11, 2002, Chennai, India',
#   '20y 286d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Matches', 'News', 'Photos'],
#  ['Zawar Farid',
#   'July 25, 1992, Sahiwal',
#   '30y 242d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Zawar Farid',
#   'July 25, 1992, Sahiwal',
#   '30y 242d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Photos'],
#  ['Basil Hameed',
#   'April 15, 1992, Panniyankara, Kozhikode, Kerala',
#   '30y 343d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Basil Hameed',
#   'April 15, 1992, Panniyankara, Kozhikode, Kerala',
#   '30y 343d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Chundangapoyil Puthiyapurayil Rizwan',
#   'April 19, 1988, Tellicherry, Kerala',
#   '34y 339d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Chundangapoyil Puthiyapurayil Rizwan',
#   'April 19, 1988, Tellicherry, Kerala',
#   '34y 339d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Aayan Afzal Khan',
#   'November 15, 2005',
#   '17y 129d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Aayan Afzal Khan',
#   'November 15, 2005',
#   '17y 129d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Karthik Palaniapan Meiyappan',
#   'October 08, 2000, Chennai, India',
#   '22y 167d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Karthik Palaniapan Meiyappan',
#   'October 08, 2000, Chennai, India',
#   '22y 167d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Photos'],
#  ['Muhammad Junaid Siddique',
#   'December 06, 1992, Multan, Pakistan',
#   '30y 108d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Muhammad Junaid Siddique',
#   'December 06, 1992, Multan, Pakistan',
#   '30y 108d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Zahoor Khan',
#   'May 25, 1989, Faisalabad, Punjab',
#   '33y 303d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Zahoor Khan',
#   'May 25, 1989, Faisalabad, Punjab',
#   '33y 303d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Vikramjit Singh',
#   'January 09, 2003, Cheema Khurd, Punjab',
#   '20y 74d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Vikramjit Singh',
#   'January 09, 2003, Cheema Khurd, Punjab',
#   '20y 74d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ["Maxwell Patrick O'Dowd",
#   'March 04, 1994, Auckland',
#   '29y 20d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ["Maxwell Patrick O'Dowd",
#   'March 04, 1994, Auckland',
#   '29y 20d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Bas de Leede',
#   'November 15, 1999',
#   '23y 129d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Bas de Leede',
#   'November 15, 1999',
#   '23y 129d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Matches', 'News', 'Photos'],
#  ['Colin Niel Ackermann',
#   'April 04, 1991, George, South Africa',
#   '31y 354d',
#   'Ackers',
#   'Right hand Bat'],
#  ['Colin Niel Ackermann',
#   'April 04, 1991, George, South Africa',
#   '31y 354d',
#   'Ackers',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Tom Lexley William Cooper',
#   'November 26, 1986, Wollongong, New South Wales',
#   '36y 118d',
#   'Coops',
#   'Right hand Bat'],
#  ['Tom Lexley William Cooper',
#   'November 26, 1986, Wollongong, New South Wales',
#   '36y 118d',
#   'Coops',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Scott Andrew Edwards',
#   'August 23, 1996, Tonga',
#   '26y 213d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Scott Andrew Edwards',
#   'August 23, 1996, Tonga',
#   '26y 213d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Roelof Erasmus van der Merwe',
#   'December 31, 1984, Johannesburg, Transvaal',
#   '38y 83d',
#   'Roela, Bulldog',
#   'Right hand Bat'],
#  ['Roelof Erasmus van der Merwe',
#   'December 31, 1984, Johannesburg, Transvaal',
#   '38y 83d',
#   'Roela, Bulldog',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Timothy James Gerard Pringle',
#   'August 29, 2002, The Hague',
#   '20y 207d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Timothy James Gerard Pringle',
#   'August 29, 2002, The Hague',
#   '20y 207d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Logan Verjus van Beek',
#   'September 07, 1990, Christchurch, Canterbury',
#   '32y 198d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Logan Verjus van Beek',
#   'September 07, 1990, Christchurch, Canterbury',
#   '32y 198d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Frederick Jack Klaassen',
#   'November 13, 1992, Haywards Heath, Sussex',
#   '30y 131d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Frederick Jack Klaassen',
#   'November 13, 1992, Haywards Heath, Sussex',
#   '30y 131d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Paul Adriaan van Meekeren',
#   'January 15, 1993, Amsterdam, Netherlands',
#   '30y 68d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Paul Adriaan van Meekeren',
#   'January 15, 1993, Amsterdam, Netherlands',
#   '30y 68d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Henry George Munsey',
#   'February 21, 1993, Oxford',
#   '30y 31d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Henry George Munsey',
#   'February 21, 1993, Oxford',
#   '30y 31d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Michael Alexander Jones',
#   'January 05, 1998, Ormskirk, Lancashire',
#   '25y 78d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Michael Alexander Jones',
#   'January 05, 1998, Ormskirk, Lancashire',
#   '25y 78d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Matthew Henry Cross',
#   'October 15, 1992, Aberdeen',
#   '30y 160d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Matthew Henry Cross',
#   'October 15, 1992, Aberdeen',
#   '30y 160d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Richard Douglas Berrington',
#   'April 03, 1987, Pretoria, South Africa',
#   '35y 355d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Richard Douglas Berrington',
#   'April 03, 1987, Pretoria, South Africa',
#   '35y 355d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Calum Scott MacLeod',
#   'November 15, 1988, Glasgow, Lanarkshire',
#   '34y 129d',
#   'Cloudy, Highlander, Scot',
#   'Right hand Bat'],
#  ['Calum Scott MacLeod',
#   'November 15, 1988, Glasgow, Lanarkshire',
#   '34y 129d',
#   'Cloudy, Highlander, Scot',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Michael Alexander Leask',
#   'October 29, 1990, Aberdeen',
#   '32y 146d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Michael Alexander Leask',
#   'October 29, 1990, Aberdeen',
#   '32y 146d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Christopher Nicholas Greaves',
#   'October 12, 1990',
#   '32y 163d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Christopher Nicholas Greaves',
#   'October 12, 1990',
#   '32y 163d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Mark Robert James Watt',
#   'July 29, 1996, Eastern General Hospital, Edinburgh',
#   '26y 238d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Mark Robert James Watt',
#   'July 29, 1996, Eastern General Hospital, Edinburgh',
#   '26y 238d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Joshua Henry Davey',
#   'August 03, 1990, Aberdeen',
#   '32y 233d',
#   'Wavey',
#   'Right hand Bat'],
#  ['Joshua Henry Davey',
#   'August 03, 1990, Aberdeen',
#   '32y 233d',
#   'Wavey',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Safyaan Mohammed Sharif',
#   'May 24, 1991, Huddersfield, Yorkshire',
#   '31y 304d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Safyaan Mohammed Sharif',
#   'May 24, 1991, Huddersfield, Yorkshire',
#   '31y 304d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Matches', 'News', 'Photos'],
#  ['Bradley Thomas James Wheal',
#   'August 28, 1996, Durban, KwaZulu-Natal',
#   '26y 208d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Bradley Thomas James Wheal',
#   'August 28, 1996, Durban, KwaZulu-Natal',
#   '26y 208d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Kyle Rico Mayers',
#   'September 08, 1992, Barbados',
#   '30y 197d',
#   'Left hand Bat',
#   'Right arm Medium'],
#  ['Kyle Rico Mayers',
#   'September 08, 1992, Barbados',
#   '30y 197d',
#   'Left hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Evin Lewis',
#   'December 27, 1991, Port of Spain, Trinidad',
#   '31y 87d',
#   'Left hand Bat',
#   'Opening Batter'],
#  ['Evin Lewis',
#   'December 27, 1991, Port of Spain, Trinidad',
#   '31y 87d',
#   'Left hand Bat',
#   'Opening Batter'],
#  ['Overview', 'Stats', 'Matches', 'Videos', 'News'],
#  ['Brandon Alexander King',
#   'December 16, 1994, Kingston, Jamaica',
#   '28y 98d',
#   'Right hand Bat',
#   'Top order Batter'],
#  ['Brandon Alexander King',
#   'December 16, 1994, Kingston, Jamaica',
#   '28y 98d',
#   'Right hand Bat',
#   'Top order Batter'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Nicholas Pooran',
#   'October 02, 1995, Trinidad',
#   '27y 173d',
#   'Left hand Bat',
#   'Right arm Offbreak'],
#  ['Nicholas Pooran',
#   'October 02, 1995, Trinidad',
#   '27y 173d',
#   'Left hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Shamarh Shaqad Joshua Brooks',
#   'October 01, 1988, St. Michael, Barbados',
#   '34y 174d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Shamarh Shaqad Joshua Brooks',
#   'October 01, 1988, St. Michael, Barbados',
#   '34y 174d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Rovman Powell',
#   'July 23, 1993, Jamaica',
#   '29y 244d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Rovman Powell',
#   'July 23, 1993, Jamaica',
#   '29y 244d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Jason Omar Holder',
#   'November 05, 1991, Barbados',
#   '31y 139d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Jason Omar Holder',
#   'November 05, 1991, Barbados',
#   '31y 139d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Akeal Jerome Hosein',
#   'April 25, 1993, Port-of-Spain',
#   '29y 333d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Akeal Jerome Hosein',
#   'April 25, 1993, Port-of-Spain',
#   '29y 333d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Alzarri Shaheim Joseph',
#   'November 20, 1996, Antigua',
#   '26y 124d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Alzarri Shaheim Joseph',
#   'November 20, 1996, Antigua',
#   '26y 124d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Odean Fabian Smith',
#   'November 01, 1996, St. Elizabeth, Jamaica',
#   '26y 143d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Odean Fabian Smith',
#   'November 01, 1996, St. Elizabeth, Jamaica',
#   '26y 143d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Obed  Christopher McCoy',
#   'January 04, 1997',
#   '26y 79d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Obed  Christopher McCoy',
#   'January 04, 1997',
#   '26y 79d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Regis Wiriranai Chakabva',
#   'September 20, 1987, Harare',
#   '35y 185d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Regis Wiriranai Chakabva',
#   'September 20, 1987, Harare',
#   '35y 185d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Craig Richard Ervine',
#   'August 19, 1985, Harare',
#   '37y 217d',
#   'Left hand Bat',
#   'Right arm Offbreak'],
#  ['Craig Richard Ervine',
#   'August 19, 1985, Harare',
#   '37y 217d',
#   'Left hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Wessly Nyasha Madhevere',
#   'September 04, 2000, Harare',
#   '22y 201d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Wessly Nyasha Madhevere',
#   'September 04, 2000, Harare',
#   '22y 201d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Sean Colin Williams',
#   'September 26, 1986, Bulawayo',
#   '36y 179d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Sean Colin Williams',
#   'September 26, 1986, Bulawayo',
#   '36y 179d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Sikandar Raza Butt',
#   'April 24, 1986, Sialkot, Punjab, Pakistan',
#   '36y 334d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Sikandar Raza Butt',
#   'April 24, 1986, Sialkot, Punjab, Pakistan',
#   '36y 334d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Milton Shumba',
#   'October 19, 2000, Chitungwiza',
#   '22y 156d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Milton Shumba',
#   'October 19, 2000, Chitungwiza',
#   '22y 156d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Ryan Ponsonby Burl',
#   'April 15, 1994, Marondera',
#   '28y 343d',
#   'Left hand Bat',
#   'Legbreak'],
#  ['Ryan Ponsonby Burl',
#   'April 15, 1994, Marondera',
#   '28y 343d',
#   'Left hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Luke Mafuwa Jongwe',
#   'February 06, 1995, Harare',
#   '28y 46d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Luke Mafuwa Jongwe',
#   'February 06, 1995, Harare',
#   '28y 46d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Tendai Larry Chatara',
#   'February 28, 1991, Chimanimani',
#   '32y 24d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Tendai Larry Chatara',
#   'February 28, 1991, Chimanimani',
#   '32y 24d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Richard Ngarava',
#   'December 28, 1997, Harare',
#   '25y 86d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Richard Ngarava',
#   'December 28, 1997, Harare',
#   '25y 86d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Blessing Muzarabani',
#   'October 02, 1996, Harare',
#   '26y 173d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Blessing Muzarabani',
#   'October 02, 1996, Harare',
#   '26y 173d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Paul Robert Stirling',
#   'September 03, 1990, Belfast',
#   '32y 202d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Paul Robert Stirling',
#   'September 03, 1990, Belfast',
#   '32y 202d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Andrew Balbirnie',
#   'December 28, 1990, Dublin, Ireland',
#   '32y 86d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Andrew Balbirnie',
#   'December 28, 1990, Dublin, Ireland',
#   '32y 86d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Lorcan John Tucker',
#   'September 10, 1996, Dublin',
#   '26y 195d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Lorcan John Tucker',
#   'September 10, 1996, Dublin',
#   '26y 195d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Harry Tom Tector',
#   'December 06, 1999, Dublin',
#   '23y 108d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Harry Tom Tector',
#   'December 06, 1999, Dublin',
#   '23y 108d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Curtis Campher',
#   'April 20, 1999, Johannesburg',
#   '23y 338d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Curtis Campher',
#   'April 20, 1999, Johannesburg',
#   '23y 338d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['George Henry Dockrell',
#   'July 22, 1992, Dublin',
#   '30y 245d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['George Henry Dockrell',
#   'July 22, 1992, Dublin',
#   '30y 245d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Gareth James Delany',
#   'April 28, 1997, Dublin',
#   '25y 330d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Gareth James Delany',
#   'April 28, 1997, Dublin',
#   '25y 330d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Mark Richard Adair',
#   'March 27, 1996, Holywood, Northern Ireland',
#   '26y 362d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Mark Richard Adair',
#   'March 27, 1996, Holywood, Northern Ireland',
#   '26y 362d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Simi Singh',
#   'February 04, 1987, Bathlana, Punjab, India',
#   '36y 48d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Simi Singh',
#   'February 04, 1987, Bathlana, Punjab, India',
#   '36y 48d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Barry John McCarthy',
#   'September 13, 1992',
#   '30y 192d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Barry John McCarthy',
#   'September 13, 1992',
#   '30y 192d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Joshua Brian Little',
#   'November 01, 1999, Dublin',
#   '23y 143d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Joshua Brian Little',
#   'November 01, 1999, Dublin',
#   '23y 143d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Michael van Lingen',
#   'October 24, 1997',
#   '25y 151d',
#   'Left hand Bat',
#   'Left arm Medium'],
#  ['Michael van Lingen',
#   'October 24, 1997',
#   '25y 151d',
#   'Left hand Bat',
#   'Left arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Divan la Cock',
#   'February 23, 2003',
#   '20y 29d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Divan la Cock',
#   'February 23, 2003',
#   '20y 29d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Stephan Julian Baard',
#   'April 29, 1992, Namibia',
#   '30y 329d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Stephan Julian Baard',
#   'April 29, 1992, Namibia',
#   '30y 329d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Jan Nicol Loftie-Eaton',
#   'March 15, 2001',
#   '22y 9d',
#   'Left hand Bat',
#   'Right arm Medium, Legbreak'],
#  ['Jan Nicol Loftie-Eaton',
#   'March 15, 2001',
#   '22y 9d',
#   'Left hand Bat',
#   'Right arm Medium, Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Jan Nicolaas Frylinck',
#   'April 06, 1994, Bellville, Western Cape',
#   '28y 352d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Jan Nicolaas Frylinck',
#   'April 06, 1994, Bellville, Western Cape',
#   '28y 352d',
#   'Left hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Merwe Gerhard Erasmus',
#   'April 11, 1995, Windhoek, Namibia',
#   '27y 347d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Merwe Gerhard Erasmus',
#   'April 11, 1995, Windhoek, Namibia',
#   '27y 347d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['David Wiese',
#   'May 18, 1985, Roodepoort',
#   '37y 310d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['David Wiese',
#   'May 18, 1985, Roodepoort',
#   '37y 310d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Johannes Jonathan Smit',
#   'November 10, 1995, keetmanshoop',
#   '27y 134d',
#   'Right hand Bat',
#   'Left arm Medium fast'],
#  ['Johannes Jonathan Smit',
#   'November 10, 1995, keetmanshoop',
#   '27y 134d',
#   'Right hand Bat',
#   'Left arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Zane Edward Green',
#   'October 11, 1996, Namibia',
#   '26y 164d',
#   'Left hand Bat',
#   'Wicketkeeper'],
#  ['Zane Edward Green',
#   'October 11, 1996, Namibia',
#   '26y 164d',
#   'Left hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Bernard Martinus Scholtz',
#   'October 03, 1990, Keetmanshoop, Namibia',
#   '32y 172d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Bernard Martinus Scholtz',
#   'October 03, 1990, Keetmanshoop, Namibia',
#   '32y 172d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Ben Shikongo',
#   'May 08, 2000',
#   '22y 320d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Ben Shikongo',
#   'May 08, 2000',
#   '22y 320d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ["Maxwell Patrick O'Dowd",
#   'March 04, 1994, Auckland',
#   '29y 20d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ["Maxwell Patrick O'Dowd",
#   'March 04, 1994, Auckland',
#   '29y 20d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Vikramjit Singh',
#   'January 09, 2003, Cheema Khurd, Punjab',
#   '20y 74d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Vikramjit Singh',
#   'January 09, 2003, Cheema Khurd, Punjab',
#   '20y 74d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Bas de Leede',
#   'November 15, 1999',
#   '23y 129d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Bas de Leede',
#   'November 15, 1999',
#   '23y 129d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Tom Lexley William Cooper',
#   'November 26, 1986, Wollongong, New South Wales',
#   '36y 118d',
#   'Coops',
#   'Right hand Bat'],
#  ['Tom Lexley William Cooper',
#   'November 26, 1986, Wollongong, New South Wales',
#   '36y 118d',
#   'Coops',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Matches', 'News', 'Photos'],
#  ['Colin Niel Ackermann',
#   'April 04, 1991, George, South Africa',
#   '31y 354d',
#   'Ackers',
#   'Right hand Bat'],
#  ['Colin Niel Ackermann',
#   'April 04, 1991, George, South Africa',
#   '31y 354d',
#   'Ackers',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Scott Andrew Edwards',
#   'August 23, 1996, Tonga',
#   '26y 213d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Scott Andrew Edwards',
#   'August 23, 1996, Tonga',
#   '26y 213d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Timothy James Gerard Pringle',
#   'August 29, 2002, The Hague',
#   '20y 207d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Timothy James Gerard Pringle',
#   'August 29, 2002, The Hague',
#   '20y 207d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Roelof Erasmus van der Merwe',
#   'December 31, 1984, Johannesburg, Transvaal',
#   '38y 83d',
#   'Roela, Bulldog',
#   'Right hand Bat'],
#  ['Roelof Erasmus van der Merwe',
#   'December 31, 1984, Johannesburg, Transvaal',
#   '38y 83d',
#   'Roela, Bulldog',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Timm van der Gugten',
#   'February 25, 1991, Hornsby, Upper North Shore, Sydney',
#   '32y 27d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Timm van der Gugten',
#   'February 25, 1991, Hornsby, Upper North Shore, Sydney',
#   '32y 27d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Frederick Jack Klaassen',
#   'November 13, 1992, Haywards Heath, Sussex',
#   '30y 131d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Frederick Jack Klaassen',
#   'November 13, 1992, Haywards Heath, Sussex',
#   '30y 131d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Paul Adriaan van Meekeren',
#   'January 15, 1993, Amsterdam, Netherlands',
#   '30y 68d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Paul Adriaan van Meekeren',
#   'January 15, 1993, Amsterdam, Netherlands',
#   '30y 68d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pathum Nissanka Silva',
#   'May 18, 1998, Galle',
#   '24y 310d',
#   'Right hand Bat',
#   'Top order Batter'],
#  ['Pathum Nissanka Silva',
#   'May 18, 1998, Galle',
#   '24y 310d',
#   'Right hand Bat',
#   'Top order Batter'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Balapuwaduge Kusal Gimhan Mendis',
#   'February 02, 1995, Moratuwa',
#   '28y 50d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Balapuwaduge Kusal Gimhan Mendis',
#   'February 02, 1995, Moratuwa',
#   '28y 50d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Dhananjaya Maduranga de Silva',
#   'September 06, 1991, Colombo',
#   '31y 199d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Dhananjaya Maduranga de Silva',
#   'September 06, 1991, Colombo',
#   '31y 199d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pramod Bhanuka Bandara Rajapaksa',
#   'October 24, 1991, Colombo',
#   '31y 151d',
#   'Left hand Bat',
#   'Right arm Medium'],
#  ['Pramod Bhanuka Bandara Rajapaksa',
#   'October 24, 1991, Colombo',
#   '31y 151d',
#   'Left hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Kariyawasam Indipalage Charith Asalanka',
#   'June 29, 1997, Elpitiya',
#   '25y 268d',
#   'Left hand Bat',
#   'Right arm Offbreak'],
#  ['Kariyawasam Indipalage Charith Asalanka',
#   'June 29, 1997, Elpitiya',
#   '25y 268d',
#   'Left hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Madagamagamage Dasun Shanaka',
#   'September 09, 1991, Negombo',
#   '31y 196d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Madagamagamage Dasun Shanaka',
#   'September 09, 1991, Negombo',
#   '31y 196d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pinnaduwage Wanindu Hasaranga de Silva',
#   'July 29, 1997, Galle',
#   '25y 238d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Pinnaduwage Wanindu Hasaranga de Silva',
#   'July 29, 1997, Galle',
#   '25y 238d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Chamika Karunaratne',
#   'May 29, 1996, Colombo',
#   '26y 299d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Chamika Karunaratne',
#   'May 29, 1996, Colombo',
#   '26y 299d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pramod Madushan Liyanagamage',
#   'December 14, 1993, Hambantota',
#   '29y 100d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Pramod Madushan Liyanagamage',
#   'December 14, 1993, Hambantota',
#   '29y 100d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Pathira Vasan Dushmantha Chameera',
#   'January 11, 1992, Ragama',
#   '31y 72d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Pathira Vasan Dushmantha Chameera',
#   'January 11, 1992, Ragama',
#   '31y 72d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Morawakage Maheesh Theekshana',
#   'August 01, 2000, Colombo',
#   '22y 235d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Morawakage Maheesh Theekshana',
#   'August 01, 2000, Colombo',
#   '22y 235d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Muhammad Waseem',
#   'February 12, 1994',
#   '29y 40d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Muhammad Waseem',
#   'February 12, 1994',
#   '29y 40d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Chirag Suri',
#   'February 18, 1995, New Delhi, India',
#   '28y 34d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Chirag Suri',
#   'February 18, 1995, New Delhi, India',
#   '28y 34d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Aryan Lakra',
#   'December 13, 2001, Sonepat, Haryana',
#   '21y 101d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Aryan Lakra',
#   'December 13, 2001, Sonepat, Haryana',
#   '21y 101d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Chundangapoyil Puthiyapurayil Rizwan',
#   'April 19, 1988, Tellicherry, Kerala',
#   '34y 339d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Chundangapoyil Puthiyapurayil Rizwan',
#   'April 19, 1988, Tellicherry, Kerala',
#   '34y 339d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Vriitya Aravind',
#   'June 11, 2002, Chennai, India',
#   '20y 286d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Vriitya Aravind',
#   'June 11, 2002, Chennai, India',
#   '20y 286d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Photos'],
#  ['Basil Hameed',
#   'April 15, 1992, Panniyankara, Kozhikode, Kerala',
#   '30y 343d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Basil Hameed',
#   'April 15, 1992, Panniyankara, Kozhikode, Kerala',
#   '30y 343d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Aayan Afzal Khan',
#   'November 15, 2005',
#   '17y 129d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Aayan Afzal Khan',
#   'November 15, 2005',
#   '17y 129d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Kashif Daud',
#   'February 10, 1986, Sialkot, Punjab',
#   '37y 42d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Kashif Daud',
#   'February 10, 1986, Sialkot, Punjab',
#   '37y 42d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Karthik Palaniapan Meiyappan',
#   'October 08, 2000, Chennai, India',
#   '22y 167d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Karthik Palaniapan Meiyappan',
#   'October 08, 2000, Chennai, India',
#   '22y 167d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Photos'],
#  ['Muhammad Junaid Siddique',
#   'December 06, 1992, Multan, Pakistan',
#   '30y 108d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Muhammad Junaid Siddique',
#   'December 06, 1992, Multan, Pakistan',
#   '30y 108d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Zahoor Khan',
#   'May 25, 1989, Faisalabad, Punjab',
#   '33y 303d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Zahoor Khan',
#   'May 25, 1989, Faisalabad, Punjab',
#   '33y 303d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Henry George Munsey',
#   'February 21, 1993, Oxford',
#   '30y 31d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Henry George Munsey',
#   'February 21, 1993, Oxford',
#   '30y 31d',
#   'Left hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Michael Alexander Jones',
#   'January 05, 1998, Ormskirk, Lancashire',
#   '25y 78d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Michael Alexander Jones',
#   'January 05, 1998, Ormskirk, Lancashire',
#   '25y 78d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Matthew Henry Cross',
#   'October 15, 1992, Aberdeen',
#   '30y 160d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Matthew Henry Cross',
#   'October 15, 1992, Aberdeen',
#   '30y 160d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Richard Douglas Berrington',
#   'April 03, 1987, Pretoria, South Africa',
#   '35y 355d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Richard Douglas Berrington',
#   'April 03, 1987, Pretoria, South Africa',
#   '35y 355d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Michael Alexander Leask',
#   'October 29, 1990, Aberdeen',
#   '32y 146d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Michael Alexander Leask',
#   'October 29, 1990, Aberdeen',
#   '32y 146d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Calum Scott MacLeod',
#   'November 15, 1988, Glasgow, Lanarkshire',
#   '34y 129d',
#   'Cloudy, Highlander, Scot',
#   'Right hand Bat'],
#  ['Calum Scott MacLeod',
#   'November 15, 1988, Glasgow, Lanarkshire',
#   '34y 129d',
#   'Cloudy, Highlander, Scot',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Christopher Nicholas Greaves',
#   'October 12, 1990',
#   '32y 163d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Christopher Nicholas Greaves',
#   'October 12, 1990',
#   '32y 163d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Mark Robert James Watt',
#   'July 29, 1996, Eastern General Hospital, Edinburgh',
#   '26y 238d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Mark Robert James Watt',
#   'July 29, 1996, Eastern General Hospital, Edinburgh',
#   '26y 238d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Joshua Henry Davey',
#   'August 03, 1990, Aberdeen',
#   '32y 233d',
#   'Wavey',
#   'Right hand Bat'],
#  ['Joshua Henry Davey',
#   'August 03, 1990, Aberdeen',
#   '32y 233d',
#   'Wavey',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Safyaan Mohammed Sharif',
#   'May 24, 1991, Huddersfield, Yorkshire',
#   '31y 304d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Safyaan Mohammed Sharif',
#   'May 24, 1991, Huddersfield, Yorkshire',
#   '31y 304d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Matches', 'News', 'Photos'],
#  ['Bradley Thomas James Wheal',
#   'August 28, 1996, Durban, KwaZulu-Natal',
#   '26y 208d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Bradley Thomas James Wheal',
#   'August 28, 1996, Durban, KwaZulu-Natal',
#   '26y 208d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Paul Robert Stirling',
#   'September 03, 1990, Belfast',
#   '32y 202d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Paul Robert Stirling',
#   'September 03, 1990, Belfast',
#   '32y 202d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Andrew Balbirnie',
#   'December 28, 1990, Dublin, Ireland',
#   '32y 86d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Andrew Balbirnie',
#   'December 28, 1990, Dublin, Ireland',
#   '32y 86d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Lorcan John Tucker',
#   'September 10, 1996, Dublin',
#   '26y 195d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Lorcan John Tucker',
#   'September 10, 1996, Dublin',
#   '26y 195d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Harry Tom Tector',
#   'December 06, 1999, Dublin',
#   '23y 108d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Harry Tom Tector',
#   'December 06, 1999, Dublin',
#   '23y 108d',
#   'Right hand Bat',
# ...
#  ['Kane Stuart Williamson',
#   'August 08, 1990, Tauranga',
#   '32y 228d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Kane Stuart Williamson',
#   'August 08, 1990, Tauranga',
#   '32y 228d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Glenn Dominic Phillips',
#   'December 06, 1996, East London, Eastern Cape, South Africa',
#   '26y 108d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Glenn Dominic Phillips',
#   'December 06, 1996, East London, Eastern Cape, South Africa',
#   '26y 108d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['James Douglas Sheahan Neesham',
#   'September 17, 1990, Auckland',
#   '32y 188d',
#   'Jimmy Neesham',
#   'Left hand Bat'],
#  ['James Douglas Sheahan Neesham',
#   'September 17, 1990, Auckland',
#   '32y 188d',
#   'Jimmy Neesham',
#   'Left hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Mark Sinclair Chapman',
#   'June 27, 1994, Hong Kong',
#   '28y 270d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Mark Sinclair Chapman',
#   'June 27, 1994, Hong Kong',
#   '28y 270d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Mitchell Josef Santner',
#   'February 05, 1992, Hamilton',
#   '31y 47d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Mitchell Josef Santner',
#   'February 05, 1992, Hamilton',
#   '31y 47d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Inderbir Singh Sodhi',
#   'October 31, 1992, Ludhiana, India',
#   '30y 144d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Inderbir Singh Sodhi',
#   'October 31, 1992, Ludhiana, India',
#   '30y 144d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Timothy Grant Southee',
#   'December 11, 1988, Whangarei, Northland',
#   '34y 103d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Timothy Grant Southee',
#   'December 11, 1988, Whangarei, Northland',
#   '34y 103d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Lachlan Hammond Ferguson',
#   'June 13, 1991, Auckland',
#   '31y 284d',
#   'Lockie',
#   'Right hand Bat'],
#  ['Lachlan Hammond Ferguson',
#   'June 13, 1991, Auckland',
#   '31y 284d',
#   'Lockie',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Trent Alexander Boult',
#   'July 22, 1989, Rotorua',
#   '33y 245d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Trent Alexander Boult',
#   'July 22, 1989, Rotorua',
#   '33y 245d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['David Andrew Warner',
#   'October 27, 1986, Paddington, New South Wales',
#   '36y 148d',
#   'Lloyd',
#   'Left hand Bat'],
#  ['David Andrew Warner',
#   'October 27, 1986, Paddington, New South Wales',
#   '36y 148d',
#   'Lloyd',
#   'Left hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Aaron James Finch',
#   'November 17, 1986, Colac, Victoria',
#   '36y 127d',
#   'Finchy',
#   'Right hand Bat'],
#  ['Aaron James Finch',
#   'November 17, 1986, Colac, Victoria',
#   '36y 127d',
#   'Finchy',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Mitchell Ross Marsh',
#   'October 20, 1991, Attadale, Perth',
#   '31y 155d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Mitchell Ross Marsh',
#   'October 20, 1991, Attadale, Perth',
#   '31y 155d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Glenn James Maxwell',
#   'October 14, 1988, Kew, Melbourne, Victoria',
#   '34y 161d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Glenn James Maxwell',
#   'October 14, 1988, Kew, Melbourne, Victoria',
#   '34y 161d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Marcus Peter Stoinis',
#   'August 16, 1989, Perth',
#   '33y 220d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Marcus Peter Stoinis',
#   'August 16, 1989, Perth',
#   '33y 220d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Timothy Hays David',
#   'March 16, 1996, Singapore',
#   '27y 8d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Timothy Hays David',
#   'March 16, 1996, Singapore',
#   '27y 8d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Matthew Scott Wade',
#   'December 26, 1987, Hobart, Tasmania',
#   '35y 88d',
#   'Wadey',
#   'Left hand Bat'],
#  ['Matthew Scott Wade',
#   'December 26, 1987, Hobart, Tasmania',
#   '35y 88d',
#   'Wadey',
#   'Left hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Patrick James Cummins',
#   'May 08, 1993, Westmead, Sydney',
#   '29y 320d',
#   'Cummo',
#   'Right hand Bat'],
#  ['Patrick James Cummins',
#   'May 08, 1993, Westmead, Sydney',
#   '29y 320d',
#   'Cummo',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Mitchell Aaron Starc',
#   'January 30, 1990, Baulkham Hills, Sydney, New South Wales',
#   '33y 53d',
#   'Left hand Bat',
#   'Left arm Fast'],
#  ['Mitchell Aaron Starc',
#   'January 30, 1990, Baulkham Hills, Sydney, New South Wales',
#   '33y 53d',
#   'Left hand Bat',
#   'Left arm Fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Adam Zampa',
#   'March 31, 1992, Shellharbour, New South Wales',
#   '30y 358d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Adam Zampa',
#   'March 31, 1992, Shellharbour, New South Wales',
#   '30y 358d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Josh Reginald Hazlewood',
#   'January 08, 1991, Tamworth, New South Wales',
#   '32y 75d',
#   'Left hand Bat',
#   'Right arm Fast medium'],
#  ['Josh Reginald Hazlewood',
#   'January 08, 1991, Tamworth, New South Wales',
#   '32y 75d',
#   'Left hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Hazratullah Zazai',
#   'March 23, 1998, Paktia',
#   '25y 1d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Hazratullah Zazai',
#   'March 23, 1998, Paktia',
#   '25y 1d',
#   'Left hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Rahmanullah Gurbaz',
#   'November 28, 2001',
#   '21y 116d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Rahmanullah Gurbaz',
#   'November 28, 2001',
#   '21y 116d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Ibrahim Zadran',
#   'December 12, 2001, Khost',
#   '21y 102d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Ibrahim Zadran',
#   'December 12, 2001, Khost',
#   '21y 102d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Usman Ghani',
#   'November 20, 1996',
#   '26y 124d',
#   'Right hand Bat',
#   'Opening Batter'],
#  ['Usman Ghani',
#   'November 20, 1996',
#   '26y 124d',
#   'Right hand Bat',
#   'Opening Batter'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Najibullah Zadran',
#   'February 28, 1993, Logar',
#   '30y 24d',
#   'Left hand Bat',
#   'Right arm Offbreak'],
#  ['Najibullah Zadran',
#   'February 28, 1993, Logar',
#   '30y 24d',
#   'Left hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Mohammad Nabi',
#   'January 01, 1985, Loger, Afghanistan',
#   '38y 82d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Mohammad Nabi',
#   'January 01, 1985, Loger, Afghanistan',
#   '38y 82d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Matches', 'Videos', 'News'],
#  ['Azmatullah Omarzai',
#   'March 24, 2000',
#   '23y',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Azmatullah Omarzai',
#   'March 24, 2000',
#   '23y',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Rashid Khan Arman',
#   'September 20, 1998, Nangarhar',
#   '24y 185d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Rashid Khan Arman',
#   'September 20, 1998, Nangarhar',
#   '24y 185d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Mujeeb Ur Rahman',
#   'March 28, 2001, Khost',
#   '21y 361d',
#   'Mujeeb Zadran',
#   'Right hand Bat'],
#  ['Mujeeb Ur Rahman',
#   'March 28, 2001, Khost',
#   '21y 361d',
#   'Mujeeb Zadran',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Fareed Ahmad Malik',
#   'August 10, 1994, Nangarahar',
#   '28y 226d',
#   'Farid Malik',
#   'Left hand Bat'],
#  ['Fareed Ahmad Malik',
#   'August 10, 1994, Nangarahar',
#   '28y 226d',
#   'Farid Malik',
#   'Left hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Fazalhaq Farooqi',
#   'September 22, 2000, Baghlan',
#   '22y 183d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Fazalhaq Farooqi',
#   'September 22, 2000, Baghlan',
#   '22y 183d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Joseph Charles Buttler',
#   'September 08, 1990, Taunton, Somerset',
#   '32y 197d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Joseph Charles Buttler',
#   'September 08, 1990, Taunton, Somerset',
#   '32y 197d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Alexander Daniel Hales',
#   'January 03, 1989, Hillingdon, Middlesex',
#   '34y 80d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Alexander Daniel Hales',
#   'January 03, 1989, Hillingdon, Middlesex',
#   '34y 80d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Dawid Johannes Malan',
#   'September 03, 1987, Roehampton, England',
#   '35y 202d',
#   'AC',
#   'Left hand Bat'],
#  ['Dawid Johannes Malan',
#   'September 03, 1987, Roehampton, England',
#   '35y 202d',
#   'AC',
#   'Left hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Benjamin Andrew Stokes',
#   'June 04, 1991, Christchurch, Canterbury, New Zealand',
#   '31y 293d',
#   'Left hand Bat',
#   'Right arm Fast medium'],
#  ['Benjamin Andrew Stokes',
#   'June 04, 1991, Christchurch, Canterbury, New Zealand',
#   '31y 293d',
#   'Left hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Liam Stephen Livingstone',
#   'August 04, 1993, Barrow-in-Furness, Cumberland',
#   '29y 232d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak'],
#  ['Liam Stephen Livingstone',
#   'August 04, 1993, Barrow-in-Furness, Cumberland',
#   '29y 232d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Harry Cherrington Brook',
#   'February 22, 1999, Keighley, Yorkshire',
#   '24y 30d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Harry Cherrington Brook',
#   'February 22, 1999, Keighley, Yorkshire',
#   '24y 30d',
#   'Right hand Bat',
#   'Right arm Medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Moeen Munir Ali',
#   'June 18, 1987, Birmingham',
#   '35y 279d',
#   'Moe',
#   'Left hand Bat'],
#  ['Moeen Munir Ali',
#   'June 18, 1987, Birmingham',
#   '35y 279d',
#   'Moe',
#   'Left hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Christopher Roger Woakes',
#   'March 02, 1989, Birmingham, Warwickshire',
#   '34y 22d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Christopher Roger Woakes',
#   'March 02, 1989, Birmingham, Warwickshire',
#   '34y 22d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Samuel Matthew Curran',
#   'June 03, 1998, Northampton',
#   '24y 294d',
#   'Left hand Bat',
#   'Left arm Medium fast'],
#  ['Samuel Matthew Curran',
#   'June 03, 1998, Northampton',
#   '24y 294d',
#   'Left hand Bat',
#   'Left arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Adil Usman Rashid',
#   'February 17, 1988, Bradford, Yorkshire',
#   '35y 35d',
#   'Dilly, Hoover',
#   'Right hand Bat'],
#  ['Adil Usman Rashid',
#   'February 17, 1988, Bradford, Yorkshire',
#   '35y 35d',
#   'Dilly, Hoover',
#   'Right hand Bat'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Mark Andrew Wood',
#   'January 11, 1990, Ashington, Northumberland',
#   '33y 72d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Mark Andrew Wood',
#   'January 11, 1990, Ashington, Northumberland',
#   '33y 72d',
#   'Right hand Bat',
#   'Right arm Fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Paul Robert Stirling',
#   'September 03, 1990, Belfast',
#   '32y 202d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Paul Robert Stirling',
#   'September 03, 1990, Belfast',
#   '32y 202d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Andrew Balbirnie',
#   'December 28, 1990, Dublin, Ireland',
#   '32y 86d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Andrew Balbirnie',
#   'December 28, 1990, Dublin, Ireland',
#   '32y 86d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Lorcan John Tucker',
#   'September 10, 1996, Dublin',
#   '26y 195d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Lorcan John Tucker',
#   'September 10, 1996, Dublin',
#   '26y 195d',
#   'Right hand Bat',
#   'Wicketkeeper'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Harry Tom Tector',
#   'December 06, 1999, Dublin',
#   '23y 108d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Harry Tom Tector',
#   'December 06, 1999, Dublin',
#   '23y 108d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Curtis Campher',
#   'April 20, 1999, Johannesburg',
#   '23y 338d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Curtis Campher',
#   'April 20, 1999, Johannesburg',
#   '23y 338d',
#   'Right hand Bat',
#   'Right arm Medium fast'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['George Henry Dockrell',
#   'July 22, 1992, Dublin',
#   '30y 245d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['George Henry Dockrell',
#   'July 22, 1992, Dublin',
#   '30y 245d',
#   'Right hand Bat',
#   'Slow Left arm Orthodox'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Gareth James Delany',
#   'April 28, 1997, Dublin',
#   '25y 330d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Gareth James Delany',
#   'April 28, 1997, Dublin',
#   '25y 330d',
#   'Right hand Bat',
#   'Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Mark Richard Adair',
#   'March 27, 1996, Holywood, Northern Ireland',
#   '26y 362d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Mark Richard Adair',
#   'March 27, 1996, Holywood, Northern Ireland',
#   '26y 362d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Simi Singh',
#   'February 04, 1987, Bathlana, Punjab, India',
#   '36y 48d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Simi Singh',
#   'February 04, 1987, Bathlana, Punjab, India',
#   '36y 48d',
#   'Right hand Bat',
#   'Right arm Offbreak, Legbreak Googly'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Barry John McCarthy',
#   'September 13, 1992',
#   '30y 192d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Barry John McCarthy',
#   'September 13, 1992',
#   '30y 192d',
#   'Right hand Bat',
#   'Right arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'News'],
#  ['Joshua Brian Little',
#   'November 01, 1999, Dublin',
#   '23y 143d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Joshua Brian Little',
#   'November 01, 1999, Dublin',
#   '23y 143d',
#   'Right hand Bat',
#   'Left arm Fast medium'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Balapuwaduge Kusal Gimhan Mendis',
#   'February 02, 1995, Moratuwa',
#   '28y 50d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Balapuwaduge Kusal Gimhan Mendis',
#   'February 02, 1995, Moratuwa',
#   '28y 50d',
#   'Right hand Bat',
#   'Legbreak'],
#  ['Overview', 'Stats', 'Records', 'Matches', 'Videos'],
#  ['Dhananjaya Maduranga de Silva',
#   'September 06, 1991, Colombo',
#   '31y 199d',
#   'Right hand Bat',
#   'Right arm Offbreak'],
#  ...]

# %%
len(player_details)
# Out:
# 2813

# %%
temp=player_details
unique_list=[]

# %%
for x in player_details:
    if x not in unique_list:
        unique_list.append(x)

# %%
len(unique_list)
# Out:
# 223

# %%
temp=[]
for x in unique_list:
    if x[0] != "Overview":
        temp.append(x)

# %%
players_dataframe = pd.DataFrame(temp)

# %%
players_dataframe.head()
# Out:
#                      Name                                DOB       Age  \
# 0      Michael van Lingen                   October 24, 1997  25y 151d
# 1           Divan la Cock                  February 23, 2003   20y 29d
# 2    Stephan Julian Baard            April 29, 1992, Namibia  30y 329d
# 3   Merwe Gerhard Erasmus  April 11, 1995, Windhoek, Namibia  27y 347d
# 4  Johannes Jonathan Smit    November 10, 1995, keetmanshoop  27y 134d
#
#     Batting_Style                   Role
# 0   Left hand Bat        Left arm Medium
# 1  Right hand Bat               Legbreak
# 2  Right hand Bat  Right arm Medium fast
# 3  Right hand Bat     Right arm Offbreak
# 4  Right hand Bat   Left arm Medium fast

# %%
players_dataframe.rename(columns={0:"Name",1:"DOB",2:"Age",3:"Batting_Style",4:"Role"},inplace=True)

# %%
players_dataframe.to_csv("players_details.csv")
